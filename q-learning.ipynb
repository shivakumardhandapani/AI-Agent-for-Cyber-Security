# %%
# !pip install -r requirements.txt
# Out:
# Obtaining gym_idsgame from git+https://github.com/Limmen/gym-idsgame.git@d10830fef55308d383c98b41b34688a7fceae357#egg=gym_idsgame (from -r requirements.txt (line 4))
#   Skipping because already up-to-date.
#   Preparing metadata (setup.py) ... done
# Collecting cloudpickle==3.1.0 (from -r requirements.txt (line 1))
#   Using cached cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gym==0.26.2 (from -r requirements.txt (line 2))
#   Using cached gym-0.26.2-py3-none-any.whl
# Collecting gym-notices==0.0.8 (from -r requirements.txt (line 3))
#   Using cached gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Collecting Gymnasium==0.29.1 (from -r requirements.txt (line 5))
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting gymnasium-notices==0.0.1 (from -r requirements.txt (line 6))
#   Using cached gymnasium_notices-0.0.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting imageio==2.36.0 (from -r requirements.txt (line 7))
#   Using cached imageio-2.36.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jsonpickle==4.0.0 (from -r requirements.txt (line 8))
#   Using cached jsonpickle-4.0.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting matplotlib==3.9.2 (from -r requirements.txt (line 9))
#   Using cached matplotlib-3.9.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting numpy==1.24.3 (from -r requirements.txt (line 11))
#   Using cached numpy-1.24.3.tar.gz (10.9 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [32 lines of output]
#       Traceback (most recent call last):
#         File "/opt/homebrew/anaconda3/envs/gym-idsgame/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/opt/homebrew/anaconda3/envs/gym-idsgame/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/homebrew/anaconda3/envs/gym-idsgame/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 137, in get_requires_for_build_wheel
#           backend = _build_backend()
#         File "/opt/homebrew/anaconda3/envs/gym-idsgame/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 70, in _build_backend
#           obj = import_module(mod_path)
#         File "/opt/homebrew/anaconda3/envs/gym-idsgame/lib/python3.13/importlib/__init__.py", line 88, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 1026, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "/private/var/folders/g8/0h0gh8rj3wbbyxrztby_mj7c0000gn/T/pip-build-env-mmt228an/overlay/lib/python3.13/site-packages/setuptools/__init__.py", line 16, in <module>
#           import setuptools.version
#         File "/private/var/folders/g8/0h0gh8rj3wbbyxrztby_mj7c0000gn/T/pip-build-env-mmt228an/overlay/lib/python3.13/site-packages/setuptools/version.py", line 1, in <module>
#           import pkg_resources
#         File "/private/var/folders/g8/0h0gh8rj3wbbyxrztby_mj7c0000gn/T/pip-build-env-mmt228an/overlay/lib/python3.13/site-packages/pkg_resources/__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pwd
# Out:
# /Users/krishnaasrinivas/Desktop/AI-Agent-for-Cyber-Security

# %%
cp /Users/shirley/Downloads/NEU/5100_final_projectHealthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/atomic_write.py /content/Healthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/closer.py /content/Healthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/json_utils.py /usr/local/lib/python3.10/dist-packages/gym/utils/
# Out:
# usage: cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file target_file
#        cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file ... target_directory

# %%
from gym_idsgame.agents.training_agents.q_learning.q_agent_config import QAgentConfig

# %%
# !pip install gym-idsgame==1.0.12
# Out:
# Requirement already satisfied: gym-idsgame==1.0.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.0.12)
# Requirement already satisfied: gym in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.26.2)
# Requirement already satisfied: pyglet==1.5.15 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.5.15)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.24.3)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.5.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (3.9.2)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.13.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.67.0)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.10.0.84)
# Requirement already satisfied: imageio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.36.0)
# Requirement already satisfied: jsonpickle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.0.0)
# Requirement already satisfied: tensorboard in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.19.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.5.2)
# Requirement already satisfied: stable_baselines3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.3.2)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.20.1)
# Requirement already satisfied: cv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.0.0)
# Requirement already satisfied: PyOpenGL in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (3.1.9)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->gym-idsgame==1.0.12) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->gym-idsgame==1.0.12) (0.0.8)
# Requirement already satisfied: pillow>=8.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imageio->gym-idsgame==1.0.12) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (3.5.0)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn->gym-idsgame==1.0.12) (2.2.3)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable_baselines3->gym-idsgame==1.0.12) (0.29.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (4.12.2)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.4.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.1.5)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy==1.13.1->torch->gym-idsgame==1.0.12) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (6.30.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (75.4.0)
# Requirement already satisfied: six>1.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (3.1.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3->gym-idsgame==1.0.12) (0.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn->gym-idsgame==1.0.12) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn->gym-idsgame==1.0.12) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->gym-idsgame==1.0.12) (3.0.2)

# %%
from gym_idsgame.agents.training_agents.q_learning.tabular_q_learning.tabular_q_agent import TabularQAgent
from experiments.util import util
from experiments.util.plotting_util import read_and_plot_results
import gymnasium as gym
from src.environment.compatibility_wrapper import GymCompatibilityWrapper

# %%
import os

# %%
random_seed = 33
default_output_dir = os.getcwd()
util.create_artefact_dirs(default_output_dir, random_seed)

# %%
q_agent_config = QAgentConfig(gamma=0.999, alpha=0.0005, epsilon=1, render=False, eval_sleep=0.9,
                              min_epsilon=0.01, eval_episodes=100, train_log_frequency=100,
                              epsilon_decay=0.9999, video=False, eval_log_frequency=1,
                              video_fps=5, video_dir=default_output_dir + "/results/videos/" + str(random_seed), num_episodes=20001,
                              eval_render=False, gifs=False, gif_dir=default_output_dir + "/results/gifs/" + str(random_seed),
                              eval_frequency=1000, attacker=False, defender=True, video_frequency=101,
                              save_dir=default_output_dir + "/results/data/" + str(random_seed))

# %%
env_name = "idsgame-random_attack-v8"
env = gym.make(env_name, save_dir=default_output_dir + "/results/data/" + str(random_seed))
env = GymCompatibilityWrapper(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment idsgame-random_attack-v8 is out of date. You should consider upgrading to version `v21`.
#   logger.deprecation(

# %%
agent = TabularQAgent(env, q_agent_config)

agent.train()
train_result = agent.train_result
eval_result = agent.eval_result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_states to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_states` for environment variables or `env.get_wrapper_attr('num_states')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_attack_actions to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_attack_actions` for environment variables or `env.get_wrapper_attr('num_attack_actions')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_defense_actions to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_defense_actions` for environment variables or `env.get_wrapper_attr('num_defense_actions')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.idsgame_config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.idsgame_config` for environment variables or `env.get_wrapper_attr('idsgame_config')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:175: UserWarning: WARN: The default seed argument in `Env.reset` should be `None`, otherwise the environment will by default always be deterministic. Actual default: seed: int = 0
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be int32, actual type: float64
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_observation to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_observation` for environment variables or `env.get_wrapper_attr('get_observation')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.is_defense_legal to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.is_defense_legal` for environment variables or `env.get_wrapper_attr('is_defense_legal')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be int32, actual type: float64
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:246: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'tuple'>
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.state to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.state` for environment variables or `env.get_wrapper_attr('state')` that will search the reminding wrappers.
#   logger.warn(
# [Train] episode: 0.00 epsilon:1.00,avg_a_R:-1.00,avg_d_R:1.00,avg_t:5.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00,A
# l Episode:   0%|                                                                    | 0/100 [00:00<?, ?it/s]
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:0.33,avg_d_R:1.00,avg_t:6.00,avg_h:0.00,acc_A_R:0.33,acc_D_R:1.00,replay_s:-1,lr:0.00E
# al] episode:1,avg_a_R:1.77,avg_d_R:-0.50,avg_t:6.50,avg_h:0.50,acc_A_R:3.53,acc_D_R:-1.00,replay_s:-1,lr:0.0
# al] episode:2,avg_a_R:0.84,avg_d_R:0.00,avg_t:4.67,avg_h:0.33,acc_A_R:2.53,acc_D_R:0.00,replay_s:-1,lr:0.00E
# al] episode:3,avg_a_R:0.38,avg_d_R:0.25,avg_t:3.75,avg_h:0.25,acc_A_R:1.53,acc_D_R:1.00,replay_s:-1,lr:0.00E
# al] episode:4,avg_a_R:0.77,avg_d_R:-0.20,avg_t:6.20,avg_h:0.40,acc_A_R:3.84,acc_D_R:-1.00,replay_s:-1,lr:0.0
# al] episode:5,avg_a_R:0.47,avg_d_R:0.00,avg_t:6.00,avg_h:0.33,acc_A_R:2.84,acc_D_R:0.00,replay_s:-1,lr:0.00E
# al] episode:6,avg_a_R:0.26,avg_d_R:0.14,avg_t:5.29,avg_h:0.29,acc_A_R:1.84,acc_D_R:1.00,replay_s:-1,lr:0.00E
# al] episode:7,avg_a_R:0.11,avg_d_R:0.25,avg_t:4.75,avg_h:0.25,acc_A_R:0.84,acc_D_R:2.00,replay_s:-1,lr:0.00E
# al] episode:8,avg_a_R:-0.02,avg_d_R:0.33,avg_t:4.78,avg_h:0.22,acc_A_R:-0.16,acc_D_R:3.00,replay_s:-1,lr:0.0
# al] episode:9,avg_a_R:-0.12,avg_d_R:0.40,avg_t:5.00,avg_h:0.20,acc_A_R:-1.16,acc_D_R:4.00,replay_s:-1,lr:0.0
# al] episode:10,avg_a_R:0.20,avg_d_R:0.18,avg_t:5.09,avg_h:0.27,acc_A_R:2.18,acc_D_R:2.00,replay_s:-1,lr:0.00
# al] episode:11,avg_a_R:0.10,avg_d_R:0.25,avg_t:5.00,avg_h:0.25,acc_A_R:1.18,acc_D_R:3.00,replay_s:-1,lr:0.00
# al] episode:12,avg_a_R:0.17,avg_d_R:0.31,avg_t:4.92,avg_h:0.23,acc_A_R:2.18,acc_D_R:4.00,replay_s:-1,lr:0.00
# al] episode:13,avg_a_R:0.08,avg_d_R:0.36,avg_t:4.64,avg_h:0.21,acc_A_R:1.18,acc_D_R:5.00,replay_s:-1,lr:0.00
# al] episode:14,avg_a_R:0.01,avg_d_R:0.40,avg_t:4.40,avg_h:0.20,acc_A_R:0.18,acc_D_R:6.00,replay_s:-1,lr:0.00
# al] episode:15,avg_a_R:-0.05,avg_d_R:0.44,avg_t:4.19,avg_h:0.19,acc_A_R:-0.82,acc_D_R:7.00,replay_s:-1,lr:0.
# al] episode:16,avg_a_R:-0.11,avg_d_R:0.47,avg_t:4.06,avg_h:0.18,acc_A_R:-1.82,acc_D_R:8.00,replay_s:-1,lr:0.
# al] episode:17,avg_a_R:-0.09,avg_d_R:0.50,avg_t:4.28,avg_h:0.17,acc_A_R:-1.66,acc_D_R:9.00,replay_s:-1,lr:0.
# al] episode:18,avg_a_R:0.09,avg_d_R:0.37,avg_t:4.32,avg_h:0.21,acc_A_R:1.68,acc_D_R:7.00,replay_s:-1,lr:0.00
# al] episode:19,avg_a_R:0.03,avg_d_R:0.40,avg_t:4.35,avg_h:0.20,acc_A_R:0.68,acc_D_R:8.00,replay_s:-1,lr:0.00
# al] episode:20,avg_a_R:-0.02,avg_d_R:0.43,avg_t:4.43,avg_h:0.19,acc_A_R:-0.32,acc_D_R:9.00,replay_s:-1,lr:0.
# al] episode:21,avg_a_R:-0.06,avg_d_R:0.45,avg_t:4.27,avg_h:0.18,acc_A_R:-1.32,acc_D_R:10.00,replay_s:-1,lr:0
# al] episode:22,avg_a_R:-0.10,avg_d_R:0.48,avg_t:4.13,avg_h:0.17,acc_A_R:-2.32,acc_D_R:11.00,replay_s:-1,lr:0
# al] episode:23,avg_a_R:-0.14,avg_d_R:0.50,avg_t:4.00,avg_h:0.17,acc_A_R:-3.32,acc_D_R:12.00,replay_s:-1,lr:0
# al] episode:24,avg_a_R:-0.17,avg_d_R:0.52,avg_t:3.96,avg_h:0.16,acc_A_R:-4.32,acc_D_R:13.00,replay_s:-1,lr:0
# al] episode:25,avg_a_R:-0.15,avg_d_R:0.54,avg_t:4.12,avg_h:0.15,acc_A_R:-3.99,acc_D_R:14.00,replay_s:-1,lr:0
# al] episode:25,avg_a_R:-0.15,avg_d_R:0.54,avg_t:4.12,avg_h:0.15,acc_A_R:-3.99,acc_D_R:14.00,replay_s:-1,lr:0
# al] episode:26,avg_a_R:-0.04,avg_d_R:0.44,avg_t:4.19,avg_h:0.19,acc_A_R:-0.99,acc_D_R:12.00,replay_s:-1,lr:0
# al] episode:27,avg_a_R:-0.07,avg_d_R:0.46,avg_t:4.29,avg_h:0.18,acc_A_R:-1.99,acc_D_R:13.00,replay_s:-1,lr:0
# al] episode:28,avg_a_R:-0.06,avg_d_R:0.48,avg_t:4.45,avg_h:0.17,acc_A_R:-1.82,acc_D_R:14.00,replay_s:-1,lr:0
# al] episode:29,avg_a_R:-0.09,avg_d_R:0.50,avg_t:4.33,avg_h:0.17,acc_A_R:-2.82,acc_D_R:15.00,replay_s:-1,lr:0
# al] episode:30,avg_a_R:-0.12,avg_d_R:0.52,avg_t:4.39,avg_h:0.16,acc_A_R:-3.82,acc_D_R:16.00,replay_s:-1,lr:0
# al] episode:31,avg_a_R:-0.15,avg_d_R:0.53,avg_t:4.38,avg_h:0.16,acc_A_R:-4.82,acc_D_R:17.00,replay_s:-1,lr:0
# al] episode:32,avg_a_R:-0.18,avg_d_R:0.55,avg_t:4.27,avg_h:0.15,acc_A_R:-5.82,acc_D_R:18.00,replay_s:-1,lr:0
# al] episode:33,avg_a_R:-0.20,avg_d_R:0.56,avg_t:4.18,avg_h:0.15,acc_A_R:-6.82,acc_D_R:19.00,replay_s:-1,lr:0
# al] episode:34,avg_a_R:-0.19,avg_d_R:0.57,avg_t:4.37,avg_h:0.14,acc_A_R:-6.66,acc_D_R:20.00,replay_s:-1,lr:0
# al] episode:35,avg_a_R:-0.07,avg_d_R:0.50,avg_t:4.33,avg_h:0.17,acc_A_R:-2.66,acc_D_R:18.00,replay_s:-1,lr:0
# al] episode:36,avg_a_R:-0.10,avg_d_R:0.51,avg_t:4.35,avg_h:0.16,acc_A_R:-3.66,acc_D_R:19.00,replay_s:-1,lr:0
# al] episode:37,avg_a_R:-0.12,avg_d_R:0.53,avg_t:4.26,avg_h:0.16,acc_A_R:-4.66,acc_D_R:20.00,replay_s:-1,lr:0
# al] episode:38,avg_a_R:-0.15,avg_d_R:0.54,avg_t:4.33,avg_h:0.15,acc_A_R:-5.66,acc_D_R:21.00,replay_s:-1,lr:0
# al] episode:39,avg_a_R:-0.17,avg_d_R:0.55,avg_t:4.38,avg_h:0.15,acc_A_R:-6.66,acc_D_R:22.00,replay_s:-1,lr:0
# al] episode:40,avg_a_R:-0.19,avg_d_R:0.56,avg_t:4.29,avg_h:0.15,acc_A_R:-7.66,acc_D_R:23.00,replay_s:-1,lr:0
# al] episode:41,avg_a_R:-0.16,avg_d_R:0.57,avg_t:4.29,avg_h:0.14,acc_A_R:-6.66,acc_D_R:24.00,replay_s:-1,lr:0
# al] episode:42,avg_a_R:-0.08,avg_d_R:0.51,avg_t:4.37,avg_h:0.16,acc_A_R:-3.49,acc_D_R:22.00,replay_s:-1,lr:0
# al] episode:43,avg_a_R:-0.06,avg_d_R:0.52,avg_t:4.34,avg_h:0.16,acc_A_R:-2.49,acc_D_R:23.00,replay_s:-1,lr:0
# al] episode:44,avg_a_R:-0.08,avg_d_R:0.53,avg_t:4.38,avg_h:0.16,acc_A_R:-3.49,acc_D_R:24.00,replay_s:-1,lr:0
# al] episode:45,avg_a_R:-0.10,avg_d_R:0.54,avg_t:4.33,avg_h:0.15,acc_A_R:-4.49,acc_D_R:25.00,replay_s:-1,lr:0
# al] episode:46,avg_a_R:-0.03,avg_d_R:0.49,avg_t:4.36,avg_h:0.17,acc_A_R:-1.49,acc_D_R:23.00,replay_s:-1,lr:0
# al] episode:47,avg_a_R:-0.05,avg_d_R:0.50,avg_t:4.29,avg_h:0.17,acc_A_R:-2.49,acc_D_R:24.00,replay_s:-1,lr:0
# al] episode:48,avg_a_R:-0.07,avg_d_R:0.51,avg_t:4.35,avg_h:0.16,acc_A_R:-3.49,acc_D_R:25.00,replay_s:-1,lr:0
# al] episode:49,avg_a_R:-0.09,avg_d_R:0.52,avg_t:4.28,avg_h:0.16,acc_A_R:-4.49,acc_D_R:26.00,replay_s:-1,lr:0
# al] episode:50,avg_a_R:-0.11,avg_d_R:0.53,avg_t:4.25,avg_h:0.16,acc_A_R:-5.49,acc_D_R:27.00,replay_s:-1,lr:0
# al] episode:50,avg_a_R:-0.11,avg_d_R:0.53,avg_t:4.25,avg_h:0.16,acc_A_R:-5.49,acc_D_R:27.00,replay_s:-1,lr:0
# al] episode:51,avg_a_R:-0.10,avg_d_R:0.54,avg_t:4.25,avg_h:0.15,acc_A_R:-4.99,acc_D_R:28.00,replay_s:-1,lr:0
# al] episode:52,avg_a_R:-0.11,avg_d_R:0.55,avg_t:4.23,avg_h:0.15,acc_A_R:-5.99,acc_D_R:29.00,replay_s:-1,lr:0
# al] episode:53,avg_a_R:-0.13,avg_d_R:0.56,avg_t:4.17,avg_h:0.15,acc_A_R:-6.99,acc_D_R:30.00,replay_s:-1,lr:0
# al] episode:54,avg_a_R:-0.05,avg_d_R:0.51,avg_t:4.13,avg_h:0.16,acc_A_R:-2.99,acc_D_R:28.00,replay_s:-1,lr:0
# al] episode:55,avg_a_R:-0.07,avg_d_R:0.52,avg_t:4.09,avg_h:0.16,acc_A_R:-3.99,acc_D_R:29.00,replay_s:-1,lr:0
# al] episode:56,avg_a_R:-0.09,avg_d_R:0.53,avg_t:4.07,avg_h:0.16,acc_A_R:-4.99,acc_D_R:30.00,replay_s:-1,lr:0
# al] episode:57,avg_a_R:-0.10,avg_d_R:0.53,avg_t:4.05,avg_h:0.16,acc_A_R:-5.99,acc_D_R:31.00,replay_s:-1,lr:0
# al] episode:58,avg_a_R:-0.10,avg_d_R:0.54,avg_t:4.12,avg_h:0.15,acc_A_R:-5.82,acc_D_R:32.00,replay_s:-1,lr:0
# al] episode:59,avg_a_R:-0.04,avg_d_R:0.50,avg_t:4.13,avg_h:0.17,acc_A_R:-2.49,acc_D_R:30.00,replay_s:-1,lr:0
# al] episode:60,avg_a_R:0.01,avg_d_R:0.46,avg_t:4.16,avg_h:0.18,acc_A_R:0.84,acc_D_R:28.00,replay_s:-1,lr:0.0
# al] episode:61,avg_a_R:0.06,avg_d_R:0.42,avg_t:4.31,avg_h:0.19,acc_A_R:3.46,acc_D_R:26.00,replay_s:-1,lr:0.0
# al] episode:62,avg_a_R:0.04,avg_d_R:0.43,avg_t:4.32,avg_h:0.19,acc_A_R:2.46,acc_D_R:27.00,replay_s:-1,lr:0.0
# al] episode:63,avg_a_R:0.09,avg_d_R:0.39,avg_t:4.33,avg_h:0.20,acc_A_R:5.96,acc_D_R:25.00,replay_s:-1,lr:0.0
# al] episode:64,avg_a_R:0.14,avg_d_R:0.35,avg_t:4.35,avg_h:0.22,acc_A_R:9.21,acc_D_R:23.00,replay_s:-1,lr:0.0
# al] episode:65,avg_a_R:0.12,avg_d_R:0.36,avg_t:4.32,avg_h:0.21,acc_A_R:8.21,acc_D_R:24.00,replay_s:-1,lr:0.0
# al] episode:66,avg_a_R:0.11,avg_d_R:0.37,avg_t:4.27,avg_h:0.21,acc_A_R:7.21,acc_D_R:25.00,replay_s:-1,lr:0.0
# al] episode:67,avg_a_R:0.09,avg_d_R:0.38,avg_t:4.28,avg_h:0.21,acc_A_R:6.21,acc_D_R:26.00,replay_s:-1,lr:0.0
# al] episode:68,avg_a_R:0.08,avg_d_R:0.39,avg_t:4.25,avg_h:0.20,acc_A_R:5.21,acc_D_R:27.00,replay_s:-1,lr:0.0
# al] episode:69,avg_a_R:0.12,avg_d_R:0.36,avg_t:4.29,avg_h:0.21,acc_A_R:8.46,acc_D_R:25.00,replay_s:-1,lr:0.0
# al] episode:70,avg_a_R:0.13,avg_d_R:0.37,avg_t:4.30,avg_h:0.21,acc_A_R:9.46,acc_D_R:26.00,replay_s:-1,lr:0.0
# al] episode:71,avg_a_R:0.18,avg_d_R:0.33,avg_t:4.33,avg_h:0.22,acc_A_R:12.66,acc_D_R:24.00,replay_s:-1,lr:0.
# al] episode:72,avg_a_R:0.16,avg_d_R:0.34,avg_t:4.29,avg_h:0.22,acc_A_R:11.66,acc_D_R:25.00,replay_s:-1,lr:0.
# al] episode:73,avg_a_R:0.16,avg_d_R:0.35,avg_t:4.32,avg_h:0.22,acc_A_R:12.16,acc_D_R:26.00,replay_s:-1,lr:0.
# al] episode:74,avg_a_R:0.20,avg_d_R:0.32,avg_t:4.41,avg_h:0.23,acc_A_R:15.28,acc_D_R:24.00,replay_s:-1,lr:0.
# al] episode:74,avg_a_R:0.20,avg_d_R:0.32,avg_t:4.41,avg_h:0.23,acc_A_R:15.28,acc_D_R:24.00,replay_s:-1,lr:0.
# al] episode:75,avg_a_R:0.19,avg_d_R:0.33,avg_t:4.41,avg_h:0.22,acc_A_R:14.28,acc_D_R:25.00,replay_s:-1,lr:0.
# al] episode:76,avg_a_R:0.17,avg_d_R:0.34,avg_t:4.38,avg_h:0.22,acc_A_R:13.28,acc_D_R:26.00,replay_s:-1,lr:0.
# al] episode:77,avg_a_R:0.16,avg_d_R:0.35,avg_t:4.36,avg_h:0.22,acc_A_R:12.28,acc_D_R:27.00,replay_s:-1,lr:0.
# al] episode:78,avg_a_R:0.14,avg_d_R:0.35,avg_t:4.35,avg_h:0.22,acc_A_R:11.28,acc_D_R:28.00,replay_s:-1,lr:0.
# al] episode:79,avg_a_R:0.15,avg_d_R:0.36,avg_t:4.40,avg_h:0.21,acc_A_R:11.61,acc_D_R:29.00,replay_s:-1,lr:0.
# al] episode:80,avg_a_R:0.19,avg_d_R:0.33,avg_t:4.41,avg_h:0.22,acc_A_R:15.11,acc_D_R:27.00,replay_s:-1,lr:0.
# al] episode:81,avg_a_R:0.17,avg_d_R:0.34,avg_t:4.41,avg_h:0.22,acc_A_R:14.11,acc_D_R:28.00,replay_s:-1,lr:0.
# al] episode:82,avg_a_R:0.18,avg_d_R:0.35,avg_t:4.40,avg_h:0.22,acc_A_R:15.11,acc_D_R:29.00,replay_s:-1,lr:0.
# al] episode:83,avg_a_R:0.18,avg_d_R:0.36,avg_t:4.43,avg_h:0.21,acc_A_R:15.31,acc_D_R:30.00,replay_s:-1,lr:0.
# al] episode:84,avg_a_R:0.17,avg_d_R:0.36,avg_t:4.44,avg_h:0.21,acc_A_R:14.31,acc_D_R:31.00,replay_s:-1,lr:0.
# al] episode:85,avg_a_R:0.21,avg_d_R:0.34,avg_t:4.44,avg_h:0.22,acc_A_R:17.65,acc_D_R:29.00,replay_s:-1,lr:0.
# al] episode:86,avg_a_R:0.19,avg_d_R:0.34,avg_t:4.44,avg_h:0.22,acc_A_R:16.65,acc_D_R:30.00,replay_s:-1,lr:0.
# al] episode:87,avg_a_R:0.18,avg_d_R:0.35,avg_t:4.42,avg_h:0.22,acc_A_R:15.65,acc_D_R:31.00,replay_s:-1,lr:0.
# al] episode:88,avg_a_R:0.19,avg_d_R:0.36,avg_t:4.40,avg_h:0.21,acc_A_R:16.65,acc_D_R:32.00,replay_s:-1,lr:0.
# al] episode:89,avg_a_R:0.19,avg_d_R:0.37,avg_t:4.43,avg_h:0.21,acc_A_R:16.90,acc_D_R:33.00,replay_s:-1,lr:0.
# al] episode:90,avg_a_R:0.22,avg_d_R:0.34,avg_t:4.44,avg_h:0.22,acc_A_R:20.40,acc_D_R:31.00,replay_s:-1,lr:0.
# al] episode:91,avg_a_R:0.25,avg_d_R:0.32,avg_t:4.52,avg_h:0.23,acc_A_R:23.02,acc_D_R:29.00,replay_s:-1,lr:0.
# al] episode:92,avg_a_R:0.28,avg_d_R:0.29,avg_t:4.55,avg_h:0.24,acc_A_R:26.27,acc_D_R:27.00,replay_s:-1,lr:0.
# al] episode:93,avg_a_R:0.27,avg_d_R:0.30,avg_t:4.55,avg_h:0.23,acc_A_R:25.27,acc_D_R:28.00,replay_s:-1,lr:0.
# al] episode:94,avg_a_R:0.26,avg_d_R:0.31,avg_t:4.54,avg_h:0.23,acc_A_R:24.27,acc_D_R:29.00,replay_s:-1,lr:0.
# al] episode:95,avg_a_R:0.24,avg_d_R:0.31,avg_t:4.56,avg_h:0.23,acc_A_R:23.27,acc_D_R:30.00,replay_s:-1,lr:0.
# al] episode:96,avg_a_R:0.23,avg_d_R:0.32,avg_t:4.57,avg_h:0.23,acc_A_R:22.27,acc_D_R:31.00,replay_s:-1,lr:0.
# al] episode:97,avg_a_R:0.23,avg_d_R:0.33,avg_t:4.59,avg_h:0.22,acc_A_R:22.47,acc_D_R:32.00,replay_s:-1,lr:0.
# al] episode:98,avg_a_R:0.22,avg_d_R:0.33,avg_t:4.57,avg_h:0.22,acc_A_R:21.47,acc_D_R:33.00,replay_s:-1,lr:0.
# al] episode:99,avg_a_R:0.20,avg_d_R:0.34,avg_t:4.56,avg_h:0.22,acc_A_R:20.47,acc_D_R:34.00,replay_s:-1,lr:0.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.save_trajectories to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.save_trajectories` for environment variables or `env.get_wrapper_attr('save_trajectories')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.save_attack_data to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.save_attack_data` for environment variables or `env.get_wrapper_attr('save_attack_data')` that will search the reminding wrappers.
#   logger.warn(
# starting eval with non-empty result objecta_R:-0.04,avg_d_R:0.52,avg_t:4.29,avg_h:0.16,acc_A_R:-131.86,acc_D_R:
#
# [Eval] episode:0,avg_a_R:0.20,avg_d_R:0.34,avg_t:4.56,avg_h:0.22,acc_A_R:20.47,acc_D_R:34.00,replay_s:-1,lr:0.0
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.00,avg_h:0.00,acc_A_R:19.47,acc_D_R:35.00,replay_s:-1,lr:0.
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.00,avg_h:0.00,acc_A_R:18.47,acc_D_R:36.00,replay_s:-1,lr:0.
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.33,avg_h:0.00,acc_A_R:17.47,acc_D_R:37.00,replay_s:-1,lr:0.
# al] episode:3,avg_a_R:0.00,avg_d_R:0.25,avg_t:3.25,avg_h:0.25,acc_A_R:20.47,acc_D_R:35.00,replay_s:-1,lr:0.0
# al] episode:4,avg_a_R:0.54,avg_d_R:-0.20,avg_t:4.40,avg_h:0.40,acc_A_R:23.17,acc_D_R:33.00,replay_s:-1,lr:0.
# al] episode:5,avg_a_R:0.28,avg_d_R:0.00,avg_t:4.33,avg_h:0.33,acc_A_R:22.17,acc_D_R:34.00,replay_s:-1,lr:0.0
# al] episode:6,avg_a_R:0.10,avg_d_R:0.14,avg_t:3.86,avg_h:0.29,acc_A_R:21.17,acc_D_R:35.00,replay_s:-1,lr:0.0
# al] episode:7,avg_a_R:-0.04,avg_d_R:0.25,avg_t:3.50,avg_h:0.25,acc_A_R:20.17,acc_D_R:36.00,replay_s:-1,lr:0.
# al] episode:8,avg_a_R:-0.14,avg_d_R:0.33,avg_t:3.22,avg_h:0.22,acc_A_R:19.17,acc_D_R:37.00,replay_s:-1,lr:0.
# al] episode:9,avg_a_R:-0.23,avg_d_R:0.40,avg_t:3.20,avg_h:0.20,acc_A_R:18.17,acc_D_R:38.00,replay_s:-1,lr:0.
# al] episode:10,avg_a_R:-0.30,avg_d_R:0.45,avg_t:3.09,avg_h:0.18,acc_A_R:17.17,acc_D_R:39.00,replay_s:-1,lr:0
# al] episode:11,avg_a_R:-0.36,avg_d_R:0.50,avg_t:3.00,avg_h:0.17,acc_A_R:16.17,acc_D_R:40.00,replay_s:-1,lr:0
# al] episode:12,avg_a_R:-0.41,avg_d_R:0.54,avg_t:2.92,avg_h:0.15,acc_A_R:15.17,acc_D_R:41.00,replay_s:-1,lr:0
# al] episode:13,avg_a_R:-0.45,avg_d_R:0.57,avg_t:2.86,avg_h:0.14,acc_A_R:14.17,acc_D_R:42.00,replay_s:-1,lr:0
# al] episode:14,avg_a_R:-0.49,avg_d_R:0.60,avg_t:2.73,avg_h:0.13,acc_A_R:13.17,acc_D_R:43.00,replay_s:-1,lr:0
# al] episode:15,avg_a_R:-0.52,avg_d_R:0.62,avg_t:2.75,avg_h:0.12,acc_A_R:12.17,acc_D_R:44.00,replay_s:-1,lr:0
# al] episode:16,avg_a_R:-0.55,avg_d_R:0.65,avg_t:2.65,avg_h:0.12,acc_A_R:11.17,acc_D_R:45.00,replay_s:-1,lr:0
# al] episode:17,avg_a_R:-0.57,avg_d_R:0.67,avg_t:2.67,avg_h:0.11,acc_A_R:10.17,acc_D_R:46.00,replay_s:-1,lr:0
# al] episode:18,avg_a_R:-0.59,avg_d_R:0.68,avg_t:2.79,avg_h:0.11,acc_A_R:9.17,acc_D_R:47.00,replay_s:-1,lr:0.
# al] episode:19,avg_a_R:-0.61,avg_d_R:0.70,avg_t:2.85,avg_h:0.10,acc_A_R:8.17,acc_D_R:48.00,replay_s:-1,lr:0.
# al] episode:20,avg_a_R:-0.63,avg_d_R:0.71,avg_t:2.86,avg_h:0.10,acc_A_R:7.17,acc_D_R:49.00,replay_s:-1,lr:0.
# al] episode:21,avg_a_R:-0.65,avg_d_R:0.73,avg_t:2.86,avg_h:0.09,acc_A_R:6.17,acc_D_R:50.00,replay_s:-1,lr:0.
# al] episode:22,avg_a_R:-0.67,avg_d_R:0.74,avg_t:2.83,avg_h:0.09,acc_A_R:5.17,acc_D_R:51.00,replay_s:-1,lr:0.
# al] episode:23,avg_a_R:-0.60,avg_d_R:0.75,avg_t:2.83,avg_h:0.08,acc_A_R:6.17,acc_D_R:52.00,replay_s:-1,lr:0.
# al] episode:24,avg_a_R:-0.61,avg_d_R:0.76,avg_t:2.84,avg_h:0.08,acc_A_R:5.17,acc_D_R:53.00,replay_s:-1,lr:0.
# al] episode:25,avg_a_R:-0.63,avg_d_R:0.77,avg_t:2.77,avg_h:0.08,acc_A_R:4.17,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:26,avg_a_R:-0.64,avg_d_R:0.78,avg_t:2.78,avg_h:0.07,acc_A_R:3.17,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:27,avg_a_R:-0.49,avg_d_R:0.68,avg_t:2.86,avg_h:0.11,acc_A_R:6.67,acc_D_R:53.00,replay_s:-1,lr:0.
# al] episode:28,avg_a_R:-0.51,avg_d_R:0.69,avg_t:2.79,avg_h:0.10,acc_A_R:5.67,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:29,avg_a_R:-0.53,avg_d_R:0.70,avg_t:2.73,avg_h:0.10,acc_A_R:4.67,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:30,avg_a_R:-0.54,avg_d_R:0.71,avg_t:2.71,avg_h:0.10,acc_A_R:3.67,acc_D_R:56.00,replay_s:-1,lr:0.
# al] episode:31,avg_a_R:-0.56,avg_d_R:0.72,avg_t:2.69,avg_h:0.09,acc_A_R:2.67,acc_D_R:57.00,replay_s:-1,lr:0.
# al] episode:32,avg_a_R:-0.57,avg_d_R:0.73,avg_t:2.67,avg_h:0.09,acc_A_R:1.67,acc_D_R:58.00,replay_s:-1,lr:0.
# al] episode:33,avg_a_R:-0.52,avg_d_R:0.74,avg_t:2.76,avg_h:0.09,acc_A_R:2.67,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:34,avg_a_R:-0.54,avg_d_R:0.74,avg_t:2.74,avg_h:0.09,acc_A_R:1.67,acc_D_R:60.00,replay_s:-1,lr:0.
# al] episode:35,avg_a_R:-0.49,avg_d_R:0.75,avg_t:2.72,avg_h:0.08,acc_A_R:2.67,acc_D_R:61.00,replay_s:-1,lr:0.
# al] episode:36,avg_a_R:-0.51,avg_d_R:0.76,avg_t:2.68,avg_h:0.08,acc_A_R:1.67,acc_D_R:62.00,replay_s:-1,lr:0.
# al] episode:37,avg_a_R:-0.47,avg_d_R:0.76,avg_t:2.68,avg_h:0.08,acc_A_R:2.67,acc_D_R:63.00,replay_s:-1,lr:0.
# al] episode:38,avg_a_R:-0.43,avg_d_R:0.77,avg_t:2.72,avg_h:0.08,acc_A_R:3.67,acc_D_R:64.00,replay_s:-1,lr:0.
# al] episode:38,avg_a_R:-0.43,avg_d_R:0.77,avg_t:2.72,avg_h:0.08,acc_A_R:3.67,acc_D_R:64.00,replay_s:-1,lr:0.
# al] episode:39,avg_a_R:-0.45,avg_d_R:0.78,avg_t:2.73,avg_h:0.07,acc_A_R:2.67,acc_D_R:65.00,replay_s:-1,lr:0.
# al] episode:40,avg_a_R:-0.46,avg_d_R:0.78,avg_t:2.78,avg_h:0.07,acc_A_R:1.67,acc_D_R:66.00,replay_s:-1,lr:0.
# al] episode:41,avg_a_R:-0.42,avg_d_R:0.79,avg_t:2.79,avg_h:0.07,acc_A_R:2.67,acc_D_R:67.00,replay_s:-1,lr:0.
# al] episode:42,avg_a_R:-0.44,avg_d_R:0.79,avg_t:2.77,avg_h:0.07,acc_A_R:1.67,acc_D_R:68.00,replay_s:-1,lr:0.
# al] episode:43,avg_a_R:-0.45,avg_d_R:0.80,avg_t:2.75,avg_h:0.07,acc_A_R:0.67,acc_D_R:69.00,replay_s:-1,lr:0.
# al] episode:44,avg_a_R:-0.46,avg_d_R:0.80,avg_t:2.73,avg_h:0.07,acc_A_R:-0.33,acc_D_R:70.00,replay_s:-1,lr:0
# al] episode:45,avg_a_R:-0.47,avg_d_R:0.80,avg_t:2.70,avg_h:0.07,acc_A_R:-1.33,acc_D_R:71.00,replay_s:-1,lr:0
# al] episode:46,avg_a_R:-0.49,avg_d_R:0.81,avg_t:2.72,avg_h:0.06,acc_A_R:-2.33,acc_D_R:72.00,replay_s:-1,lr:0
# al] episode:47,avg_a_R:-0.41,avg_d_R:0.75,avg_t:2.81,avg_h:0.08,acc_A_R:0.87,acc_D_R:70.00,replay_s:-1,lr:0.
# al] episode:48,avg_a_R:-0.42,avg_d_R:0.76,avg_t:2.78,avg_h:0.08,acc_A_R:-0.13,acc_D_R:71.00,replay_s:-1,lr:0
# al] episode:49,avg_a_R:-0.43,avg_d_R:0.76,avg_t:2.76,avg_h:0.08,acc_A_R:-1.13,acc_D_R:72.00,replay_s:-1,lr:0
# al] episode:50,avg_a_R:-0.44,avg_d_R:0.76,avg_t:2.76,avg_h:0.08,acc_A_R:-2.13,acc_D_R:73.00,replay_s:-1,lr:0
# al] episode:51,avg_a_R:-0.45,avg_d_R:0.77,avg_t:2.73,avg_h:0.08,acc_A_R:-3.13,acc_D_R:74.00,replay_s:-1,lr:0
# al] episode:52,avg_a_R:-0.43,avg_d_R:0.77,avg_t:2.75,avg_h:0.08,acc_A_R:-2.13,acc_D_R:75.00,replay_s:-1,lr:0
# al] episode:53,avg_a_R:-0.41,avg_d_R:0.78,avg_t:2.78,avg_h:0.07,acc_A_R:-1.63,acc_D_R:76.00,replay_s:-1,lr:0
# al] episode:54,avg_a_R:-0.38,avg_d_R:0.78,avg_t:2.82,avg_h:0.07,acc_A_R:-0.63,acc_D_R:77.00,replay_s:-1,lr:0
# al] episode:55,avg_a_R:-0.39,avg_d_R:0.79,avg_t:2.79,avg_h:0.07,acc_A_R:-1.63,acc_D_R:78.00,replay_s:-1,lr:0
# al] episode:56,avg_a_R:-0.41,avg_d_R:0.79,avg_t:2.79,avg_h:0.07,acc_A_R:-2.63,acc_D_R:79.00,replay_s:-1,lr:0
# al] episode:57,avg_a_R:-0.42,avg_d_R:0.79,avg_t:2.76,avg_h:0.07,acc_A_R:-3.63,acc_D_R:80.00,replay_s:-1,lr:0
# al] episode:58,avg_a_R:-0.43,avg_d_R:0.80,avg_t:2.75,avg_h:0.07,acc_A_R:-4.63,acc_D_R:81.00,replay_s:-1,lr:0
# al] episode:59,avg_a_R:-0.43,avg_d_R:0.80,avg_t:2.73,avg_h:0.07,acc_A_R:-5.63,acc_D_R:82.00,replay_s:-1,lr:0
# al] episode:60,avg_a_R:-0.44,avg_d_R:0.80,avg_t:2.72,avg_h:0.07,acc_A_R:-6.63,acc_D_R:83.00,replay_s:-1,lr:0
# al] episode:61,avg_a_R:-0.45,avg_d_R:0.81,avg_t:2.69,avg_h:0.06,acc_A_R:-7.63,acc_D_R:84.00,replay_s:-1,lr:0
# al] episode:62,avg_a_R:-0.46,avg_d_R:0.81,avg_t:2.67,avg_h:0.06,acc_A_R:-8.63,acc_D_R:85.00,replay_s:-1,lr:0
# al] episode:63,avg_a_R:-0.47,avg_d_R:0.81,avg_t:2.66,avg_h:0.06,acc_A_R:-9.63,acc_D_R:86.00,replay_s:-1,lr:0
# al] episode:64,avg_a_R:-0.45,avg_d_R:0.82,avg_t:2.66,avg_h:0.06,acc_A_R:-8.63,acc_D_R:87.00,replay_s:-1,lr:0
# al] episode:65,avg_a_R:-0.46,avg_d_R:0.82,avg_t:2.67,avg_h:0.06,acc_A_R:-9.63,acc_D_R:88.00,replay_s:-1,lr:0
# al] episode:66,avg_a_R:-0.46,avg_d_R:0.82,avg_t:2.64,avg_h:0.06,acc_A_R:-10.63,acc_D_R:89.00,replay_s:-1,lr:
# al] episode:67,avg_a_R:-0.47,avg_d_R:0.82,avg_t:2.62,avg_h:0.06,acc_A_R:-11.63,acc_D_R:90.00,replay_s:-1,lr:
# al] episode:68,avg_a_R:-0.48,avg_d_R:0.83,avg_t:2.59,avg_h:0.06,acc_A_R:-12.63,acc_D_R:91.00,replay_s:-1,lr:
# al] episode:69,avg_a_R:-0.49,avg_d_R:0.83,avg_t:2.60,avg_h:0.06,acc_A_R:-13.63,acc_D_R:92.00,replay_s:-1,lr:
# al] episode:70,avg_a_R:-0.47,avg_d_R:0.83,avg_t:2.61,avg_h:0.06,acc_A_R:-12.63,acc_D_R:93.00,replay_s:-1,lr:
# al] episode:71,avg_a_R:-0.47,avg_d_R:0.83,avg_t:2.58,avg_h:0.06,acc_A_R:-13.63,acc_D_R:94.00,replay_s:-1,lr:
# al] episode:72,avg_a_R:-0.41,avg_d_R:0.79,avg_t:2.58,avg_h:0.07,acc_A_R:-9.63,acc_D_R:92.00,replay_s:-1,lr:0
# al] episode:73,avg_a_R:-0.42,avg_d_R:0.80,avg_t:2.58,avg_h:0.07,acc_A_R:-10.63,acc_D_R:93.00,replay_s:-1,lr:
# al] episode:74,avg_a_R:-0.43,avg_d_R:0.80,avg_t:2.59,avg_h:0.07,acc_A_R:-11.63,acc_D_R:94.00,replay_s:-1,lr:
# al] episode:75,avg_a_R:-0.44,avg_d_R:0.80,avg_t:2.59,avg_h:0.07,acc_A_R:-12.63,acc_D_R:95.00,replay_s:-1,lr:
# al] episode:76,avg_a_R:-0.44,avg_d_R:0.81,avg_t:2.60,avg_h:0.06,acc_A_R:-13.63,acc_D_R:96.00,replay_s:-1,lr:
# al] episode:77,avg_a_R:-0.45,avg_d_R:0.81,avg_t:2.59,avg_h:0.06,acc_A_R:-14.63,acc_D_R:97.00,replay_s:-1,lr:
# al] episode:77,avg_a_R:-0.45,avg_d_R:0.81,avg_t:2.59,avg_h:0.06,acc_A_R:-14.63,acc_D_R:97.00,replay_s:-1,lr:
# al] episode:78,avg_a_R:-0.46,avg_d_R:0.81,avg_t:2.58,avg_h:0.06,acc_A_R:-15.63,acc_D_R:98.00,replay_s:-1,lr:
# al] episode:79,avg_a_R:-0.46,avg_d_R:0.81,avg_t:2.58,avg_h:0.06,acc_A_R:-16.63,acc_D_R:99.00,replay_s:-1,lr:
# al] episode:80,avg_a_R:-0.45,avg_d_R:0.81,avg_t:2.69,avg_h:0.06,acc_A_R:-16.13,acc_D_R:100.00,replay_s:-1,lr
# al] episode:81,avg_a_R:-0.46,avg_d_R:0.82,avg_t:2.72,avg_h:0.06,acc_A_R:-17.13,acc_D_R:101.00,replay_s:-1,lr
# al] episode:82,avg_a_R:-0.47,avg_d_R:0.82,avg_t:2.75,avg_h:0.06,acc_A_R:-18.13,acc_D_R:102.00,replay_s:-1,lr
# al] episode:83,avg_a_R:-0.47,avg_d_R:0.82,avg_t:2.74,avg_h:0.06,acc_A_R:-19.13,acc_D_R:103.00,replay_s:-1,lr
# al] episode:84,avg_a_R:-0.48,avg_d_R:0.82,avg_t:2.73,avg_h:0.06,acc_A_R:-20.13,acc_D_R:104.00,replay_s:-1,lr
# al] episode:85,avg_a_R:-0.48,avg_d_R:0.83,avg_t:2.72,avg_h:0.06,acc_A_R:-21.13,acc_D_R:105.00,replay_s:-1,lr
# al] episode:86,avg_a_R:-0.49,avg_d_R:0.83,avg_t:2.74,avg_h:0.06,acc_A_R:-22.13,acc_D_R:106.00,replay_s:-1,lr
# al] episode:87,avg_a_R:-0.50,avg_d_R:0.83,avg_t:2.72,avg_h:0.06,acc_A_R:-23.13,acc_D_R:107.00,replay_s:-1,lr
# al] episode:88,avg_a_R:-0.50,avg_d_R:0.83,avg_t:2.73,avg_h:0.06,acc_A_R:-24.13,acc_D_R:108.00,replay_s:-1,lr
# al] episode:89,avg_a_R:-0.51,avg_d_R:0.83,avg_t:2.73,avg_h:0.06,acc_A_R:-25.13,acc_D_R:109.00,replay_s:-1,lr
# al] episode:90,avg_a_R:-0.51,avg_d_R:0.84,avg_t:2.71,avg_h:0.05,acc_A_R:-26.13,acc_D_R:110.00,replay_s:-1,lr
# al] episode:91,avg_a_R:-0.52,avg_d_R:0.84,avg_t:2.72,avg_h:0.05,acc_A_R:-27.13,acc_D_R:111.00,replay_s:-1,lr
# al] episode:92,avg_a_R:-0.52,avg_d_R:0.84,avg_t:2.72,avg_h:0.05,acc_A_R:-28.13,acc_D_R:112.00,replay_s:-1,lr
# al] episode:93,avg_a_R:-0.53,avg_d_R:0.84,avg_t:2.72,avg_h:0.05,acc_A_R:-29.13,acc_D_R:113.00,replay_s:-1,lr
# al] episode:94,avg_a_R:-0.53,avg_d_R:0.84,avg_t:2.71,avg_h:0.05,acc_A_R:-30.13,acc_D_R:114.00,replay_s:-1,lr
# al] episode:95,avg_a_R:-0.54,avg_d_R:0.84,avg_t:2.73,avg_h:0.05,acc_A_R:-31.13,acc_D_R:115.00,replay_s:-1,lr
# al] episode:96,avg_a_R:-0.54,avg_d_R:0.85,avg_t:2.74,avg_h:0.05,acc_A_R:-32.13,acc_D_R:116.00,replay_s:-1,lr
# al] episode:97,avg_a_R:-0.50,avg_d_R:0.82,avg_t:2.76,avg_h:0.06,acc_A_R:-28.63,acc_D_R:114.00,replay_s:-1,lr
# al] episode:98,avg_a_R:-0.51,avg_d_R:0.82,avg_t:2.76,avg_h:0.06,acc_A_R:-29.63,acc_D_R:115.00,replay_s:-1,lr
# al] episode:99,avg_a_R:-0.51,avg_d_R:0.82,avg_t:2.78,avg_h:0.06,acc_A_R:-30.63,acc_D_R:116.00,replay_s:-1,lr
# starting eval with non-empty result objecta_R:-0.23,avg_d_R:0.76,avg_t:4.48,avg_h:0.08,acc_A_R:-314.10,acc_D_R:
#
# [Eval] episode:1000,avg_a_R:-0.51,avg_d_R:0.82,avg_t:2.78,avg_h:0.06,acc_A_R:-30.63,acc_D_R:116.00,replay_s:-1,
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:-31.63,acc_D_R:117.00,replay_s:-1,lr:
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:4.00,avg_h:0.00,acc_A_R:-32.63,acc_D_R:118.00,replay_s:-1,lr:
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:4.00,avg_h:0.00,acc_A_R:-33.63,acc_D_R:119.00,replay_s:-1,lr:
# al] episode:3,avg_a_R:-0.50,avg_d_R:1.00,avg_t:4.50,avg_h:0.00,acc_A_R:-32.63,acc_D_R:120.00,replay_s:-1,lr:
# al] episode:4,avg_a_R:-0.60,avg_d_R:1.00,avg_t:4.00,avg_h:0.00,acc_A_R:-33.63,acc_D_R:121.00,replay_s:-1,lr:
# al] episode:5,avg_a_R:-0.67,avg_d_R:1.00,avg_t:3.83,avg_h:0.00,acc_A_R:-34.63,acc_D_R:122.00,replay_s:-1,lr:
# al] episode:6,avg_a_R:-0.71,avg_d_R:1.00,avg_t:3.86,avg_h:0.00,acc_A_R:-35.63,acc_D_R:123.00,replay_s:-1,lr:
# al] episode:7,avg_a_R:-0.75,avg_d_R:1.00,avg_t:3.50,avg_h:0.00,acc_A_R:-36.63,acc_D_R:124.00,replay_s:-1,lr:
# al] episode:8,avg_a_R:-0.78,avg_d_R:1.00,avg_t:3.44,avg_h:0.00,acc_A_R:-37.63,acc_D_R:125.00,replay_s:-1,lr:
# al] episode:9,avg_a_R:-0.80,avg_d_R:1.00,avg_t:3.30,avg_h:0.00,acc_A_R:-38.63,acc_D_R:126.00,replay_s:-1,lr:
# al] episode:10,avg_a_R:-0.82,avg_d_R:1.00,avg_t:3.09,avg_h:0.00,acc_A_R:-39.63,acc_D_R:127.00,replay_s:-1,lr
# al] episode:11,avg_a_R:-0.67,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:-38.63,acc_D_R:128.00,replay_s:-1,lr
# al] episode:12,avg_a_R:-0.69,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:-39.63,acc_D_R:129.00,replay_s:-1,lr
# al] episode:13,avg_a_R:-0.36,avg_d_R:0.79,avg_t:3.00,avg_h:0.07,acc_A_R:-35.63,acc_D_R:127.00,replay_s:-1,lr
# al] episode:14,avg_a_R:-0.40,avg_d_R:0.80,avg_t:2.93,avg_h:0.07,acc_A_R:-36.63,acc_D_R:128.00,replay_s:-1,lr
# al] episode:15,avg_a_R:-0.44,avg_d_R:0.81,avg_t:2.94,avg_h:0.06,acc_A_R:-37.63,acc_D_R:129.00,replay_s:-1,lr
# al] episode:16,avg_a_R:-0.47,avg_d_R:0.82,avg_t:2.94,avg_h:0.06,acc_A_R:-38.63,acc_D_R:130.00,replay_s:-1,lr
# al] episode:17,avg_a_R:-0.50,avg_d_R:0.83,avg_t:3.00,avg_h:0.06,acc_A_R:-39.63,acc_D_R:131.00,replay_s:-1,lr
# al] episode:18,avg_a_R:-0.53,avg_d_R:0.84,avg_t:2.95,avg_h:0.05,acc_A_R:-40.63,acc_D_R:132.00,replay_s:-1,lr
# al] episode:19,avg_a_R:-0.45,avg_d_R:0.85,avg_t:2.95,avg_h:0.05,acc_A_R:-39.63,acc_D_R:133.00,replay_s:-1,lr
# al] episode:20,avg_a_R:-0.48,avg_d_R:0.86,avg_t:2.95,avg_h:0.05,acc_A_R:-40.63,acc_D_R:134.00,replay_s:-1,lr
# al] episode:21,avg_a_R:-0.44,avg_d_R:0.86,avg_t:3.18,avg_h:0.05,acc_A_R:-40.29,acc_D_R:135.00,replay_s:-1,lr
# al] episode:22,avg_a_R:-0.46,avg_d_R:0.87,avg_t:3.17,avg_h:0.04,acc_A_R:-41.29,acc_D_R:136.00,replay_s:-1,lr
# al] episode:23,avg_a_R:-0.49,avg_d_R:0.88,avg_t:3.08,avg_h:0.04,acc_A_R:-42.29,acc_D_R:137.00,replay_s:-1,lr
# al] episode:24,avg_a_R:-0.51,avg_d_R:0.88,avg_t:3.08,avg_h:0.04,acc_A_R:-43.29,acc_D_R:138.00,replay_s:-1,lr
# al] episode:25,avg_a_R:-0.53,avg_d_R:0.88,avg_t:3.08,avg_h:0.04,acc_A_R:-44.29,acc_D_R:139.00,replay_s:-1,lr
# al] episode:26,avg_a_R:-0.54,avg_d_R:0.89,avg_t:3.07,avg_h:0.04,acc_A_R:-45.29,acc_D_R:140.00,replay_s:-1,lr
# al] episode:27,avg_a_R:-0.56,avg_d_R:0.89,avg_t:3.00,avg_h:0.04,acc_A_R:-46.29,acc_D_R:141.00,replay_s:-1,lr
# al] episode:28,avg_a_R:-0.57,avg_d_R:0.90,avg_t:2.93,avg_h:0.03,acc_A_R:-47.29,acc_D_R:142.00,replay_s:-1,lr
# al] episode:29,avg_a_R:-0.59,avg_d_R:0.90,avg_t:2.87,avg_h:0.03,acc_A_R:-48.29,acc_D_R:143.00,replay_s:-1,lr
# al] episode:30,avg_a_R:-0.60,avg_d_R:0.90,avg_t:2.84,avg_h:0.03,acc_A_R:-49.29,acc_D_R:144.00,replay_s:-1,lr
# al] episode:31,avg_a_R:-0.55,avg_d_R:0.91,avg_t:2.84,avg_h:0.03,acc_A_R:-48.29,acc_D_R:145.00,replay_s:-1,lr
# al] episode:32,avg_a_R:-0.57,avg_d_R:0.91,avg_t:2.82,avg_h:0.03,acc_A_R:-49.29,acc_D_R:146.00,replay_s:-1,lr
# al] episode:33,avg_a_R:-0.53,avg_d_R:0.91,avg_t:2.85,avg_h:0.03,acc_A_R:-48.79,acc_D_R:147.00,replay_s:-1,lr
# al] episode:34,avg_a_R:-0.49,avg_d_R:0.91,avg_t:3.03,avg_h:0.03,acc_A_R:-47.79,acc_D_R:148.00,replay_s:-1,lr
# al] episode:35,avg_a_R:-0.50,avg_d_R:0.92,avg_t:3.00,avg_h:0.03,acc_A_R:-48.79,acc_D_R:149.00,replay_s:-1,lr
# al] episode:36,avg_a_R:-0.52,avg_d_R:0.92,avg_t:2.97,avg_h:0.03,acc_A_R:-49.79,acc_D_R:150.00,replay_s:-1,lr
# al] episode:37,avg_a_R:-0.48,avg_d_R:0.92,avg_t:3.05,avg_h:0.03,acc_A_R:-48.79,acc_D_R:151.00,replay_s:-1,lr
# al] episode:38,avg_a_R:-0.49,avg_d_R:0.92,avg_t:3.00,avg_h:0.03,acc_A_R:-49.79,acc_D_R:152.00,replay_s:-1,lr
# al] episode:39,avg_a_R:-0.50,avg_d_R:0.93,avg_t:2.98,avg_h:0.03,acc_A_R:-50.79,acc_D_R:153.00,replay_s:-1,lr
# al] episode:40,avg_a_R:-0.52,avg_d_R:0.93,avg_t:2.95,avg_h:0.02,acc_A_R:-51.79,acc_D_R:154.00,replay_s:-1,lr
# al] episode:41,avg_a_R:-0.53,avg_d_R:0.93,avg_t:2.93,avg_h:0.02,acc_A_R:-52.79,acc_D_R:155.00,replay_s:-1,lr
# al] episode:42,avg_a_R:-0.54,avg_d_R:0.93,avg_t:2.93,avg_h:0.02,acc_A_R:-53.79,acc_D_R:156.00,replay_s:-1,lr
# al] episode:42,avg_a_R:-0.54,avg_d_R:0.93,avg_t:2.93,avg_h:0.02,acc_A_R:-53.79,acc_D_R:156.00,replay_s:-1,lr
# al] episode:43,avg_a_R:-0.55,avg_d_R:0.93,avg_t:2.91,avg_h:0.02,acc_A_R:-54.79,acc_D_R:157.00,replay_s:-1,lr
# al] episode:44,avg_a_R:-0.51,avg_d_R:0.93,avg_t:2.89,avg_h:0.02,acc_A_R:-53.79,acc_D_R:158.00,replay_s:-1,lr
# al] episode:45,avg_a_R:-0.53,avg_d_R:0.93,avg_t:2.89,avg_h:0.02,acc_A_R:-54.79,acc_D_R:159.00,replay_s:-1,lr
# al] episode:46,avg_a_R:-0.54,avg_d_R:0.94,avg_t:2.85,avg_h:0.02,acc_A_R:-55.79,acc_D_R:160.00,replay_s:-1,lr
# al] episode:47,avg_a_R:-0.50,avg_d_R:0.94,avg_t:2.85,avg_h:0.02,acc_A_R:-54.79,acc_D_R:161.00,replay_s:-1,lr
# al] episode:48,avg_a_R:-0.51,avg_d_R:0.94,avg_t:2.84,avg_h:0.02,acc_A_R:-55.79,acc_D_R:162.00,replay_s:-1,lr
# al] episode:49,avg_a_R:-0.52,avg_d_R:0.94,avg_t:2.82,avg_h:0.02,acc_A_R:-56.79,acc_D_R:163.00,replay_s:-1,lr
# al] episode:50,avg_a_R:-0.53,avg_d_R:0.94,avg_t:2.80,avg_h:0.02,acc_A_R:-57.79,acc_D_R:164.00,replay_s:-1,lr
# al] episode:51,avg_a_R:-0.52,avg_d_R:0.94,avg_t:2.87,avg_h:0.02,acc_A_R:-57.46,acc_D_R:165.00,replay_s:-1,lr
# al] episode:52,avg_a_R:-0.53,avg_d_R:0.94,avg_t:2.89,avg_h:0.02,acc_A_R:-58.46,acc_D_R:166.00,replay_s:-1,lr
# al] episode:53,avg_a_R:-0.53,avg_d_R:0.94,avg_t:2.85,avg_h:0.02,acc_A_R:-59.46,acc_D_R:167.00,replay_s:-1,lr
# al] episode:54,avg_a_R:-0.54,avg_d_R:0.95,avg_t:2.87,avg_h:0.02,acc_A_R:-60.46,acc_D_R:168.00,replay_s:-1,lr
# al] episode:55,avg_a_R:-0.55,avg_d_R:0.95,avg_t:2.84,avg_h:0.02,acc_A_R:-61.46,acc_D_R:169.00,replay_s:-1,lr
# al] episode:56,avg_a_R:-0.48,avg_d_R:0.89,avg_t:2.86,avg_h:0.04,acc_A_R:-57.96,acc_D_R:167.00,replay_s:-1,lr
# al] episode:57,avg_a_R:-0.49,avg_d_R:0.90,avg_t:2.84,avg_h:0.03,acc_A_R:-58.96,acc_D_R:168.00,replay_s:-1,lr
# al] episode:58,avg_a_R:-0.50,avg_d_R:0.90,avg_t:2.81,avg_h:0.03,acc_A_R:-59.96,acc_D_R:169.00,replay_s:-1,lr
# al] episode:59,avg_a_R:-0.51,avg_d_R:0.90,avg_t:2.82,avg_h:0.03,acc_A_R:-60.96,acc_D_R:170.00,replay_s:-1,lr
# al] episode:60,avg_a_R:-0.44,avg_d_R:0.85,avg_t:2.84,avg_h:0.05,acc_A_R:-57.46,acc_D_R:168.00,replay_s:-1,lr
# al] episode:61,avg_a_R:-0.45,avg_d_R:0.85,avg_t:2.82,avg_h:0.05,acc_A_R:-58.46,acc_D_R:169.00,replay_s:-1,lr
# al] episode:62,avg_a_R:-0.46,avg_d_R:0.86,avg_t:2.83,avg_h:0.05,acc_A_R:-59.46,acc_D_R:170.00,replay_s:-1,lr
# al] episode:63,avg_a_R:-0.43,avg_d_R:0.86,avg_t:2.83,avg_h:0.05,acc_A_R:-58.46,acc_D_R:171.00,replay_s:-1,lr
# al] episode:64,avg_a_R:-0.44,avg_d_R:0.86,avg_t:2.83,avg_h:0.05,acc_A_R:-59.46,acc_D_R:172.00,replay_s:-1,lr
# al] episode:65,avg_a_R:-0.45,avg_d_R:0.86,avg_t:2.80,avg_h:0.05,acc_A_R:-60.46,acc_D_R:173.00,replay_s:-1,lr
# al] episode:66,avg_a_R:-0.46,avg_d_R:0.87,avg_t:2.79,avg_h:0.04,acc_A_R:-61.46,acc_D_R:174.00,replay_s:-1,lr
# al] episode:67,avg_a_R:-0.47,avg_d_R:0.87,avg_t:2.78,avg_h:0.04,acc_A_R:-62.46,acc_D_R:175.00,replay_s:-1,lr
# al] episode:68,avg_a_R:-0.48,avg_d_R:0.87,avg_t:2.77,avg_h:0.04,acc_A_R:-63.46,acc_D_R:176.00,replay_s:-1,lr
# al] episode:69,avg_a_R:-0.45,avg_d_R:0.87,avg_t:2.80,avg_h:0.04,acc_A_R:-62.46,acc_D_R:177.00,replay_s:-1,lr
# al] episode:70,avg_a_R:-0.46,avg_d_R:0.87,avg_t:2.79,avg_h:0.04,acc_A_R:-63.46,acc_D_R:178.00,replay_s:-1,lr
# al] episode:71,avg_a_R:-0.47,avg_d_R:0.88,avg_t:2.78,avg_h:0.04,acc_A_R:-64.46,acc_D_R:179.00,replay_s:-1,lr
# al] episode:72,avg_a_R:-0.48,avg_d_R:0.88,avg_t:2.77,avg_h:0.04,acc_A_R:-65.46,acc_D_R:180.00,replay_s:-1,lr
# al] episode:73,avg_a_R:-0.48,avg_d_R:0.88,avg_t:2.77,avg_h:0.04,acc_A_R:-66.46,acc_D_R:181.00,replay_s:-1,lr
# al] episode:74,avg_a_R:-0.49,avg_d_R:0.88,avg_t:2.75,avg_h:0.04,acc_A_R:-67.46,acc_D_R:182.00,replay_s:-1,lr
# al] episode:75,avg_a_R:-0.50,avg_d_R:0.88,avg_t:2.74,avg_h:0.04,acc_A_R:-68.46,acc_D_R:183.00,replay_s:-1,lr
# al] episode:76,avg_a_R:-0.50,avg_d_R:0.88,avg_t:2.73,avg_h:0.04,acc_A_R:-69.46,acc_D_R:184.00,replay_s:-1,lr
# al] episode:77,avg_a_R:-0.51,avg_d_R:0.88,avg_t:2.71,avg_h:0.04,acc_A_R:-70.46,acc_D_R:185.00,replay_s:-1,lr
# al] episode:78,avg_a_R:-0.45,avg_d_R:0.85,avg_t:2.71,avg_h:0.05,acc_A_R:-66.46,acc_D_R:183.00,replay_s:-1,lr
# al] episode:79,avg_a_R:-0.46,avg_d_R:0.85,avg_t:2.70,avg_h:0.05,acc_A_R:-67.46,acc_D_R:184.00,replay_s:-1,lr
# al] episode:80,avg_a_R:-0.45,avg_d_R:0.85,avg_t:2.73,avg_h:0.05,acc_A_R:-67.13,acc_D_R:185.00,replay_s:-1,lr
# al] episode:81,avg_a_R:-0.46,avg_d_R:0.85,avg_t:2.71,avg_h:0.05,acc_A_R:-68.13,acc_D_R:186.00,replay_s:-1,lr
# al] episode:82,avg_a_R:-0.46,avg_d_R:0.86,avg_t:2.71,avg_h:0.05,acc_A_R:-69.13,acc_D_R:187.00,replay_s:-1,lr
# al] episode:83,avg_a_R:-0.45,avg_d_R:0.86,avg_t:2.70,avg_h:0.05,acc_A_R:-68.13,acc_D_R:188.00,replay_s:-1,lr
# al] episode:84,avg_a_R:-0.45,avg_d_R:0.86,avg_t:2.68,avg_h:0.05,acc_A_R:-69.13,acc_D_R:189.00,replay_s:-1,lr
# al] episode:85,avg_a_R:-0.44,avg_d_R:0.86,avg_t:2.73,avg_h:0.05,acc_A_R:-68.13,acc_D_R:190.00,replay_s:-1,lr
# al] episode:85,avg_a_R:-0.44,avg_d_R:0.86,avg_t:2.73,avg_h:0.05,acc_A_R:-68.13,acc_D_R:190.00,replay_s:-1,lr
# al] episode:86,avg_a_R:-0.42,avg_d_R:0.86,avg_t:2.75,avg_h:0.05,acc_A_R:-67.13,acc_D_R:191.00,replay_s:-1,lr
# al] episode:87,avg_a_R:-0.43,avg_d_R:0.86,avg_t:2.74,avg_h:0.05,acc_A_R:-68.13,acc_D_R:192.00,replay_s:-1,lr
# al] episode:88,avg_a_R:-0.43,avg_d_R:0.87,avg_t:2.78,avg_h:0.04,acc_A_R:-69.13,acc_D_R:193.00,replay_s:-1,lr
# al] episode:89,avg_a_R:-0.44,avg_d_R:0.87,avg_t:2.77,avg_h:0.04,acc_A_R:-70.13,acc_D_R:194.00,replay_s:-1,lr
# al] episode:90,avg_a_R:-0.45,avg_d_R:0.87,avg_t:2.77,avg_h:0.04,acc_A_R:-71.13,acc_D_R:195.00,replay_s:-1,lr
# al] episode:91,avg_a_R:-0.45,avg_d_R:0.87,avg_t:2.75,avg_h:0.04,acc_A_R:-72.13,acc_D_R:196.00,replay_s:-1,lr
# al] episode:92,avg_a_R:-0.46,avg_d_R:0.87,avg_t:2.74,avg_h:0.04,acc_A_R:-73.13,acc_D_R:197.00,replay_s:-1,lr
# al] episode:93,avg_a_R:-0.46,avg_d_R:0.87,avg_t:2.76,avg_h:0.04,acc_A_R:-74.13,acc_D_R:198.00,replay_s:-1,lr
# al] episode:94,avg_a_R:-0.47,avg_d_R:0.87,avg_t:2.76,avg_h:0.04,acc_A_R:-75.13,acc_D_R:199.00,replay_s:-1,lr
# al] episode:95,avg_a_R:-0.45,avg_d_R:0.88,avg_t:2.77,avg_h:0.04,acc_A_R:-74.13,acc_D_R:200.00,replay_s:-1,lr
# al] episode:96,avg_a_R:-0.46,avg_d_R:0.88,avg_t:2.75,avg_h:0.04,acc_A_R:-75.13,acc_D_R:201.00,replay_s:-1,lr
# al] episode:97,avg_a_R:-0.46,avg_d_R:0.88,avg_t:2.73,avg_h:0.04,acc_A_R:-76.13,acc_D_R:202.00,replay_s:-1,lr
# al] episode:98,avg_a_R:-0.45,avg_d_R:0.88,avg_t:2.76,avg_h:0.04,acc_A_R:-75.63,acc_D_R:203.00,replay_s:-1,lr
# al] episode:99,avg_a_R:-0.46,avg_d_R:0.88,avg_t:2.74,avg_h:0.04,acc_A_R:-76.63,acc_D_R:204.00,replay_s:-1,lr
# starting eval with non-empty result objecta_R:-0.15,avg_d_R:0.73,avg_t:3.61,avg_h:0.09,acc_A_R:-419.08,acc_D_R:
#
# [Eval] episode:2000,avg_a_R:-0.46,avg_d_R:0.88,avg_t:2.74,avg_h:0.04,acc_A_R:-76.63,acc_D_R:204.00,replay_s:-1,
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:1.00,avg_h:0.00,acc_A_R:-77.63,acc_D_R:205.00,replay_s:-1,lr:
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.50,avg_h:0.00,acc_A_R:-78.63,acc_D_R:206.00,replay_s:-1,lr:
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.67,avg_h:0.00,acc_A_R:-79.63,acc_D_R:207.00,replay_s:-1,lr:
# al] episode:3,avg_a_R:-1.00,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:-80.63,acc_D_R:208.00,replay_s:-1,lr:
# al] episode:4,avg_a_R:-1.00,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:-81.63,acc_D_R:209.00,replay_s:-1,lr:
# al] episode:5,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.67,avg_h:0.00,acc_A_R:-82.63,acc_D_R:210.00,replay_s:-1,lr:
# al] episode:6,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.86,avg_h:0.00,acc_A_R:-83.63,acc_D_R:211.00,replay_s:-1,lr:
# al] episode:7,avg_a_R:-0.75,avg_d_R:1.00,avg_t:2.75,avg_h:0.00,acc_A_R:-82.63,acc_D_R:212.00,replay_s:-1,lr:
# al] episode:8,avg_a_R:-0.78,avg_d_R:1.00,avg_t:2.56,avg_h:0.00,acc_A_R:-83.63,acc_D_R:213.00,replay_s:-1,lr:
# al] episode:9,avg_a_R:-0.80,avg_d_R:1.00,avg_t:2.50,avg_h:0.00,acc_A_R:-84.63,acc_D_R:214.00,replay_s:-1,lr:
# al] episode:10,avg_a_R:-0.82,avg_d_R:1.00,avg_t:2.36,avg_h:0.00,acc_A_R:-85.63,acc_D_R:215.00,replay_s:-1,lr
# al] episode:11,avg_a_R:-0.83,avg_d_R:1.00,avg_t:2.25,avg_h:0.00,acc_A_R:-86.63,acc_D_R:216.00,replay_s:-1,lr
# al] episode:12,avg_a_R:-0.85,avg_d_R:1.00,avg_t:2.23,avg_h:0.00,acc_A_R:-87.63,acc_D_R:217.00,replay_s:-1,lr
# al] episode:13,avg_a_R:-0.86,avg_d_R:1.00,avg_t:2.29,avg_h:0.00,acc_A_R:-88.63,acc_D_R:218.00,replay_s:-1,lr
# al] episode:14,avg_a_R:-0.87,avg_d_R:1.00,avg_t:2.27,avg_h:0.00,acc_A_R:-89.63,acc_D_R:219.00,replay_s:-1,lr
# al] episode:15,avg_a_R:-0.88,avg_d_R:1.00,avg_t:2.31,avg_h:0.00,acc_A_R:-90.63,acc_D_R:220.00,replay_s:-1,lr
# al] episode:16,avg_a_R:-0.88,avg_d_R:1.00,avg_t:2.35,avg_h:0.00,acc_A_R:-91.63,acc_D_R:221.00,replay_s:-1,lr
# al] episode:17,avg_a_R:-0.89,avg_d_R:1.00,avg_t:2.39,avg_h:0.00,acc_A_R:-92.63,acc_D_R:222.00,replay_s:-1,lr
# al] episode:18,avg_a_R:-0.68,avg_d_R:0.84,avg_t:2.79,avg_h:0.05,acc_A_R:-89.48,acc_D_R:220.00,replay_s:-1,lr
# al] episode:19,avg_a_R:-0.59,avg_d_R:0.85,avg_t:2.85,avg_h:0.05,acc_A_R:-88.48,acc_D_R:221.00,replay_s:-1,lr
# al] episode:20,avg_a_R:-0.61,avg_d_R:0.86,avg_t:2.86,avg_h:0.05,acc_A_R:-89.48,acc_D_R:222.00,replay_s:-1,lr
# al] episode:21,avg_a_R:-0.63,avg_d_R:0.86,avg_t:2.82,avg_h:0.05,acc_A_R:-90.48,acc_D_R:223.00,replay_s:-1,lr
# al] episode:22,avg_a_R:-0.65,avg_d_R:0.87,avg_t:2.74,avg_h:0.04,acc_A_R:-91.48,acc_D_R:224.00,replay_s:-1,lr
# al] episode:23,avg_a_R:-0.58,avg_d_R:0.88,avg_t:2.92,avg_h:0.04,acc_A_R:-90.48,acc_D_R:225.00,replay_s:-1,lr
# al] episode:24,avg_a_R:-0.59,avg_d_R:0.88,avg_t:2.88,avg_h:0.04,acc_A_R:-91.48,acc_D_R:226.00,replay_s:-1,lr
# al] episode:25,avg_a_R:-0.61,avg_d_R:0.88,avg_t:2.92,avg_h:0.04,acc_A_R:-92.48,acc_D_R:227.00,replay_s:-1,lr
# al] episode:26,avg_a_R:-0.62,avg_d_R:0.89,avg_t:2.85,avg_h:0.04,acc_A_R:-93.48,acc_D_R:228.00,replay_s:-1,lr
# al] episode:27,avg_a_R:-0.64,avg_d_R:0.89,avg_t:2.82,avg_h:0.04,acc_A_R:-94.48,acc_D_R:229.00,replay_s:-1,lr
# al] episode:28,avg_a_R:-0.65,avg_d_R:0.90,avg_t:2.79,avg_h:0.03,acc_A_R:-95.48,acc_D_R:230.00,replay_s:-1,lr
# al] episode:29,avg_a_R:-0.66,avg_d_R:0.90,avg_t:2.80,avg_h:0.03,acc_A_R:-96.48,acc_D_R:231.00,replay_s:-1,lr
# al] episode:30,avg_a_R:-0.67,avg_d_R:0.90,avg_t:2.74,avg_h:0.03,acc_A_R:-97.48,acc_D_R:232.00,replay_s:-1,lr
# al] episode:31,avg_a_R:-0.62,avg_d_R:0.91,avg_t:2.81,avg_h:0.03,acc_A_R:-96.48,acc_D_R:233.00,replay_s:-1,lr
# al] episode:32,avg_a_R:-0.51,avg_d_R:0.82,avg_t:3.00,avg_h:0.06,acc_A_R:-93.34,acc_D_R:231.00,replay_s:-1,lr
# al] episode:33,avg_a_R:-0.52,avg_d_R:0.82,avg_t:2.94,avg_h:0.06,acc_A_R:-94.34,acc_D_R:232.00,replay_s:-1,lr
# al] episode:34,avg_a_R:-0.48,avg_d_R:0.83,avg_t:3.06,avg_h:0.06,acc_A_R:-93.34,acc_D_R:233.00,replay_s:-1,lr
# al] episode:35,avg_a_R:-0.49,avg_d_R:0.83,avg_t:3.06,avg_h:0.06,acc_A_R:-94.34,acc_D_R:234.00,replay_s:-1,lr
# al] episode:36,avg_a_R:-0.45,avg_d_R:0.84,avg_t:3.14,avg_h:0.05,acc_A_R:-93.34,acc_D_R:235.00,replay_s:-1,lr
# al] episode:37,avg_a_R:-0.47,avg_d_R:0.84,avg_t:3.08,avg_h:0.05,acc_A_R:-94.34,acc_D_R:236.00,replay_s:-1,lr
# al] episode:38,avg_a_R:-0.45,avg_d_R:0.85,avg_t:3.18,avg_h:0.05,acc_A_R:-94.01,acc_D_R:237.00,replay_s:-1,lr
# al] episode:39,avg_a_R:-0.33,avg_d_R:0.78,avg_t:3.15,avg_h:0.07,acc_A_R:-90.01,acc_D_R:235.00,replay_s:-1,lr
# al] episode:39,avg_a_R:-0.33,avg_d_R:0.78,avg_t:3.15,avg_h:0.07,acc_A_R:-90.01,acc_D_R:235.00,replay_s:-1,lr
# al] episode:40,avg_a_R:-0.30,avg_d_R:0.78,avg_t:3.12,avg_h:0.07,acc_A_R:-89.01,acc_D_R:236.00,replay_s:-1,lr
# al] episode:41,avg_a_R:-0.20,avg_d_R:0.71,avg_t:3.14,avg_h:0.10,acc_A_R:-85.01,acc_D_R:234.00,replay_s:-1,lr
# al] episode:42,avg_a_R:-0.17,avg_d_R:0.72,avg_t:3.26,avg_h:0.09,acc_A_R:-84.01,acc_D_R:235.00,replay_s:-1,lr
# al] episode:43,avg_a_R:-0.19,avg_d_R:0.73,avg_t:3.20,avg_h:0.09,acc_A_R:-85.01,acc_D_R:236.00,replay_s:-1,lr
# al] episode:44,avg_a_R:-0.16,avg_d_R:0.73,avg_t:3.18,avg_h:0.09,acc_A_R:-84.01,acc_D_R:237.00,replay_s:-1,lr
# al] episode:45,avg_a_R:-0.18,avg_d_R:0.74,avg_t:3.17,avg_h:0.09,acc_A_R:-85.01,acc_D_R:238.00,replay_s:-1,lr
# al] episode:46,avg_a_R:-0.20,avg_d_R:0.74,avg_t:3.15,avg_h:0.09,acc_A_R:-86.01,acc_D_R:239.00,replay_s:-1,lr
# al] episode:47,avg_a_R:-0.22,avg_d_R:0.75,avg_t:3.10,avg_h:0.08,acc_A_R:-87.01,acc_D_R:240.00,replay_s:-1,lr
# al] episode:48,avg_a_R:-0.21,avg_d_R:0.76,avg_t:3.18,avg_h:0.08,acc_A_R:-86.68,acc_D_R:241.00,replay_s:-1,lr
# al] episode:49,avg_a_R:-0.22,avg_d_R:0.76,avg_t:3.14,avg_h:0.08,acc_A_R:-87.68,acc_D_R:242.00,replay_s:-1,lr
# al] episode:50,avg_a_R:-0.24,avg_d_R:0.76,avg_t:3.12,avg_h:0.08,acc_A_R:-88.68,acc_D_R:243.00,replay_s:-1,lr
# al] episode:51,avg_a_R:-0.25,avg_d_R:0.77,avg_t:3.10,avg_h:0.08,acc_A_R:-89.68,acc_D_R:244.00,replay_s:-1,lr
# al] episode:52,avg_a_R:-0.27,avg_d_R:0.77,avg_t:3.09,avg_h:0.08,acc_A_R:-90.68,acc_D_R:245.00,replay_s:-1,lr
# al] episode:53,avg_a_R:-0.28,avg_d_R:0.78,avg_t:3.06,avg_h:0.07,acc_A_R:-91.68,acc_D_R:246.00,replay_s:-1,lr
# al] episode:54,avg_a_R:-0.26,avg_d_R:0.78,avg_t:3.11,avg_h:0.07,acc_A_R:-90.68,acc_D_R:247.00,replay_s:-1,lr
# al] episode:55,avg_a_R:-0.27,avg_d_R:0.79,avg_t:3.12,avg_h:0.07,acc_A_R:-91.68,acc_D_R:248.00,replay_s:-1,lr
# al] episode:56,avg_a_R:-0.25,avg_d_R:0.79,avg_t:3.12,avg_h:0.07,acc_A_R:-90.68,acc_D_R:249.00,replay_s:-1,lr
# al] episode:57,avg_a_R:-0.26,avg_d_R:0.79,avg_t:3.09,avg_h:0.07,acc_A_R:-91.68,acc_D_R:250.00,replay_s:-1,lr
# al] episode:58,avg_a_R:-0.24,avg_d_R:0.80,avg_t:3.08,avg_h:0.07,acc_A_R:-90.68,acc_D_R:251.00,replay_s:-1,lr
# al] episode:59,avg_a_R:-0.22,avg_d_R:0.80,avg_t:3.12,avg_h:0.07,acc_A_R:-89.68,acc_D_R:252.00,replay_s:-1,lr
# al] episode:60,avg_a_R:-0.17,avg_d_R:0.75,avg_t:3.31,avg_h:0.08,acc_A_R:-87.24,acc_D_R:250.00,replay_s:-1,lr
# al] episode:61,avg_a_R:-0.19,avg_d_R:0.76,avg_t:3.27,avg_h:0.08,acc_A_R:-88.24,acc_D_R:251.00,replay_s:-1,lr
# al] episode:62,avg_a_R:-0.20,avg_d_R:0.76,avg_t:3.29,avg_h:0.08,acc_A_R:-89.24,acc_D_R:252.00,replay_s:-1,lr
# al] episode:63,avg_a_R:-0.21,avg_d_R:0.77,avg_t:3.25,avg_h:0.08,acc_A_R:-90.24,acc_D_R:253.00,replay_s:-1,lr
# al] episode:64,avg_a_R:-0.22,avg_d_R:0.77,avg_t:3.26,avg_h:0.08,acc_A_R:-91.24,acc_D_R:254.00,replay_s:-1,lr
# al] episode:65,avg_a_R:-0.24,avg_d_R:0.77,avg_t:3.23,avg_h:0.08,acc_A_R:-92.24,acc_D_R:255.00,replay_s:-1,lr
# al] episode:66,avg_a_R:-0.20,avg_d_R:0.73,avg_t:3.34,avg_h:0.09,acc_A_R:-89.79,acc_D_R:253.00,replay_s:-1,lr
# ...
# al] episode:66,avg_a_R:-0.26,avg_d_R:0.73,avg_t:3.36,avg_h:0.09,acc_A_R:-563.97,acc_D_R:1367.00,replay_s:-1,
# al] episode:67,avg_a_R:-0.27,avg_d_R:0.74,avg_t:3.34,avg_h:0.09,acc_A_R:-564.97,acc_D_R:1368.00,replay_s:-1,
# al] episode:68,avg_a_R:-0.28,avg_d_R:0.74,avg_t:3.32,avg_h:0.09,acc_A_R:-565.97,acc_D_R:1369.00,replay_s:-1,
# al] episode:69,avg_a_R:-0.29,avg_d_R:0.74,avg_t:3.29,avg_h:0.09,acc_A_R:-566.97,acc_D_R:1370.00,replay_s:-1,
# al] episode:70,avg_a_R:-0.30,avg_d_R:0.75,avg_t:3.25,avg_h:0.08,acc_A_R:-567.97,acc_D_R:1371.00,replay_s:-1,
# al] episode:71,avg_a_R:-0.31,avg_d_R:0.75,avg_t:3.22,avg_h:0.08,acc_A_R:-568.97,acc_D_R:1372.00,replay_s:-1,
# al] episode:72,avg_a_R:-0.32,avg_d_R:0.75,avg_t:3.21,avg_h:0.08,acc_A_R:-569.97,acc_D_R:1373.00,replay_s:-1,
# al] episode:73,avg_a_R:-0.33,avg_d_R:0.76,avg_t:3.19,avg_h:0.08,acc_A_R:-570.97,acc_D_R:1374.00,replay_s:-1,
# al] episode:74,avg_a_R:-0.34,avg_d_R:0.76,avg_t:3.17,avg_h:0.08,acc_A_R:-571.97,acc_D_R:1375.00,replay_s:-1,
# al] episode:75,avg_a_R:-0.35,avg_d_R:0.76,avg_t:3.16,avg_h:0.08,acc_A_R:-572.97,acc_D_R:1376.00,replay_s:-1,
# al] episode:76,avg_a_R:-0.36,avg_d_R:0.77,avg_t:3.17,avg_h:0.08,acc_A_R:-573.97,acc_D_R:1377.00,replay_s:-1,
# al] episode:77,avg_a_R:-0.36,avg_d_R:0.77,avg_t:3.17,avg_h:0.08,acc_A_R:-574.97,acc_D_R:1378.00,replay_s:-1,
# al] episode:78,avg_a_R:-0.32,avg_d_R:0.73,avg_t:3.22,avg_h:0.09,acc_A_R:-572.14,acc_D_R:1376.00,replay_s:-1,
# al] episode:79,avg_a_R:-0.33,avg_d_R:0.74,avg_t:3.27,avg_h:0.09,acc_A_R:-573.14,acc_D_R:1377.00,replay_s:-1,
# al] episode:80,avg_a_R:-0.34,avg_d_R:0.74,avg_t:3.26,avg_h:0.09,acc_A_R:-574.14,acc_D_R:1378.00,replay_s:-1,
# al] episode:81,avg_a_R:-0.35,avg_d_R:0.74,avg_t:3.24,avg_h:0.09,acc_A_R:-575.14,acc_D_R:1379.00,replay_s:-1,
# al] episode:82,avg_a_R:-0.36,avg_d_R:0.75,avg_t:3.27,avg_h:0.08,acc_A_R:-576.14,acc_D_R:1380.00,replay_s:-1,
# al] episode:83,avg_a_R:-0.35,avg_d_R:0.75,avg_t:3.31,avg_h:0.08,acc_A_R:-575.89,acc_D_R:1381.00,replay_s:-1,
# al] episode:84,avg_a_R:-0.34,avg_d_R:0.75,avg_t:3.34,avg_h:0.08,acc_A_R:-575.55,acc_D_R:1382.00,replay_s:-1,
# al] episode:85,avg_a_R:-0.35,avg_d_R:0.76,avg_t:3.33,avg_h:0.08,acc_A_R:-576.55,acc_D_R:1383.00,replay_s:-1,
# al] episode:86,avg_a_R:-0.34,avg_d_R:0.76,avg_t:3.39,avg_h:0.08,acc_A_R:-576.05,acc_D_R:1384.00,replay_s:-1,
# al] episode:87,avg_a_R:-0.35,avg_d_R:0.76,avg_t:3.40,avg_h:0.08,acc_A_R:-577.05,acc_D_R:1385.00,replay_s:-1,
# al] episode:88,avg_a_R:-0.35,avg_d_R:0.76,avg_t:3.38,avg_h:0.08,acc_A_R:-578.05,acc_D_R:1386.00,replay_s:-1,
# al] episode:89,avg_a_R:-0.36,avg_d_R:0.77,avg_t:3.38,avg_h:0.08,acc_A_R:-579.05,acc_D_R:1387.00,replay_s:-1,
# al] episode:90,avg_a_R:-0.35,avg_d_R:0.77,avg_t:3.37,avg_h:0.08,acc_A_R:-578.05,acc_D_R:1388.00,replay_s:-1,
# al] episode:91,avg_a_R:-0.35,avg_d_R:0.77,avg_t:3.36,avg_h:0.08,acc_A_R:-579.05,acc_D_R:1389.00,replay_s:-1,
# al] episode:92,avg_a_R:-0.36,avg_d_R:0.77,avg_t:3.34,avg_h:0.08,acc_A_R:-580.05,acc_D_R:1390.00,replay_s:-1,
# al] episode:93,avg_a_R:-0.37,avg_d_R:0.78,avg_t:3.33,avg_h:0.07,acc_A_R:-581.05,acc_D_R:1391.00,replay_s:-1,
# al] episode:93,avg_a_R:-0.37,avg_d_R:0.78,avg_t:3.33,avg_h:0.07,acc_A_R:-581.05,acc_D_R:1391.00,replay_s:-1,
# al] episode:94,avg_a_R:-0.37,avg_d_R:0.78,avg_t:3.34,avg_h:0.07,acc_A_R:-582.05,acc_D_R:1392.00,replay_s:-1,
# al] episode:95,avg_a_R:-0.33,avg_d_R:0.75,avg_t:3.34,avg_h:0.08,acc_A_R:-578.55,acc_D_R:1390.00,replay_s:-1,
# al] episode:96,avg_a_R:-0.34,avg_d_R:0.75,avg_t:3.34,avg_h:0.08,acc_A_R:-579.55,acc_D_R:1391.00,replay_s:-1,
# al] episode:97,avg_a_R:-0.35,avg_d_R:0.76,avg_t:3.34,avg_h:0.08,acc_A_R:-580.55,acc_D_R:1392.00,replay_s:-1,
# al] episode:98,avg_a_R:-0.31,avg_d_R:0.73,avg_t:3.36,avg_h:0.09,acc_A_R:-577.30,acc_D_R:1390.00,replay_s:-1,
# al] episode:99,avg_a_R:-0.32,avg_d_R:0.73,avg_t:3.34,avg_h:0.09,acc_A_R:-578.30,acc_D_R:1391.00,replay_s:-1,
# starting eval with non-empty result object_a_R:-0.36,avg_d_R:0.70,avg_t:3.18,avg_h:0.10,acc_A_R:-5241.25,acc_D_
#
# [Eval] episode:19000,avg_a_R:-0.32,avg_d_R:0.73,avg_t:3.34,avg_h:0.09,acc_A_R:-578.30,acc_D_R:1391.00,replay_s:
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:5.00,avg_h:0.00,acc_A_R:-579.30,acc_D_R:1392.00,replay_s:-1,l
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:3.50,avg_h:0.00,acc_A_R:-580.30,acc_D_R:1393.00,replay_s:-1,l
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.67,avg_h:0.00,acc_A_R:-581.30,acc_D_R:1394.00,replay_s:-1,l
# al] episode:3,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.50,avg_h:0.00,acc_A_R:-582.30,acc_D_R:1395.00,replay_s:-1,l
# al] episode:4,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.40,avg_h:0.00,acc_A_R:-583.30,acc_D_R:1396.00,replay_s:-1,l
# al] episode:5,avg_a_R:-0.67,avg_d_R:1.00,avg_t:3.33,avg_h:0.00,acc_A_R:-582.30,acc_D_R:1397.00,replay_s:-1,l
# al] episode:6,avg_a_R:0.00,avg_d_R:0.57,avg_t:3.29,avg_h:0.14,acc_A_R:-578.30,acc_D_R:1395.00,replay_s:-1,lr
# al] episode:7,avg_a_R:0.04,avg_d_R:0.62,avg_t:3.75,avg_h:0.12,acc_A_R:-577.97,acc_D_R:1396.00,replay_s:-1,lr
# al] episode:8,avg_a_R:-0.07,avg_d_R:0.67,avg_t:3.67,avg_h:0.11,acc_A_R:-578.97,acc_D_R:1397.00,replay_s:-1,l
# al] episode:9,avg_a_R:-0.17,avg_d_R:0.70,avg_t:3.60,avg_h:0.10,acc_A_R:-579.97,acc_D_R:1398.00,replay_s:-1,l
# al] episode:10,avg_a_R:-0.24,avg_d_R:0.73,avg_t:3.45,avg_h:0.09,acc_A_R:-580.97,acc_D_R:1399.00,replay_s:-1,
# al] episode:11,avg_a_R:-0.31,avg_d_R:0.75,avg_t:3.33,avg_h:0.08,acc_A_R:-581.97,acc_D_R:1400.00,replay_s:-1,
# al] episode:12,avg_a_R:-0.36,avg_d_R:0.77,avg_t:3.15,avg_h:0.08,acc_A_R:-582.97,acc_D_R:1401.00,replay_s:-1,
# al] episode:13,avg_a_R:-0.40,avg_d_R:0.79,avg_t:3.07,avg_h:0.07,acc_A_R:-583.97,acc_D_R:1402.00,replay_s:-1,
# al] episode:14,avg_a_R:-0.44,avg_d_R:0.80,avg_t:3.07,avg_h:0.07,acc_A_R:-584.97,acc_D_R:1403.00,replay_s:-1,
# al] episode:15,avg_a_R:-0.39,avg_d_R:0.81,avg_t:3.31,avg_h:0.06,acc_A_R:-584.47,acc_D_R:1404.00,replay_s:-1,
# al] episode:16,avg_a_R:-0.17,avg_d_R:0.65,avg_t:3.53,avg_h:0.12,acc_A_R:-581.22,acc_D_R:1402.00,replay_s:-1,
# al] episode:17,avg_a_R:-0.22,avg_d_R:0.67,avg_t:3.39,avg_h:0.11,acc_A_R:-582.22,acc_D_R:1403.00,replay_s:-1,
# al] episode:18,avg_a_R:-0.26,avg_d_R:0.68,avg_t:3.32,avg_h:0.11,acc_A_R:-583.22,acc_D_R:1404.00,replay_s:-1,
# al] episode:19,avg_a_R:-0.30,avg_d_R:0.70,avg_t:3.25,avg_h:0.10,acc_A_R:-584.22,acc_D_R:1405.00,replay_s:-1,
# al] episode:20,avg_a_R:-0.12,avg_d_R:0.57,avg_t:3.29,avg_h:0.14,acc_A_R:-580.72,acc_D_R:1403.00,replay_s:-1,
# al] episode:21,avg_a_R:-0.16,avg_d_R:0.59,avg_t:3.23,avg_h:0.14,acc_A_R:-581.72,acc_D_R:1404.00,replay_s:-1,
# al] episode:22,avg_a_R:-0.13,avg_d_R:0.61,avg_t:3.48,avg_h:0.13,acc_A_R:-581.39,acc_D_R:1405.00,replay_s:-1,
# al] episode:23,avg_a_R:-0.17,avg_d_R:0.62,avg_t:3.42,avg_h:0.12,acc_A_R:-582.39,acc_D_R:1406.00,replay_s:-1,
# al] episode:24,avg_a_R:-0.00,avg_d_R:0.52,avg_t:3.36,avg_h:0.16,acc_A_R:-578.39,acc_D_R:1404.00,replay_s:-1,
# al] episode:24,avg_a_R:-0.00,avg_d_R:0.52,avg_t:3.36,avg_h:0.16,acc_A_R:-578.39,acc_D_R:1404.00,replay_s:-1,
# al] episode:25,avg_a_R:0.04,avg_d_R:0.54,avg_t:3.35,avg_h:0.15,acc_A_R:-577.39,acc_D_R:1405.00,replay_s:-1,l
# al] episode:26,avg_a_R:-0.00,avg_d_R:0.56,avg_t:3.30,avg_h:0.15,acc_A_R:-578.39,acc_D_R:1406.00,replay_s:-1,
# al] episode:27,avg_a_R:-0.04,avg_d_R:0.57,avg_t:3.25,avg_h:0.14,acc_A_R:-579.39,acc_D_R:1407.00,replay_s:-1,
# al] episode:28,avg_a_R:-0.07,avg_d_R:0.59,avg_t:3.24,avg_h:0.14,acc_A_R:-580.39,acc_D_R:1408.00,replay_s:-1,
# al] episode:29,avg_a_R:-0.10,avg_d_R:0.60,avg_t:3.20,avg_h:0.13,acc_A_R:-581.39,acc_D_R:1409.00,replay_s:-1,
# al] episode:30,avg_a_R:-0.13,avg_d_R:0.61,avg_t:3.13,avg_h:0.13,acc_A_R:-582.39,acc_D_R:1410.00,replay_s:-1,
# al] episode:31,avg_a_R:-0.16,avg_d_R:0.62,avg_t:3.09,avg_h:0.12,acc_A_R:-583.39,acc_D_R:1411.00,replay_s:-1,
# al] episode:32,avg_a_R:-0.07,avg_d_R:0.55,avg_t:3.21,avg_h:0.15,acc_A_R:-580.55,acc_D_R:1409.00,replay_s:-1,
# al] episode:33,avg_a_R:-0.10,avg_d_R:0.56,avg_t:3.21,avg_h:0.15,acc_A_R:-581.55,acc_D_R:1410.00,replay_s:-1,
# al] episode:34,avg_a_R:-0.12,avg_d_R:0.57,avg_t:3.14,avg_h:0.14,acc_A_R:-582.55,acc_D_R:1411.00,replay_s:-1,
# al] episode:35,avg_a_R:-0.15,avg_d_R:0.58,avg_t:3.17,avg_h:0.14,acc_A_R:-583.55,acc_D_R:1412.00,replay_s:-1,
# al] episode:36,avg_a_R:-0.17,avg_d_R:0.59,avg_t:3.11,avg_h:0.14,acc_A_R:-584.55,acc_D_R:1413.00,replay_s:-1,
# al] episode:37,avg_a_R:-0.19,avg_d_R:0.61,avg_t:3.05,avg_h:0.13,acc_A_R:-585.55,acc_D_R:1414.00,replay_s:-1,
# al] episode:38,avg_a_R:-0.10,avg_d_R:0.54,avg_t:3.18,avg_h:0.15,acc_A_R:-582.35,acc_D_R:1412.00,replay_s:-1,
# al] episode:39,avg_a_R:-0.13,avg_d_R:0.55,avg_t:3.20,avg_h:0.15,acc_A_R:-583.35,acc_D_R:1413.00,replay_s:-1,
# al] episode:40,avg_a_R:-0.10,avg_d_R:0.56,avg_t:3.20,avg_h:0.15,acc_A_R:-582.35,acc_D_R:1414.00,replay_s:-1,
# al] episode:41,avg_a_R:-0.12,avg_d_R:0.57,avg_t:3.21,avg_h:0.14,acc_A_R:-583.35,acc_D_R:1415.00,replay_s:-1,
# al] episode:42,avg_a_R:-0.14,avg_d_R:0.58,avg_t:3.16,avg_h:0.14,acc_A_R:-584.35,acc_D_R:1416.00,replay_s:-1,
# al] episode:43,avg_a_R:-0.16,avg_d_R:0.59,avg_t:3.11,avg_h:0.14,acc_A_R:-585.35,acc_D_R:1417.00,replay_s:-1,
# al] episode:44,avg_a_R:-0.09,avg_d_R:0.53,avg_t:3.20,avg_h:0.16,acc_A_R:-582.15,acc_D_R:1415.00,replay_s:-1,
# al] episode:45,avg_a_R:-0.06,avg_d_R:0.54,avg_t:3.28,avg_h:0.15,acc_A_R:-581.15,acc_D_R:1416.00,replay_s:-1,
# al] episode:46,avg_a_R:-0.08,avg_d_R:0.55,avg_t:3.26,avg_h:0.15,acc_A_R:-582.15,acc_D_R:1417.00,replay_s:-1,
# al] episode:47,avg_a_R:-0.10,avg_d_R:0.56,avg_t:3.27,avg_h:0.15,acc_A_R:-583.15,acc_D_R:1418.00,replay_s:-1,
# al] episode:48,avg_a_R:-0.12,avg_d_R:0.57,avg_t:3.24,avg_h:0.14,acc_A_R:-584.15,acc_D_R:1419.00,replay_s:-1,
# al] episode:48,avg_a_R:-0.12,avg_d_R:0.57,avg_t:3.24,avg_h:0.14,acc_A_R:-584.15,acc_D_R:1419.00,replay_s:-1,
# al] episode:49,avg_a_R:-0.14,avg_d_R:0.58,avg_t:3.22,avg_h:0.14,acc_A_R:-585.15,acc_D_R:1420.00,replay_s:-1,
# al] episode:50,avg_a_R:-0.15,avg_d_R:0.59,avg_t:3.20,avg_h:0.14,acc_A_R:-586.15,acc_D_R:1421.00,replay_s:-1,
# al] episode:51,avg_a_R:-0.17,avg_d_R:0.60,avg_t:3.23,avg_h:0.13,acc_A_R:-587.15,acc_D_R:1422.00,replay_s:-1,
# al] episode:52,avg_a_R:-0.19,avg_d_R:0.60,avg_t:3.25,avg_h:0.13,acc_A_R:-588.15,acc_D_R:1423.00,replay_s:-1,
# al] episode:53,avg_a_R:-0.20,avg_d_R:0.61,avg_t:3.22,avg_h:0.13,acc_A_R:-589.15,acc_D_R:1424.00,replay_s:-1,
# al] episode:54,avg_a_R:-0.22,avg_d_R:0.62,avg_t:3.20,avg_h:0.13,acc_A_R:-590.15,acc_D_R:1425.00,replay_s:-1,
# al] episode:55,avg_a_R:-0.23,avg_d_R:0.62,avg_t:3.18,avg_h:0.12,acc_A_R:-591.15,acc_D_R:1426.00,replay_s:-1,
# al] episode:56,avg_a_R:-0.21,avg_d_R:0.63,avg_t:3.21,avg_h:0.12,acc_A_R:-590.15,acc_D_R:1427.00,replay_s:-1,
# al] episode:57,avg_a_R:-0.22,avg_d_R:0.64,avg_t:3.19,avg_h:0.12,acc_A_R:-591.15,acc_D_R:1428.00,replay_s:-1,
# al] episode:58,avg_a_R:-0.20,avg_d_R:0.64,avg_t:3.19,avg_h:0.12,acc_A_R:-590.15,acc_D_R:1429.00,replay_s:-1,
# al] episode:59,avg_a_R:-0.21,avg_d_R:0.65,avg_t:3.18,avg_h:0.12,acc_A_R:-591.15,acc_D_R:1430.00,replay_s:-1,
# al] episode:60,avg_a_R:-0.21,avg_d_R:0.66,avg_t:3.28,avg_h:0.11,acc_A_R:-590.82,acc_D_R:1431.00,replay_s:-1,
# al] episode:61,avg_a_R:-0.22,avg_d_R:0.66,avg_t:3.24,avg_h:0.11,acc_A_R:-591.82,acc_D_R:1432.00,replay_s:-1,
# al] episode:62,avg_a_R:-0.21,avg_d_R:0.67,avg_t:3.25,avg_h:0.11,acc_A_R:-591.32,acc_D_R:1433.00,replay_s:-1,
# al] episode:63,avg_a_R:-0.22,avg_d_R:0.67,avg_t:3.22,avg_h:0.11,acc_A_R:-592.32,acc_D_R:1434.00,replay_s:-1,
# al] episode:64,avg_a_R:-0.23,avg_d_R:0.68,avg_t:3.22,avg_h:0.11,acc_A_R:-593.32,acc_D_R:1435.00,replay_s:-1,
# al] episode:65,avg_a_R:-0.18,avg_d_R:0.64,avg_t:3.30,avg_h:0.12,acc_A_R:-590.18,acc_D_R:1433.00,replay_s:-1,
# al] episode:66,avg_a_R:-0.16,avg_d_R:0.64,avg_t:3.28,avg_h:0.12,acc_A_R:-589.18,acc_D_R:1434.00,replay_s:-1,
# al] episode:67,avg_a_R:-0.16,avg_d_R:0.65,avg_t:3.32,avg_h:0.12,acc_A_R:-588.84,acc_D_R:1435.00,replay_s:-1,
# al] episode:68,avg_a_R:-0.17,avg_d_R:0.65,avg_t:3.29,avg_h:0.12,acc_A_R:-589.84,acc_D_R:1436.00,replay_s:-1,
# al] episode:69,avg_a_R:-0.18,avg_d_R:0.66,avg_t:3.27,avg_h:0.11,acc_A_R:-590.84,acc_D_R:1437.00,replay_s:-1,
# al] episode:70,avg_a_R:-0.19,avg_d_R:0.66,avg_t:3.25,avg_h:0.11,acc_A_R:-591.84,acc_D_R:1438.00,replay_s:-1,
# al] episode:71,avg_a_R:-0.20,avg_d_R:0.67,avg_t:3.22,avg_h:0.11,acc_A_R:-592.84,acc_D_R:1439.00,replay_s:-1,
# al] episode:72,avg_a_R:-0.21,avg_d_R:0.67,avg_t:3.19,avg_h:0.11,acc_A_R:-593.84,acc_D_R:1440.00,replay_s:-1,
# al] episode:73,avg_a_R:-0.16,avg_d_R:0.64,avg_t:3.19,avg_h:0.12,acc_A_R:-589.84,acc_D_R:1438.00,replay_s:-1,
# al] episode:74,avg_a_R:-0.10,avg_d_R:0.60,avg_t:3.19,avg_h:0.13,acc_A_R:-585.84,acc_D_R:1436.00,replay_s:-1,
# al] episode:75,avg_a_R:-0.11,avg_d_R:0.61,avg_t:3.16,avg_h:0.13,acc_A_R:-586.84,acc_D_R:1437.00,replay_s:-1,
# al] episode:76,avg_a_R:-0.07,avg_d_R:0.57,avg_t:3.19,avg_h:0.14,acc_A_R:-583.51,acc_D_R:1435.00,replay_s:-1,
# al] episode:76,avg_a_R:-0.07,avg_d_R:0.57,avg_t:3.19,avg_h:0.14,acc_A_R:-583.51,acc_D_R:1435.00,replay_s:-1,
# al] episode:77,avg_a_R:-0.08,avg_d_R:0.58,avg_t:3.21,avg_h:0.14,acc_A_R:-584.51,acc_D_R:1436.00,replay_s:-1,
# al] episode:78,avg_a_R:-0.03,avg_d_R:0.54,avg_t:3.22,avg_h:0.15,acc_A_R:-580.51,acc_D_R:1434.00,replay_s:-1,
# al] episode:79,avg_a_R:-0.04,avg_d_R:0.55,avg_t:3.20,avg_h:0.15,acc_A_R:-581.51,acc_D_R:1435.00,replay_s:-1,
# al] episode:80,avg_a_R:-0.03,avg_d_R:0.56,avg_t:3.25,avg_h:0.15,acc_A_R:-581.01,acc_D_R:1436.00,replay_s:-1,
# al] episode:81,avg_a_R:-0.05,avg_d_R:0.56,avg_t:3.22,avg_h:0.15,acc_A_R:-582.01,acc_D_R:1437.00,replay_s:-1,
# al] episode:82,avg_a_R:-0.06,avg_d_R:0.57,avg_t:3.19,avg_h:0.14,acc_A_R:-583.01,acc_D_R:1438.00,replay_s:-1,
# al] episode:83,avg_a_R:-0.07,avg_d_R:0.57,avg_t:3.17,avg_h:0.14,acc_A_R:-584.01,acc_D_R:1439.00,replay_s:-1,
# al] episode:84,avg_a_R:-0.08,avg_d_R:0.58,avg_t:3.16,avg_h:0.14,acc_A_R:-585.01,acc_D_R:1440.00,replay_s:-1,
# al] episode:85,avg_a_R:-0.09,avg_d_R:0.58,avg_t:3.14,avg_h:0.14,acc_A_R:-586.01,acc_D_R:1441.00,replay_s:-1,
# al] episode:86,avg_a_R:-0.10,avg_d_R:0.59,avg_t:3.11,avg_h:0.14,acc_A_R:-587.01,acc_D_R:1442.00,replay_s:-1,
# al] episode:87,avg_a_R:-0.09,avg_d_R:0.59,avg_t:3.14,avg_h:0.14,acc_A_R:-586.51,acc_D_R:1443.00,replay_s:-1,
# al] episode:88,avg_a_R:-0.10,avg_d_R:0.60,avg_t:3.12,avg_h:0.13,acc_A_R:-587.51,acc_D_R:1444.00,replay_s:-1,
# al] episode:89,avg_a_R:-0.11,avg_d_R:0.60,avg_t:3.12,avg_h:0.13,acc_A_R:-588.51,acc_D_R:1445.00,replay_s:-1,
# al] episode:90,avg_a_R:-0.12,avg_d_R:0.60,avg_t:3.11,avg_h:0.13,acc_A_R:-589.51,acc_D_R:1446.00,replay_s:-1,
# al] episode:91,avg_a_R:-0.13,avg_d_R:0.61,avg_t:3.13,avg_h:0.13,acc_A_R:-590.51,acc_D_R:1447.00,replay_s:-1,
# al] episode:92,avg_a_R:-0.14,avg_d_R:0.61,avg_t:3.12,avg_h:0.13,acc_A_R:-591.51,acc_D_R:1448.00,replay_s:-1,
# al] episode:93,avg_a_R:-0.13,avg_d_R:0.62,avg_t:3.13,avg_h:0.13,acc_A_R:-590.51,acc_D_R:1449.00,replay_s:-1,
# al] episode:94,avg_a_R:-0.14,avg_d_R:0.62,avg_t:3.13,avg_h:0.13,acc_A_R:-591.51,acc_D_R:1450.00,replay_s:-1,
# al] episode:95,avg_a_R:-0.13,avg_d_R:0.62,avg_t:3.18,avg_h:0.12,acc_A_R:-590.51,acc_D_R:1451.00,replay_s:-1,
# al] episode:96,avg_a_R:-0.14,avg_d_R:0.63,avg_t:3.19,avg_h:0.12,acc_A_R:-591.51,acc_D_R:1452.00,replay_s:-1,
# al] episode:97,avg_a_R:-0.14,avg_d_R:0.63,avg_t:3.19,avg_h:0.12,acc_A_R:-592.51,acc_D_R:1453.00,replay_s:-1,
# al] episode:98,avg_a_R:-0.15,avg_d_R:0.64,avg_t:3.17,avg_h:0.12,acc_A_R:-593.51,acc_D_R:1454.00,replay_s:-1,
# al] episode:99,avg_a_R:-0.16,avg_d_R:0.64,avg_t:3.17,avg_h:0.12,acc_A_R:-594.51,acc_D_R:1455.00,replay_s:-1,
# starting eval with non-empty result object64,avg_t:3.17,avg_h:0.12,acc_A_R:-594.51,acc_D_R:1455.00,replay_s:
#
# [Eval] episode:20000,avg_a_R:-0.16,avg_d_R:0.64,avg_t:3.17,avg_h:0.12,acc_A_R:-594.51,acc_D_R:1455.00,replay_s:
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# [Train] episode: 20000.00 epsilon:0.14,avg_a_R:-0.36,avg_d_R:0.70,avg_t:3.18,avg_h:0.10,acc_A_R:-5241.25,acc_D_
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00: 100%|█| 100/100 [00:13<00:00,

# %%
from src.utils.utils import get_output_dir, print_summary
from src.utils.plotting import plot_results

# %%
print_summary(train_result, title = "Training")
print("\n")
print_summary(eval_result, title = "Evaluation")
# Out:
# Training Summary:
# --------------------------------------------------
# Final Defense Performance:
# - Average Reward: 0.69 ± 0.09
# - Max-Min Reward: 1.0 - 0.4
# - Average Episode Length: 3.49 ± 0.48
# - Max-Min Episode Length: 5.0 - 2.5
# - Average Hack Probability: 10.24% ± 3.06%
# - Max-Min Hack Probability: 0.2 - 0.0
# - Final Cumulative Reward: 13812
#
#
#
# Evaluation Summary:
# --------------------------------------------------
# Final Defense Performance:
# - Average Reward: 0.69 ± 0.13
# - Max-Min Reward: 0.88 - 0.34
# - Average Episode Length: 3.10 ± 0.40
# - Max-Min Episode Length: 4.56 - 2.52
# - Average Hack Probability: 10.24% ± 4.21%
# - Max-Min Hack Probability: 0.22 - 0.04
# - Final Cumulative Reward: 1455

# %%
train_path = "results/data/33/1743696969.26054_train_results_checkpoint.csv"
eval_path = "results/data/33/1743696969.26054_eval_results_checkpoint.csv"

read_and_plot_results(
    train_path, eval_path,
    q_agent_config.train_log_frequency,
    q_agent_config.eval_frequency, q_agent_config.eval_log_frequency,
    q_agent_config.eval_episodes, default_output_dir , sim = False,
    random_seed = random_seed)
# Out:
# /Users/shirley/Downloads/NEU/5100_final_project/Healthcare-Cyber-Security-with-SARSA-DDQN/src/gym-idsgame/experiments/util/plotting_util.py:449: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlims)
# /Users/shirley/Downloads/NEU/5100_final_project/Healthcare-Cyber-Security-with-SARSA-DDQN/src/gym-idsgame/experiments/util/plotting_util.py:449: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlims)
# /Users/shirley/Downloads/NEU/5100_final_project/Healthcare-Cyber-Security-with-SARSA-DDQN/src/gym-idsgame/experiments/util/plotting_util.py:449: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlims)
# /Users/shirley/Downloads/NEU/5100_final_project/Healthcare-Cyber-Security-with-SARSA-DDQN/src/gym-idsgame/experiments/util/plotting_util.py:449: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlims)
# Failed to process string with tex because latex could not be found
# Error in callback <function _draw_all_if_interactive at 0x15df439a0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
