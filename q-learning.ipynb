# %%
# !pip install -r requirements.txt
# Out:
# Obtaining gym_idsgame from git+https://github.com/Limmen/gym-idsgame.git@d10830fef55308d383c98b41b34688a7fceae357#egg=gym_idsgame (from -r requirements.txt (line 4))
#   Skipping because already up-to-date.
#   Installing build dependencies ... one
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cloudpickle==3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: gym==0.26.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.26.2)
# Requirement already satisfied: gym-notices==0.0.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.0.8)
# Requirement already satisfied: Gymnasium==0.29.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.29.1)
# Requirement already satisfied: gymnasium-notices==0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.0.1)
# Requirement already satisfied: imageio==2.36.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.36.0)
# Requirement already satisfied: jsonpickle==4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: matplotlib==3.9.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.9.2)
# Requirement already satisfied: numpy==1.24.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.24.3)
# Requirement already satisfied: opencv_python==4.10.0.84 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (4.10.0.84)
# Requirement already satisfied: pandas==2.2.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2.2.3)
# Requirement already satisfied: pyglet==1.5.15 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.5.15)
# Requirement already satisfied: pytest==8.3.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (8.3.3)
# Requirement already satisfied: PyYAML==6.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (6.0.2)
# Requirement already satisfied: scikit_learn==1.5.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.5.2)
# Requirement already satisfied: scipy==1.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.13.1)
# Requirement already satisfied: seaborn==0.13.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: setuptools==75.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (75.4.0)
# Requirement already satisfied: six==1.16.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (1.16.0)
# Requirement already satisfied: stable_baselines3==2.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (2.3.2)
# Requirement already satisfied: torch==2.5.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (0.20.1)
# Requirement already satisfied: tqdm==4.67.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Gymnasium==0.29.1->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Gymnasium==0.29.1->-r requirements.txt (line 5)) (0.0.4)
# Requirement already satisfied: pillow>=8.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imageio==2.36.0->-r requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 13)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 13)) (2025.1)
# Requirement already satisfied: iniconfig in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pytest==8.3.3->-r requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pytest==8.3.3->-r requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pytest==8.3.3->-r requirements.txt (line 15)) (1.2.2)
# Requirement already satisfied: tomli>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pytest==8.3.3->-r requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit_learn==1.5.2->-r requirements.txt (line 17)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit_learn==1.5.2->-r requirements.txt (line 17)) (3.5.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 23)) (3.17.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 23)) (3.4.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 23)) (3.1.5)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 23)) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 23)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: tensorboard in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym_idsgame->-r requirements.txt (line 4)) (2.19.0)
# Requirement already satisfied: cv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym_idsgame->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: PyOpenGL in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym_idsgame->-r requirements.txt (line 4)) (3.1.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2->torch==2.5.1->-r requirements.txt (line 23)) (3.0.2)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (6.30.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym_idsgame->-r requirements.txt (line 4)) (3.1.3)
# Building wheels for collected packages: gym_idsgame
#   Building editable for gym_idsgame (pyproject.toml) ... one
#   Created wheel for gym_idsgame: filename=gym_idsgame-1.0.12-0.editable-py3-none-any.whl size=4212 sha256=031728e64b86b388ce2c7b56734a3fe0727a2f7277c43852d528a1b331f4468b
#   Stored in directory: /private/var/folders/h2/x0kxqc2j2kv90drf1mg_96d80000gn/T/pip-ephem-wheel-cache-47rawdbl/wheels/39/58/37/5b783198d09a610c3a67411b1d963fe3e029b950c7f2df0d42
# Successfully built gym_idsgame
# Installing collected packages: gym_idsgame
#   Attempting uninstall: gym_idsgame
#     Found existing installation: gym_idsgame 1.0.12
#     Uninstalling gym_idsgame-1.0.12:
#       Successfully uninstalled gym_idsgame-1.0.12
# Successfully installed gym_idsgame-1.0.12

# %%
# !pwd
# Out:
# /Users/shirley/AI-Agent-for-Cyber-Security

# %%
cp /Users/shirley/Downloads/NEU/5100_final_projectHealthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/atomic_write.py /content/Healthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/closer.py /content/Healthcare-Cyber-Security-with-SARSA-DDQN/missing_py_files_for_gym/json_utils.py /usr/local/lib/python3.10/dist-packages/gym/utils/
# Out:
# usage: cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file target_file
#        cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file ... target_directory

# %%
from gym_idsgame.agents.training_agents.q_learning.q_agent_config import QAgentConfig

# %%
# !pip install gym-idsgame==1.0.12
# Out:
# Requirement already satisfied: gym-idsgame==1.0.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.0.12)
# Requirement already satisfied: gym in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.26.2)
# Requirement already satisfied: pyglet==1.5.15 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.5.15)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.24.3)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.5.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (3.9.2)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.13.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.67.0)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.10.0.84)
# Requirement already satisfied: imageio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.36.0)
# Requirement already satisfied: jsonpickle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (4.0.0)
# Requirement already satisfied: tensorboard in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.19.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.5.2)
# Requirement already satisfied: stable_baselines3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (2.3.2)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (0.20.1)
# Requirement already satisfied: cv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (1.0.0)
# Requirement already satisfied: PyOpenGL in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym-idsgame==1.0.12) (3.1.9)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->gym-idsgame==1.0.12) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->gym-idsgame==1.0.12) (0.0.8)
# Requirement already satisfied: pillow>=8.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from imageio->gym-idsgame==1.0.12) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->gym-idsgame==1.0.12) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn->gym-idsgame==1.0.12) (3.5.0)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn->gym-idsgame==1.0.12) (2.2.3)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable_baselines3->gym-idsgame==1.0.12) (0.29.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (4.12.2)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.4.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (3.1.5)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch->gym-idsgame==1.0.12) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy==1.13.1->torch->gym-idsgame==1.0.12) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (6.30.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (75.4.0)
# Requirement already satisfied: six>1.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard->gym-idsgame==1.0.12) (3.1.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3->gym-idsgame==1.0.12) (0.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn->gym-idsgame==1.0.12) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn->gym-idsgame==1.0.12) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->gym-idsgame==1.0.12) (3.0.2)

# %%
from gym_idsgame.agents.training_agents.q_learning.tabular_q_learning.tabular_q_agent import TabularQAgent
from experiments.util import util
from experiments.util.plotting_util import read_and_plot_results
import gymnasium as gym
from datetime import datetime
from src.environment.compatibility_wrapper import GymCompatibilityWrapper

# %%
import os

# %%
random_seed = 33
default_output_dir = os.getcwd()
util.create_artefact_dirs(default_output_dir, random_seed)

# %%
q_agent_config = QAgentConfig(gamma=0.999, alpha=0.0005, epsilon=1, render=False, eval_sleep=0.9,
                              min_epsilon=0.01, eval_episodes=100, train_log_frequency=100,
                              epsilon_decay=0.9999, video=False, eval_log_frequency=1,
                              video_fps=5, video_dir=default_output_dir + "/results/videos/" + str(random_seed), num_episodes=20001,
                              eval_render=False, gifs=False, gif_dir=default_output_dir + "/results/gifs/" + str(random_seed),
                              eval_frequency=1000, attacker=False, defender=True, video_frequency=101,
                              save_dir=default_output_dir + "/results/data/" + str(random_seed))

# %%
env_name = "idsgame-random_attack-v8"
env = gym.make(env_name, save_dir=default_output_dir + "/results/data/" + str(random_seed))
env = GymCompatibilityWrapper(env)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment idsgame-random_attack-v8 is out of date. You should consider upgrading to version `v21`.
#   logger.deprecation(
# 2025-04-11 08:34:54.458 Python[92769:5368189] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/h2/x0kxqc2j2kv90drf1mg_96d80000gn/T/org.python.python.savedState

# %%
agent = TabularQAgent(env, q_agent_config)

agent.train()
train_result = agent.train_result
eval_result = agent.eval_result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_states to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_states` for environment variables or `env.get_wrapper_attr('num_states')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_attack_actions to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_attack_actions` for environment variables or `env.get_wrapper_attr('num_attack_actions')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_defense_actions to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_defense_actions` for environment variables or `env.get_wrapper_attr('num_defense_actions')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.idsgame_config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.idsgame_config` for environment variables or `env.get_wrapper_attr('idsgame_config')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:175: UserWarning: WARN: The default seed argument in `Env.reset` should be `None`, otherwise the environment will by default always be deterministic. Actual default: seed: int = 0
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be int32, actual type: float64
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_observation to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_observation` for environment variables or `env.get_wrapper_attr('get_observation')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.is_defense_legal to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.is_defense_legal` for environment variables or `env.get_wrapper_attr('is_defense_legal')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be int32, actual type: float64
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:246: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'tuple'>
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.state to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.state` for environment variables or `env.get_wrapper_attr('state')` that will search the reminding wrappers.
#   logger.warn(
# [Train] episode: 0.00 epsilon:1.00,avg_a_R:-1.00,avg_d_R:1.00,avg_t:5.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00,A
# l Episode:   0%|                                                                    | 0/100 [00:00<?, ?it/s]
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:5.00,avg_h:0.00,acc_A_R:-1.00,acc_D_R:1.00,replay_s:-1,lr:0.0
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:6.50,avg_h:0.00,acc_A_R:-2.00,acc_D_R:2.00,replay_s:-1,lr:0.0
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:5.33,avg_h:0.00,acc_A_R:-3.00,acc_D_R:3.00,replay_s:-1,lr:0.0
# al] episode:3,avg_a_R:-0.15,avg_d_R:0.25,avg_t:7.25,avg_h:0.25,acc_A_R:-0.61,acc_D_R:1.00,replay_s:-1,lr:0.0
# al] episode:4,avg_a_R:-0.32,avg_d_R:0.40,avg_t:7.00,avg_h:0.20,acc_A_R:-1.61,acc_D_R:2.00,replay_s:-1,lr:0.0
# al] episode:5,avg_a_R:-0.43,avg_d_R:0.50,avg_t:6.00,avg_h:0.17,acc_A_R:-2.61,acc_D_R:3.00,replay_s:-1,lr:0.0
# al] episode:6,avg_a_R:-0.52,avg_d_R:0.57,avg_t:5.29,avg_h:0.14,acc_A_R:-3.61,acc_D_R:4.00,replay_s:-1,lr:0.0
# al] episode:7,avg_a_R:-0.58,avg_d_R:0.62,avg_t:5.25,avg_h:0.12,acc_A_R:-4.61,acc_D_R:5.00,replay_s:-1,lr:0.0
# al] episode:8,avg_a_R:-0.48,avg_d_R:0.67,avg_t:5.67,avg_h:0.11,acc_A_R:-4.36,acc_D_R:6.00,replay_s:-1,lr:0.0
# al] episode:9,avg_a_R:-0.54,avg_d_R:0.70,avg_t:5.50,avg_h:0.10,acc_A_R:-5.36,acc_D_R:7.00,replay_s:-1,lr:0.0
# al] episode:10,avg_a_R:-0.19,avg_d_R:0.45,avg_t:5.55,avg_h:0.18,acc_A_R:-2.11,acc_D_R:5.00,replay_s:-1,lr:0.
# al] episode:11,avg_a_R:-0.26,avg_d_R:0.50,avg_t:5.25,avg_h:0.17,acc_A_R:-3.11,acc_D_R:6.00,replay_s:-1,lr:0.
# al] episode:12,avg_a_R:-0.32,avg_d_R:0.54,avg_t:4.92,avg_h:0.15,acc_A_R:-4.11,acc_D_R:7.00,replay_s:-1,lr:0.
# al] episode:13,avg_a_R:-0.36,avg_d_R:0.57,avg_t:4.64,avg_h:0.14,acc_A_R:-5.11,acc_D_R:8.00,replay_s:-1,lr:0.
# al] episode:14,avg_a_R:-0.41,avg_d_R:0.60,avg_t:4.40,avg_h:0.13,acc_A_R:-6.11,acc_D_R:9.00,replay_s:-1,lr:0.
# al] episode:15,avg_a_R:-0.44,avg_d_R:0.62,avg_t:4.25,avg_h:0.12,acc_A_R:-7.11,acc_D_R:10.00,replay_s:-1,lr:0
# al] episode:15,avg_a_R:-0.44,avg_d_R:0.62,avg_t:4.25,avg_h:0.12,acc_A_R:-7.11,acc_D_R:10.00,replay_s:-1,lr:0
# al] episode:16,avg_a_R:-0.39,avg_d_R:0.65,avg_t:4.47,avg_h:0.12,acc_A_R:-6.61,acc_D_R:11.00,replay_s:-1,lr:0
# al] episode:17,avg_a_R:-0.42,avg_d_R:0.67,avg_t:4.44,avg_h:0.11,acc_A_R:-7.61,acc_D_R:12.00,replay_s:-1,lr:0
# al] episode:18,avg_a_R:-0.45,avg_d_R:0.68,avg_t:4.32,avg_h:0.11,acc_A_R:-8.61,acc_D_R:13.00,replay_s:-1,lr:0
# al] episode:19,avg_a_R:-0.48,avg_d_R:0.70,avg_t:4.25,avg_h:0.10,acc_A_R:-9.61,acc_D_R:14.00,replay_s:-1,lr:0
# al] episode:20,avg_a_R:-0.51,avg_d_R:0.71,avg_t:4.14,avg_h:0.10,acc_A_R:-10.61,acc_D_R:15.00,replay_s:-1,lr:
# al] episode:21,avg_a_R:-0.47,avg_d_R:0.73,avg_t:4.23,avg_h:0.09,acc_A_R:-10.36,acc_D_R:16.00,replay_s:-1,lr:
# al] episode:22,avg_a_R:-0.41,avg_d_R:0.74,avg_t:4.13,avg_h:0.09,acc_A_R:-9.36,acc_D_R:17.00,replay_s:-1,lr:0
# al] episode:23,avg_a_R:-0.43,avg_d_R:0.75,avg_t:4.08,avg_h:0.08,acc_A_R:-10.36,acc_D_R:18.00,replay_s:-1,lr:
# al] episode:24,avg_a_R:-0.45,avg_d_R:0.76,avg_t:4.24,avg_h:0.08,acc_A_R:-11.36,acc_D_R:19.00,replay_s:-1,lr:
# al] episode:25,avg_a_R:-0.34,avg_d_R:0.65,avg_t:4.54,avg_h:0.12,acc_A_R:-8.73,acc_D_R:17.00,replay_s:-1,lr:0
# al] episode:26,avg_a_R:-0.36,avg_d_R:0.67,avg_t:4.41,avg_h:0.11,acc_A_R:-9.73,acc_D_R:18.00,replay_s:-1,lr:0
# al] episode:27,avg_a_R:-0.38,avg_d_R:0.68,avg_t:4.29,avg_h:0.11,acc_A_R:-10.73,acc_D_R:19.00,replay_s:-1,lr:
# al] episode:28,avg_a_R:-0.26,avg_d_R:0.59,avg_t:4.34,avg_h:0.14,acc_A_R:-7.40,acc_D_R:17.00,replay_s:-1,lr:0
# al] episode:29,avg_a_R:-0.28,avg_d_R:0.60,avg_t:4.30,avg_h:0.13,acc_A_R:-8.40,acc_D_R:18.00,replay_s:-1,lr:0
# al] episode:30,avg_a_R:-0.30,avg_d_R:0.61,avg_t:4.29,avg_h:0.13,acc_A_R:-9.40,acc_D_R:19.00,replay_s:-1,lr:0
# al] episode:31,avg_a_R:-0.28,avg_d_R:0.62,avg_t:4.31,avg_h:0.12,acc_A_R:-9.07,acc_D_R:20.00,replay_s:-1,lr:0
# al] episode:32,avg_a_R:-0.31,avg_d_R:0.64,avg_t:4.21,avg_h:0.12,acc_A_R:-10.07,acc_D_R:21.00,replay_s:-1,lr:
# al] episode:33,avg_a_R:-0.20,avg_d_R:0.56,avg_t:4.29,avg_h:0.15,acc_A_R:-6.82,acc_D_R:19.00,replay_s:-1,lr:0
# al] episode:34,avg_a_R:-0.22,avg_d_R:0.57,avg_t:4.20,avg_h:0.14,acc_A_R:-7.82,acc_D_R:20.00,replay_s:-1,lr:0
# al] episode:35,avg_a_R:-0.19,avg_d_R:0.58,avg_t:4.17,avg_h:0.14,acc_A_R:-6.82,acc_D_R:21.00,replay_s:-1,lr:0
# al] episode:36,avg_a_R:-0.16,avg_d_R:0.59,avg_t:4.27,avg_h:0.14,acc_A_R:-5.82,acc_D_R:22.00,replay_s:-1,lr:0
# al] episode:37,avg_a_R:-0.18,avg_d_R:0.61,avg_t:4.21,avg_h:0.13,acc_A_R:-6.82,acc_D_R:23.00,replay_s:-1,lr:0
# al] episode:38,avg_a_R:-0.10,avg_d_R:0.54,avg_t:4.26,avg_h:0.15,acc_A_R:-3.82,acc_D_R:21.00,replay_s:-1,lr:0
# al] episode:39,avg_a_R:-0.12,avg_d_R:0.55,avg_t:4.20,avg_h:0.15,acc_A_R:-4.82,acc_D_R:22.00,replay_s:-1,lr:0
# al] episode:40,avg_a_R:-0.09,avg_d_R:0.56,avg_t:4.27,avg_h:0.15,acc_A_R:-3.82,acc_D_R:23.00,replay_s:-1,lr:0
# al] episode:41,avg_a_R:-0.02,avg_d_R:0.50,avg_t:4.50,avg_h:0.17,acc_A_R:-0.72,acc_D_R:21.00,replay_s:-1,lr:0
# al] episode:42,avg_a_R:0.01,avg_d_R:0.51,avg_t:4.47,avg_h:0.16,acc_A_R:0.28,acc_D_R:22.00,replay_s:-1,lr:0.0
# al] episode:43,avg_a_R:0.07,avg_d_R:0.45,avg_t:4.52,avg_h:0.18,acc_A_R:3.11,acc_D_R:20.00,replay_s:-1,lr:0.0
# al] episode:43,avg_a_R:0.07,avg_d_R:0.45,avg_t:4.52,avg_h:0.18,acc_A_R:3.11,acc_D_R:20.00,replay_s:-1,lr:0.0
# al] episode:44,avg_a_R:0.05,avg_d_R:0.47,avg_t:4.44,avg_h:0.18,acc_A_R:2.11,acc_D_R:21.00,replay_s:-1,lr:0.0
# al] episode:45,avg_a_R:0.12,avg_d_R:0.41,avg_t:4.50,avg_h:0.20,acc_A_R:5.36,acc_D_R:19.00,replay_s:-1,lr:0.0
# al] episode:46,avg_a_R:0.20,avg_d_R:0.36,avg_t:4.45,avg_h:0.21,acc_A_R:9.36,acc_D_R:17.00,replay_s:-1,lr:0.0
# al] episode:47,avg_a_R:0.17,avg_d_R:0.38,avg_t:4.42,avg_h:0.21,acc_A_R:8.36,acc_D_R:18.00,replay_s:-1,lr:0.0
# al] episode:48,avg_a_R:0.15,avg_d_R:0.39,avg_t:4.35,avg_h:0.20,acc_A_R:7.36,acc_D_R:19.00,replay_s:-1,lr:0.0
# al] episode:49,avg_a_R:0.21,avg_d_R:0.34,avg_t:4.36,avg_h:0.22,acc_A_R:10.69,acc_D_R:17.00,replay_s:-1,lr:0.
# al] episode:50,avg_a_R:0.19,avg_d_R:0.35,avg_t:4.33,avg_h:0.22,acc_A_R:9.69,acc_D_R:18.00,replay_s:-1,lr:0.0
# al] episode:51,avg_a_R:0.17,avg_d_R:0.37,avg_t:4.31,avg_h:0.21,acc_A_R:8.69,acc_D_R:19.00,replay_s:-1,lr:0.0
# al] episode:52,avg_a_R:0.15,avg_d_R:0.38,avg_t:4.25,avg_h:0.21,acc_A_R:7.69,acc_D_R:20.00,replay_s:-1,lr:0.0
# al] episode:53,avg_a_R:0.12,avg_d_R:0.39,avg_t:4.22,avg_h:0.20,acc_A_R:6.69,acc_D_R:21.00,replay_s:-1,lr:0.0
# al] episode:54,avg_a_R:0.19,avg_d_R:0.35,avg_t:4.20,avg_h:0.22,acc_A_R:10.69,acc_D_R:19.00,replay_s:-1,lr:0.
# al] episode:55,avg_a_R:0.17,avg_d_R:0.36,avg_t:4.21,avg_h:0.21,acc_A_R:9.69,acc_D_R:20.00,replay_s:-1,lr:0.0
# al] episode:56,avg_a_R:0.23,avg_d_R:0.32,avg_t:4.26,avg_h:0.23,acc_A_R:12.94,acc_D_R:18.00,replay_s:-1,lr:0.
# al] episode:57,avg_a_R:0.21,avg_d_R:0.33,avg_t:4.21,avg_h:0.22,acc_A_R:11.94,acc_D_R:19.00,replay_s:-1,lr:0.
# al] episode:58,avg_a_R:0.22,avg_d_R:0.34,avg_t:4.22,avg_h:0.22,acc_A_R:12.94,acc_D_R:20.00,replay_s:-1,lr:0.
# al] episode:59,avg_a_R:0.22,avg_d_R:0.35,avg_t:4.38,avg_h:0.22,acc_A_R:13.08,acc_D_R:21.00,replay_s:-1,lr:0.
# al] episode:60,avg_a_R:0.20,avg_d_R:0.36,avg_t:4.34,avg_h:0.21,acc_A_R:12.08,acc_D_R:22.00,replay_s:-1,lr:0.
# al] episode:61,avg_a_R:0.21,avg_d_R:0.37,avg_t:4.34,avg_h:0.21,acc_A_R:13.08,acc_D_R:23.00,replay_s:-1,lr:0.
# al] episode:62,avg_a_R:0.19,avg_d_R:0.38,avg_t:4.33,avg_h:0.21,acc_A_R:12.08,acc_D_R:24.00,replay_s:-1,lr:0.
# al] episode:63,avg_a_R:0.17,avg_d_R:0.39,avg_t:4.31,avg_h:0.20,acc_A_R:11.08,acc_D_R:25.00,replay_s:-1,lr:0.
# al] episode:64,avg_a_R:0.16,avg_d_R:0.40,avg_t:4.28,avg_h:0.20,acc_A_R:10.08,acc_D_R:26.00,replay_s:-1,lr:0.
# al] episode:65,avg_a_R:0.14,avg_d_R:0.41,avg_t:4.29,avg_h:0.20,acc_A_R:9.08,acc_D_R:27.00,replay_s:-1,lr:0.0
# al] episode:66,avg_a_R:0.12,avg_d_R:0.42,avg_t:4.28,avg_h:0.19,acc_A_R:8.08,acc_D_R:28.00,replay_s:-1,lr:0.0
# al] episode:67,avg_a_R:0.10,avg_d_R:0.43,avg_t:4.24,avg_h:0.19,acc_A_R:7.08,acc_D_R:29.00,replay_s:-1,lr:0.0
# al] episode:68,avg_a_R:0.09,avg_d_R:0.43,avg_t:4.20,avg_h:0.19,acc_A_R:6.08,acc_D_R:30.00,replay_s:-1,lr:0.0
# al] episode:69,avg_a_R:0.07,avg_d_R:0.44,avg_t:4.17,avg_h:0.19,acc_A_R:5.08,acc_D_R:31.00,replay_s:-1,lr:0.0
# al] episode:70,avg_a_R:0.06,avg_d_R:0.45,avg_t:4.13,avg_h:0.18,acc_A_R:4.08,acc_D_R:32.00,replay_s:-1,lr:0.0
# al] episode:71,avg_a_R:0.04,avg_d_R:0.46,avg_t:4.08,avg_h:0.18,acc_A_R:3.08,acc_D_R:33.00,replay_s:-1,lr:0.0
# al] episode:72,avg_a_R:0.04,avg_d_R:0.47,avg_t:4.14,avg_h:0.18,acc_A_R:3.25,acc_D_R:34.00,replay_s:-1,lr:0.0
# al] episode:73,avg_a_R:0.06,avg_d_R:0.47,avg_t:4.14,avg_h:0.18,acc_A_R:4.25,acc_D_R:35.00,replay_s:-1,lr:0.0
# al] episode:74,avg_a_R:0.11,avg_d_R:0.44,avg_t:4.12,avg_h:0.19,acc_A_R:8.25,acc_D_R:33.00,replay_s:-1,lr:0.0
# al] episode:75,avg_a_R:0.10,avg_d_R:0.45,avg_t:4.09,avg_h:0.18,acc_A_R:7.25,acc_D_R:34.00,replay_s:-1,lr:0.0
# al] episode:76,avg_a_R:0.10,avg_d_R:0.45,avg_t:4.16,avg_h:0.18,acc_A_R:7.42,acc_D_R:35.00,replay_s:-1,lr:0.0
# al] episode:76,avg_a_R:0.10,avg_d_R:0.45,avg_t:4.16,avg_h:0.18,acc_A_R:7.42,acc_D_R:35.00,replay_s:-1,lr:0.0
# al] episode:77,avg_a_R:0.10,avg_d_R:0.46,avg_t:4.21,avg_h:0.18,acc_A_R:7.67,acc_D_R:36.00,replay_s:-1,lr:0.0
# al] episode:78,avg_a_R:0.08,avg_d_R:0.47,avg_t:4.22,avg_h:0.18,acc_A_R:6.67,acc_D_R:37.00,replay_s:-1,lr:0.0
# al] episode:79,avg_a_R:0.07,avg_d_R:0.47,avg_t:4.19,avg_h:0.17,acc_A_R:5.67,acc_D_R:38.00,replay_s:-1,lr:0.0
# al] episode:80,avg_a_R:0.08,avg_d_R:0.48,avg_t:4.16,avg_h:0.17,acc_A_R:6.67,acc_D_R:39.00,replay_s:-1,lr:0.0
# al] episode:81,avg_a_R:0.07,avg_d_R:0.49,avg_t:4.12,avg_h:0.17,acc_A_R:5.67,acc_D_R:40.00,replay_s:-1,lr:0.0
# al] episode:82,avg_a_R:0.06,avg_d_R:0.49,avg_t:4.08,avg_h:0.17,acc_A_R:4.67,acc_D_R:41.00,replay_s:-1,lr:0.0
# al] episode:83,avg_a_R:0.04,avg_d_R:0.50,avg_t:4.06,avg_h:0.17,acc_A_R:3.67,acc_D_R:42.00,replay_s:-1,lr:0.0
# al] episode:84,avg_a_R:0.03,avg_d_R:0.51,avg_t:4.05,avg_h:0.16,acc_A_R:2.67,acc_D_R:43.00,replay_s:-1,lr:0.0
# al] episode:85,avg_a_R:0.04,avg_d_R:0.51,avg_t:4.09,avg_h:0.16,acc_A_R:3.17,acc_D_R:44.00,replay_s:-1,lr:0.0
# al] episode:86,avg_a_R:0.07,avg_d_R:0.48,avg_t:4.14,avg_h:0.17,acc_A_R:5.92,acc_D_R:42.00,replay_s:-1,lr:0.0
# al] episode:87,avg_a_R:0.06,avg_d_R:0.49,avg_t:4.11,avg_h:0.17,acc_A_R:4.92,acc_D_R:43.00,replay_s:-1,lr:0.0
# al] episode:88,avg_a_R:0.06,avg_d_R:0.49,avg_t:4.13,avg_h:0.17,acc_A_R:5.17,acc_D_R:44.00,replay_s:-1,lr:0.0
# al] episode:89,avg_a_R:0.05,avg_d_R:0.50,avg_t:4.10,avg_h:0.17,acc_A_R:4.17,acc_D_R:45.00,replay_s:-1,lr:0.0
# al] episode:90,avg_a_R:0.03,avg_d_R:0.51,avg_t:4.07,avg_h:0.16,acc_A_R:3.17,acc_D_R:46.00,replay_s:-1,lr:0.0
# al] episode:91,avg_a_R:0.05,avg_d_R:0.51,avg_t:4.04,avg_h:0.16,acc_A_R:4.17,acc_D_R:47.00,replay_s:-1,lr:0.0
# al] episode:92,avg_a_R:0.05,avg_d_R:0.52,avg_t:4.10,avg_h:0.16,acc_A_R:4.42,acc_D_R:48.00,replay_s:-1,lr:0.0
# al] episode:93,avg_a_R:0.05,avg_d_R:0.52,avg_t:4.20,avg_h:0.16,acc_A_R:4.56,acc_D_R:49.00,replay_s:-1,lr:0.0
# al] episode:94,avg_a_R:0.08,avg_d_R:0.49,avg_t:4.22,avg_h:0.17,acc_A_R:7.89,acc_D_R:47.00,replay_s:-1,lr:0.0
# al] episode:95,avg_a_R:0.07,avg_d_R:0.50,avg_t:4.22,avg_h:0.17,acc_A_R:6.89,acc_D_R:48.00,replay_s:-1,lr:0.0
# al] episode:96,avg_a_R:0.06,avg_d_R:0.51,avg_t:4.19,avg_h:0.16,acc_A_R:5.89,acc_D_R:49.00,replay_s:-1,lr:0.0
# al] episode:97,avg_a_R:0.09,avg_d_R:0.48,avg_t:4.27,avg_h:0.17,acc_A_R:9.01,acc_D_R:47.00,replay_s:-1,lr:0.0
# al] episode:98,avg_a_R:0.08,avg_d_R:0.48,avg_t:4.23,avg_h:0.17,acc_A_R:8.01,acc_D_R:48.00,replay_s:-1,lr:0.0
# al] episode:99,avg_a_R:0.08,avg_d_R:0.49,avg_t:4.28,avg_h:0.17,acc_A_R:8.34,acc_D_R:49.00,replay_s:-1,lr:0.0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.save_trajectories to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.save_trajectories` for environment variables or `env.get_wrapper_attr('save_trajectories')` that will search the reminding wrappers.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.save_attack_data to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.save_attack_data` for environment variables or `env.get_wrapper_attr('save_attack_data')` that will search the reminding wrappers.
#   logger.warn(
# starting eval with non-empty result objecta_R:-0.33,avg_d_R:0.73,avg_t:4.11,avg_h:0.09,acc_A_R:-73.81,acc_D_R:5
#
# [Eval] episode:0,avg_a_R:0.08,avg_d_R:0.49,avg_t:4.28,avg_h:0.17,acc_A_R:8.34,acc_D_R:49.00,replay_s:-1,lr:0.00
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:3.00,avg_h:0.00,acc_A_R:7.34,acc_D_R:50.00,replay_s:-1,lr:0.0
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:4.00,avg_h:0.00,acc_A_R:6.34,acc_D_R:51.00,replay_s:-1,lr:0.0
# al] episode:2,avg_a_R:0.44,avg_d_R:0.00,avg_t:4.67,avg_h:0.33,acc_A_R:9.67,acc_D_R:49.00,replay_s:-1,lr:0.00
# al] episode:3,avg_a_R:1.33,avg_d_R:-0.50,avg_t:4.00,avg_h:0.50,acc_A_R:13.67,acc_D_R:47.00,replay_s:-1,lr:0.
# al] episode:4,avg_a_R:1.12,avg_d_R:-0.20,avg_t:4.40,avg_h:0.40,acc_A_R:13.92,acc_D_R:48.00,replay_s:-1,lr:0.
# al] episode:5,avg_a_R:0.76,avg_d_R:0.00,avg_t:4.17,avg_h:0.33,acc_A_R:12.92,acc_D_R:49.00,replay_s:-1,lr:0.0
# al] episode:6,avg_a_R:0.80,avg_d_R:0.14,avg_t:4.00,avg_h:0.29,acc_A_R:13.92,acc_D_R:50.00,replay_s:-1,lr:0.0
# al] episode:7,avg_a_R:0.57,avg_d_R:0.25,avg_t:3.62,avg_h:0.25,acc_A_R:12.92,acc_D_R:51.00,replay_s:-1,lr:0.0
# al] episode:8,avg_a_R:0.55,avg_d_R:0.33,avg_t:3.78,avg_h:0.22,acc_A_R:13.26,acc_D_R:52.00,replay_s:-1,lr:0.0
# al] episode:9,avg_a_R:0.39,avg_d_R:0.40,avg_t:3.50,avg_h:0.20,acc_A_R:12.26,acc_D_R:53.00,replay_s:-1,lr:0.0
# al] episode:10,avg_a_R:0.27,avg_d_R:0.45,avg_t:3.45,avg_h:0.18,acc_A_R:11.26,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:11,avg_a_R:0.53,avg_d_R:0.25,avg_t:3.50,avg_h:0.25,acc_A_R:14.76,acc_D_R:52.00,replay_s:-1,lr:0.
# al] episode:12,avg_a_R:0.42,avg_d_R:0.31,avg_t:3.31,avg_h:0.23,acc_A_R:13.76,acc_D_R:53.00,replay_s:-1,lr:0.
# al] episode:13,avg_a_R:0.32,avg_d_R:0.36,avg_t:3.29,avg_h:0.21,acc_A_R:12.76,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:14,avg_a_R:0.23,avg_d_R:0.40,avg_t:3.13,avg_h:0.20,acc_A_R:11.76,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:15,avg_a_R:0.15,avg_d_R:0.44,avg_t:3.00,avg_h:0.19,acc_A_R:10.76,acc_D_R:56.00,replay_s:-1,lr:0.
# al] episode:16,avg_a_R:0.08,avg_d_R:0.47,avg_t:2.94,avg_h:0.18,acc_A_R:9.76,acc_D_R:57.00,replay_s:-1,lr:0.0
# al] episode:17,avg_a_R:0.02,avg_d_R:0.50,avg_t:2.83,avg_h:0.17,acc_A_R:8.76,acc_D_R:58.00,replay_s:-1,lr:0.0
# al] episode:18,avg_a_R:-0.03,avg_d_R:0.53,avg_t:2.79,avg_h:0.16,acc_A_R:7.76,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:19,avg_a_R:-0.08,avg_d_R:0.55,avg_t:2.85,avg_h:0.15,acc_A_R:6.76,acc_D_R:60.00,replay_s:-1,lr:0.
# al] episode:20,avg_a_R:0.06,avg_d_R:0.43,avg_t:3.10,avg_h:0.19,acc_A_R:9.51,acc_D_R:58.00,replay_s:-1,lr:0.0
# al] episode:21,avg_a_R:0.20,avg_d_R:0.32,avg_t:3.27,avg_h:0.23,acc_A_R:12.76,acc_D_R:56.00,replay_s:-1,lr:0.
# al] episode:22,avg_a_R:0.33,avg_d_R:0.22,avg_t:3.57,avg_h:0.26,acc_A_R:15.88,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:23,avg_a_R:0.27,avg_d_R:0.25,avg_t:3.46,avg_h:0.25,acc_A_R:14.88,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:24,avg_a_R:0.36,avg_d_R:0.16,avg_t:3.80,avg_h:0.28,acc_A_R:17.36,acc_D_R:53.00,replay_s:-1,lr:0.
# al] episode:25,avg_a_R:0.39,avg_d_R:0.19,avg_t:3.73,avg_h:0.27,acc_A_R:18.36,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:26,avg_a_R:0.33,avg_d_R:0.22,avg_t:3.67,avg_h:0.26,acc_A_R:17.36,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:27,avg_a_R:0.46,avg_d_R:0.14,avg_t:3.61,avg_h:0.29,acc_A_R:21.36,acc_D_R:53.00,replay_s:-1,lr:0.
# al] episode:28,avg_a_R:0.41,avg_d_R:0.17,avg_t:3.52,avg_h:0.28,acc_A_R:20.36,acc_D_R:54.00,replay_s:-1,lr:0.
# al] episode:29,avg_a_R:0.41,avg_d_R:0.20,avg_t:3.77,avg_h:0.27,acc_A_R:20.56,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:30,avg_a_R:0.36,avg_d_R:0.23,avg_t:3.71,avg_h:0.26,acc_A_R:19.56,acc_D_R:56.00,replay_s:-1,lr:0.
# al] episode:31,avg_a_R:0.32,avg_d_R:0.25,avg_t:3.75,avg_h:0.25,acc_A_R:18.56,acc_D_R:57.00,replay_s:-1,lr:0.
# al] episode:32,avg_a_R:0.32,avg_d_R:0.27,avg_t:3.76,avg_h:0.24,acc_A_R:19.06,acc_D_R:58.00,replay_s:-1,lr:0.
# al] episode:32,avg_a_R:0.32,avg_d_R:0.27,avg_t:3.76,avg_h:0.24,acc_A_R:19.06,acc_D_R:58.00,replay_s:-1,lr:0.
# al] episode:33,avg_a_R:0.29,avg_d_R:0.29,avg_t:3.76,avg_h:0.24,acc_A_R:18.06,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:34,avg_a_R:0.38,avg_d_R:0.23,avg_t:3.80,avg_h:0.26,acc_A_R:21.56,acc_D_R:57.00,replay_s:-1,lr:0.
# al] episode:35,avg_a_R:0.48,avg_d_R:0.17,avg_t:3.78,avg_h:0.28,acc_A_R:25.56,acc_D_R:55.00,replay_s:-1,lr:0.
# al] episode:36,avg_a_R:0.44,avg_d_R:0.19,avg_t:3.89,avg_h:0.27,acc_A_R:24.56,acc_D_R:56.00,replay_s:-1,lr:0.
# al] episode:37,avg_a_R:0.40,avg_d_R:0.21,avg_t:3.89,avg_h:0.26,acc_A_R:23.56,acc_D_R:57.00,replay_s:-1,lr:0.
# al] episode:38,avg_a_R:0.36,avg_d_R:0.23,avg_t:3.87,avg_h:0.26,acc_A_R:22.56,acc_D_R:58.00,replay_s:-1,lr:0.
# al] episode:39,avg_a_R:0.33,avg_d_R:0.25,avg_t:3.80,avg_h:0.25,acc_A_R:21.56,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:40,avg_a_R:0.38,avg_d_R:0.20,avg_t:4.02,avg_h:0.27,acc_A_R:23.92,acc_D_R:57.00,replay_s:-1,lr:0.
# al] episode:41,avg_a_R:0.35,avg_d_R:0.21,avg_t:3.95,avg_h:0.26,acc_A_R:22.92,acc_D_R:58.00,replay_s:-1,lr:0.
# al] episode:42,avg_a_R:0.32,avg_d_R:0.23,avg_t:3.91,avg_h:0.26,acc_A_R:21.92,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:43,avg_a_R:0.29,avg_d_R:0.25,avg_t:3.84,avg_h:0.25,acc_A_R:20.92,acc_D_R:60.00,replay_s:-1,lr:0.
# al] episode:44,avg_a_R:0.30,avg_d_R:0.27,avg_t:3.80,avg_h:0.24,acc_A_R:21.92,acc_D_R:61.00,replay_s:-1,lr:0.
# al] episode:45,avg_a_R:0.27,avg_d_R:0.28,avg_t:3.78,avg_h:0.24,acc_A_R:20.92,acc_D_R:62.00,replay_s:-1,lr:0.
# al] episode:46,avg_a_R:0.25,avg_d_R:0.30,avg_t:3.74,avg_h:0.23,acc_A_R:19.92,acc_D_R:63.00,replay_s:-1,lr:0.
# al] episode:47,avg_a_R:0.30,avg_d_R:0.25,avg_t:3.85,avg_h:0.25,acc_A_R:22.62,acc_D_R:61.00,replay_s:-1,lr:0.
# al] episode:48,avg_a_R:0.36,avg_d_R:0.20,avg_t:3.92,avg_h:0.27,acc_A_R:25.87,acc_D_R:59.00,replay_s:-1,lr:0.
# al] episode:49,avg_a_R:0.35,avg_d_R:0.22,avg_t:3.98,avg_h:0.26,acc_A_R:26.07,acc_D_R:60.00,replay_s:-1,lr:0.
# al] episode:50,avg_a_R:0.33,avg_d_R:0.24,avg_t:3.92,avg_h:0.25,acc_A_R:25.07,acc_D_R:61.00,replay_s:-1,lr:0.
# al] episode:51,avg_a_R:0.30,avg_d_R:0.25,avg_t:3.87,avg_h:0.25,acc_A_R:24.07,acc_D_R:62.00,replay_s:-1,lr:0.
# al] episode:52,avg_a_R:0.32,avg_d_R:0.26,avg_t:3.87,avg_h:0.25,acc_A_R:25.07,acc_D_R:63.00,replay_s:-1,lr:0.
# al] episode:53,avg_a_R:0.33,avg_d_R:0.28,avg_t:3.87,avg_h:0.24,acc_A_R:26.07,acc_D_R:64.00,replay_s:-1,lr:0.
# al] episode:54,avg_a_R:0.34,avg_d_R:0.29,avg_t:3.84,avg_h:0.24,acc_A_R:27.07,acc_D_R:65.00,replay_s:-1,lr:0.
# al] episode:55,avg_a_R:0.32,avg_d_R:0.30,avg_t:3.93,avg_h:0.23,acc_A_R:26.07,acc_D_R:66.00,replay_s:-1,lr:0.
# al] episode:56,avg_a_R:0.29,avg_d_R:0.32,avg_t:3.93,avg_h:0.23,acc_A_R:25.07,acc_D_R:67.00,replay_s:-1,lr:0.
# al] episode:57,avg_a_R:0.34,avg_d_R:0.28,avg_t:3.97,avg_h:0.24,acc_A_R:28.32,acc_D_R:65.00,replay_s:-1,lr:0.
# al] episode:58,avg_a_R:0.32,avg_d_R:0.29,avg_t:3.93,avg_h:0.24,acc_A_R:27.32,acc_D_R:66.00,replay_s:-1,lr:0.
# al] episode:59,avg_a_R:0.30,avg_d_R:0.30,avg_t:3.90,avg_h:0.23,acc_A_R:26.32,acc_D_R:67.00,replay_s:-1,lr:0.
# al] episode:60,avg_a_R:0.30,avg_d_R:0.31,avg_t:3.98,avg_h:0.23,acc_A_R:26.57,acc_D_R:68.00,replay_s:-1,lr:0.
# al] episode:61,avg_a_R:0.28,avg_d_R:0.32,avg_t:4.00,avg_h:0.23,acc_A_R:25.57,acc_D_R:69.00,replay_s:-1,lr:0.
# al] episode:62,avg_a_R:0.33,avg_d_R:0.29,avg_t:4.03,avg_h:0.24,acc_A_R:28.91,acc_D_R:67.00,replay_s:-1,lr:0.
# al] episode:63,avg_a_R:0.34,avg_d_R:0.30,avg_t:4.00,avg_h:0.23,acc_A_R:29.91,acc_D_R:68.00,replay_s:-1,lr:0.
# al] episode:64,avg_a_R:0.35,avg_d_R:0.31,avg_t:3.98,avg_h:0.23,acc_A_R:30.91,acc_D_R:69.00,replay_s:-1,lr:0.
# al] episode:65,avg_a_R:0.33,avg_d_R:0.32,avg_t:3.95,avg_h:0.23,acc_A_R:29.91,acc_D_R:70.00,replay_s:-1,lr:0.
# al] episode:65,avg_a_R:0.33,avg_d_R:0.32,avg_t:3.95,avg_h:0.23,acc_A_R:29.91,acc_D_R:70.00,replay_s:-1,lr:0.
# al] episode:66,avg_a_R:0.34,avg_d_R:0.33,avg_t:3.97,avg_h:0.22,acc_A_R:30.91,acc_D_R:71.00,replay_s:-1,lr:0.
# al] episode:67,avg_a_R:0.37,avg_d_R:0.29,avg_t:4.09,avg_h:0.24,acc_A_R:33.53,acc_D_R:69.00,replay_s:-1,lr:0.
# al] episode:68,avg_a_R:0.35,avg_d_R:0.30,avg_t:4.06,avg_h:0.23,acc_A_R:32.53,acc_D_R:70.00,replay_s:-1,lr:0.
# al] episode:69,avg_a_R:0.33,avg_d_R:0.31,avg_t:4.03,avg_h:0.23,acc_A_R:31.53,acc_D_R:71.00,replay_s:-1,lr:0.
# al] episode:70,avg_a_R:0.37,avg_d_R:0.28,avg_t:4.07,avg_h:0.24,acc_A_R:34.78,acc_D_R:69.00,replay_s:-1,lr:0.
# al] episode:71,avg_a_R:0.35,avg_d_R:0.29,avg_t:4.04,avg_h:0.24,acc_A_R:33.78,acc_D_R:70.00,replay_s:-1,lr:0.
# al] episode:72,avg_a_R:0.33,avg_d_R:0.30,avg_t:4.03,avg_h:0.23,acc_A_R:32.78,acc_D_R:71.00,replay_s:-1,lr:0.
# al] episode:73,avg_a_R:0.32,avg_d_R:0.31,avg_t:3.99,avg_h:0.23,acc_A_R:31.78,acc_D_R:72.00,replay_s:-1,lr:0.
# al] episode:74,avg_a_R:0.30,avg_d_R:0.32,avg_t:3.96,avg_h:0.23,acc_A_R:30.78,acc_D_R:73.00,replay_s:-1,lr:0.
# al] episode:75,avg_a_R:0.28,avg_d_R:0.33,avg_t:3.93,avg_h:0.22,acc_A_R:29.78,acc_D_R:74.00,replay_s:-1,lr:0.
# al] episode:76,avg_a_R:0.33,avg_d_R:0.30,avg_t:3.92,avg_h:0.23,acc_A_R:33.78,acc_D_R:72.00,replay_s:-1,lr:0.
# al] episode:77,avg_a_R:0.31,avg_d_R:0.31,avg_t:3.88,avg_h:0.23,acc_A_R:32.78,acc_D_R:73.00,replay_s:-1,lr:0.
# al] episode:78,avg_a_R:0.31,avg_d_R:0.32,avg_t:4.00,avg_h:0.23,acc_A_R:32.98,acc_D_R:74.00,replay_s:-1,lr:0.
# al] episode:79,avg_a_R:0.30,avg_d_R:0.33,avg_t:3.98,avg_h:0.23,acc_A_R:31.98,acc_D_R:75.00,replay_s:-1,lr:0.
# al] episode:80,avg_a_R:0.30,avg_d_R:0.33,avg_t:3.99,avg_h:0.22,acc_A_R:32.98,acc_D_R:76.00,replay_s:-1,lr:0.
# al] episode:81,avg_a_R:0.29,avg_d_R:0.34,avg_t:3.95,avg_h:0.22,acc_A_R:31.98,acc_D_R:77.00,replay_s:-1,lr:0.
# al] episode:82,avg_a_R:0.29,avg_d_R:0.35,avg_t:4.07,avg_h:0.22,acc_A_R:32.11,acc_D_R:78.00,replay_s:-1,lr:0.
# al] episode:83,avg_a_R:0.27,avg_d_R:0.36,avg_t:4.04,avg_h:0.21,acc_A_R:31.11,acc_D_R:79.00,replay_s:-1,lr:0.
# al] episode:84,avg_a_R:0.26,avg_d_R:0.36,avg_t:4.00,avg_h:0.21,acc_A_R:30.11,acc_D_R:80.00,replay_s:-1,lr:0.
# al] episode:85,avg_a_R:0.24,avg_d_R:0.37,avg_t:3.97,avg_h:0.21,acc_A_R:29.11,acc_D_R:81.00,replay_s:-1,lr:0.
# al] episode:86,avg_a_R:0.23,avg_d_R:0.38,avg_t:3.98,avg_h:0.21,acc_A_R:28.11,acc_D_R:82.00,replay_s:-1,lr:0.
# al] episode:87,avg_a_R:0.21,avg_d_R:0.39,avg_t:4.01,avg_h:0.20,acc_A_R:27.11,acc_D_R:83.00,replay_s:-1,lr:0.
# al] episode:88,avg_a_R:0.20,avg_d_R:0.39,avg_t:4.01,avg_h:0.20,acc_A_R:26.11,acc_D_R:84.00,replay_s:-1,lr:0.
# al] episode:89,avg_a_R:0.19,avg_d_R:0.40,avg_t:4.00,avg_h:0.20,acc_A_R:25.11,acc_D_R:85.00,replay_s:-1,lr:0.
# al] episode:90,avg_a_R:0.22,avg_d_R:0.37,avg_t:4.09,avg_h:0.21,acc_A_R:28.22,acc_D_R:83.00,replay_s:-1,lr:0.
# al] episode:91,avg_a_R:0.21,avg_d_R:0.38,avg_t:4.07,avg_h:0.21,acc_A_R:27.22,acc_D_R:84.00,replay_s:-1,lr:0.
# al] episode:92,avg_a_R:0.19,avg_d_R:0.39,avg_t:4.03,avg_h:0.20,acc_A_R:26.22,acc_D_R:85.00,replay_s:-1,lr:0.
# al] episode:93,avg_a_R:0.23,avg_d_R:0.36,avg_t:4.04,avg_h:0.21,acc_A_R:29.55,acc_D_R:83.00,replay_s:-1,lr:0.
# al] episode:94,avg_a_R:0.26,avg_d_R:0.34,avg_t:4.04,avg_h:0.22,acc_A_R:33.05,acc_D_R:81.00,replay_s:-1,lr:0.
# al] episode:95,avg_a_R:0.25,avg_d_R:0.34,avg_t:4.02,avg_h:0.22,acc_A_R:32.05,acc_D_R:82.00,replay_s:-1,lr:0.
# al] episode:96,avg_a_R:0.25,avg_d_R:0.35,avg_t:4.06,avg_h:0.22,acc_A_R:32.55,acc_D_R:83.00,replay_s:-1,lr:0.
# al] episode:96,avg_a_R:0.25,avg_d_R:0.35,avg_t:4.06,avg_h:0.22,acc_A_R:32.55,acc_D_R:83.00,replay_s:-1,lr:0.
# al] episode:97,avg_a_R:0.24,avg_d_R:0.36,avg_t:4.03,avg_h:0.21,acc_A_R:31.55,acc_D_R:84.00,replay_s:-1,lr:0.
# al] episode:98,avg_a_R:0.22,avg_d_R:0.36,avg_t:4.01,avg_h:0.21,acc_A_R:30.55,acc_D_R:85.00,replay_s:-1,lr:0.
# al] episode:99,avg_a_R:0.21,avg_d_R:0.37,avg_t:4.01,avg_h:0.21,acc_A_R:29.55,acc_D_R:86.00,replay_s:-1,lr:0.
# starting eval with non-empty result objecta_R:-0.07,avg_d_R:0.70,avg_t:4.07,avg_h:0.10,acc_A_R:-126.90,acc_D_R:
#
# [Eval] episode:1000,avg_a_R:0.21,avg_d_R:0.37,avg_t:4.01,avg_h:0.21,acc_A_R:29.55,acc_D_R:86.00,replay_s:-1,lr:
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.00,avg_h:0.00,acc_A_R:28.55,acc_D_R:87.00,replay_s:-1,lr:0.
# al] episode:1,avg_a_R:-1.00,avg_d_R:1.00,avg_t:1.50,avg_h:0.00,acc_A_R:27.55,acc_D_R:88.00,replay_s:-1,lr:0.
# al] episode:2,avg_a_R:-1.00,avg_d_R:1.00,avg_t:2.67,avg_h:0.00,acc_A_R:26.55,acc_D_R:89.00,replay_s:-1,lr:0.
# al] episode:3,avg_a_R:0.25,avg_d_R:0.25,avg_t:2.50,avg_h:0.25,acc_A_R:30.55,acc_D_R:87.00,replay_s:-1,lr:0.0
# al] episode:4,avg_a_R:0.30,avg_d_R:0.40,avg_t:2.80,avg_h:0.20,acc_A_R:31.05,acc_D_R:88.00,replay_s:-1,lr:0.0
# al] episode:5,avg_a_R:0.27,avg_d_R:0.50,avg_t:4.00,avg_h:0.17,acc_A_R:31.19,acc_D_R:89.00,replay_s:-1,lr:0.0
# al] episode:6,avg_a_R:0.38,avg_d_R:0.57,avg_t:4.00,avg_h:0.14,acc_A_R:32.19,acc_D_R:90.00,replay_s:-1,lr:0.0
# al] episode:7,avg_a_R:0.46,avg_d_R:0.62,avg_t:4.25,avg_h:0.12,acc_A_R:33.19,acc_D_R:91.00,replay_s:-1,lr:0.0
# al] episode:8,avg_a_R:0.29,avg_d_R:0.67,avg_t:4.00,avg_h:0.11,acc_A_R:32.19,acc_D_R:92.00,replay_s:-1,lr:0.0
# al] episode:9,avg_a_R:0.53,avg_d_R:0.40,avg_t:4.80,avg_h:0.20,acc_A_R:34.82,acc_D_R:90.00,replay_s:-1,lr:0.0
# al] episode:10,avg_a_R:0.39,avg_d_R:0.45,avg_t:4.45,avg_h:0.18,acc_A_R:33.82,acc_D_R:91.00,replay_s:-1,lr:0.
# al] episode:11,avg_a_R:0.27,avg_d_R:0.50,avg_t:4.17,avg_h:0.17,acc_A_R:32.82,acc_D_R:92.00,replay_s:-1,lr:0.
# al] episode:12,avg_a_R:0.17,avg_d_R:0.54,avg_t:3.92,avg_h:0.15,acc_A_R:31.82,acc_D_R:93.00,replay_s:-1,lr:0.
# al] episode:13,avg_a_R:0.09,avg_d_R:0.57,avg_t:3.71,avg_h:0.14,acc_A_R:30.82,acc_D_R:94.00,replay_s:-1,lr:0.
# al] episode:14,avg_a_R:0.25,avg_d_R:0.40,avg_t:4.20,avg_h:0.20,acc_A_R:33.32,acc_D_R:92.00,replay_s:-1,lr:0.
# al] episode:15,avg_a_R:0.30,avg_d_R:0.44,avg_t:4.38,avg_h:0.19,acc_A_R:34.32,acc_D_R:93.00,replay_s:-1,lr:0.
# al] episode:16,avg_a_R:0.22,avg_d_R:0.47,avg_t:4.35,avg_h:0.18,acc_A_R:33.32,acc_D_R:94.00,replay_s:-1,lr:0.
# al] episode:17,avg_a_R:0.39,avg_d_R:0.33,avg_t:4.44,avg_h:0.22,acc_A_R:36.65,acc_D_R:92.00,replay_s:-1,lr:0.
# al] episode:18,avg_a_R:0.32,avg_d_R:0.37,avg_t:4.37,avg_h:0.21,acc_A_R:35.65,acc_D_R:93.00,replay_s:-1,lr:0.
# al] episode:19,avg_a_R:0.26,avg_d_R:0.40,avg_t:4.30,avg_h:0.20,acc_A_R:34.65,acc_D_R:94.00,replay_s:-1,lr:0.
# al] episode:20,avg_a_R:0.20,avg_d_R:0.43,avg_t:4.52,avg_h:0.19,acc_A_R:33.65,acc_D_R:95.00,replay_s:-1,lr:0.
# al] episode:21,avg_a_R:0.14,avg_d_R:0.45,avg_t:4.41,avg_h:0.18,acc_A_R:32.65,acc_D_R:96.00,replay_s:-1,lr:0.
# al] episode:22,avg_a_R:0.18,avg_d_R:0.48,avg_t:4.57,avg_h:0.17,acc_A_R:33.65,acc_D_R:97.00,replay_s:-1,lr:0.
# al] episode:23,avg_a_R:0.13,avg_d_R:0.50,avg_t:4.50,avg_h:0.17,acc_A_R:32.65,acc_D_R:98.00,replay_s:-1,lr:0.
# al] episode:24,avg_a_R:0.08,avg_d_R:0.52,avg_t:4.40,avg_h:0.16,acc_A_R:31.65,acc_D_R:99.00,replay_s:-1,lr:0.
# al] episode:25,avg_a_R:0.04,avg_d_R:0.54,avg_t:4.27,avg_h:0.15,acc_A_R:30.65,acc_D_R:100.00,replay_s:-1,lr:0
# al] episode:26,avg_a_R:0.08,avg_d_R:0.56,avg_t:4.30,avg_h:0.15,acc_A_R:31.65,acc_D_R:101.00,replay_s:-1,lr:0
# al] episode:27,avg_a_R:0.04,avg_d_R:0.57,avg_t:4.29,avg_h:0.14,acc_A_R:30.65,acc_D_R:102.00,replay_s:-1,lr:0
# al] episode:28,avg_a_R:0.00,avg_d_R:0.59,avg_t:4.17,avg_h:0.14,acc_A_R:29.65,acc_D_R:103.00,replay_s:-1,lr:0
# al] episode:29,avg_a_R:0.14,avg_d_R:0.50,avg_t:4.13,avg_h:0.17,acc_A_R:33.65,acc_D_R:101.00,replay_s:-1,lr:0
# al] episode:30,avg_a_R:0.21,avg_d_R:0.42,avg_t:4.58,avg_h:0.19,acc_A_R:35.92,acc_D_R:99.00,replay_s:-1,lr:0.
# al] episode:30,avg_a_R:0.21,avg_d_R:0.42,avg_t:4.58,avg_h:0.19,acc_A_R:35.92,acc_D_R:99.00,replay_s:-1,lr:0.
# al] episode:31,avg_a_R:0.17,avg_d_R:0.44,avg_t:4.62,avg_h:0.19,acc_A_R:34.92,acc_D_R:100.00,replay_s:-1,lr:0
# al] episode:32,avg_a_R:0.13,avg_d_R:0.45,avg_t:4.61,avg_h:0.18,acc_A_R:33.92,acc_D_R:101.00,replay_s:-1,lr:0
# al] episode:33,avg_a_R:0.10,avg_d_R:0.47,avg_t:4.62,avg_h:0.18,acc_A_R:32.92,acc_D_R:102.00,replay_s:-1,lr:0
# al] episode:34,avg_a_R:0.07,avg_d_R:0.49,avg_t:4.74,avg_h:0.17,acc_A_R:31.92,acc_D_R:103.00,replay_s:-1,lr:0
# al] episode:35,avg_a_R:0.04,avg_d_R:0.50,avg_t:4.69,avg_h:0.17,acc_A_R:30.92,acc_D_R:104.00,replay_s:-1,lr:0
# al] episode:36,avg_a_R:0.04,avg_d_R:0.51,avg_t:4.73,avg_h:0.16,acc_A_R:31.17,acc_D_R:105.00,replay_s:-1,lr:0
# al] episode:37,avg_a_R:0.02,avg_d_R:0.53,avg_t:4.71,avg_h:0.16,acc_A_R:30.17,acc_D_R:106.00,replay_s:-1,lr:0
# al] episode:38,avg_a_R:-0.01,avg_d_R:0.54,avg_t:4.67,avg_h:0.15,acc_A_R:29.17,acc_D_R:107.00,replay_s:-1,lr:
# al] episode:39,avg_a_R:0.09,avg_d_R:0.47,avg_t:4.62,avg_h:0.17,acc_A_R:33.17,acc_D_R:105.00,replay_s:-1,lr:0
# al] episode:40,avg_a_R:0.16,avg_d_R:0.41,avg_t:4.66,avg_h:0.20,acc_A_R:36.17,acc_D_R:103.00,replay_s:-1,lr:0
# al] episode:41,avg_a_R:0.13,avg_d_R:0.43,avg_t:4.57,avg_h:0.19,acc_A_R:35.17,acc_D_R:104.00,replay_s:-1,lr:0
# al] episode:42,avg_a_R:0.20,avg_d_R:0.37,avg_t:4.67,avg_h:0.21,acc_A_R:38.31,acc_D_R:102.00,replay_s:-1,lr:0
# al] episode:43,avg_a_R:0.21,avg_d_R:0.39,avg_t:4.75,avg_h:0.20,acc_A_R:38.81,acc_D_R:103.00,replay_s:-1,lr:0
# al] episode:44,avg_a_R:0.28,avg_d_R:0.33,avg_t:4.73,avg_h:0.22,acc_A_R:42.31,acc_D_R:101.00,replay_s:-1,lr:0
# al] episode:45,avg_a_R:0.26,avg_d_R:0.35,avg_t:4.65,avg_h:0.22,acc_A_R:41.31,acc_D_R:102.00,replay_s:-1,lr:0
# al] episode:46,avg_a_R:0.23,avg_d_R:0.36,avg_t:4.57,avg_h:0.21,acc_A_R:40.31,acc_D_R:103.00,replay_s:-1,lr:0
# al] episode:47,avg_a_R:0.20,avg_d_R:0.38,avg_t:4.52,avg_h:0.21,acc_A_R:39.31,acc_D_R:104.00,replay_s:-1,lr:0
# al] episode:48,avg_a_R:0.18,avg_d_R:0.39,avg_t:4.45,avg_h:0.20,acc_A_R:38.31,acc_D_R:105.00,replay_s:-1,lr:0
# al] episode:49,avg_a_R:0.20,avg_d_R:0.40,avg_t:4.42,avg_h:0.20,acc_A_R:39.31,acc_D_R:106.00,replay_s:-1,lr:0
# al] episode:50,avg_a_R:0.17,avg_d_R:0.41,avg_t:4.35,avg_h:0.20,acc_A_R:38.31,acc_D_R:107.00,replay_s:-1,lr:0
# al] episode:51,avg_a_R:0.19,avg_d_R:0.42,avg_t:4.31,avg_h:0.19,acc_A_R:39.31,acc_D_R:108.00,replay_s:-1,lr:0
# al] episode:52,avg_a_R:0.17,avg_d_R:0.43,avg_t:4.25,avg_h:0.19,acc_A_R:38.31,acc_D_R:109.00,replay_s:-1,lr:0
# al] episode:53,avg_a_R:0.18,avg_d_R:0.44,avg_t:4.24,avg_h:0.19,acc_A_R:39.31,acc_D_R:110.00,replay_s:-1,lr:0
# al] episode:54,avg_a_R:0.16,avg_d_R:0.45,avg_t:4.33,avg_h:0.18,acc_A_R:38.31,acc_D_R:111.00,replay_s:-1,lr:0
# al] episode:55,avg_a_R:0.16,avg_d_R:0.46,avg_t:4.52,avg_h:0.18,acc_A_R:38.56,acc_D_R:112.00,replay_s:-1,lr:0
# al] episode:56,avg_a_R:0.14,avg_d_R:0.47,avg_t:4.49,avg_h:0.18,acc_A_R:37.56,acc_D_R:113.00,replay_s:-1,lr:0
# al] episode:57,avg_a_R:0.12,avg_d_R:0.48,avg_t:4.48,avg_h:0.17,acc_A_R:36.56,acc_D_R:114.00,replay_s:-1,lr:0
# al] episode:58,avg_a_R:0.10,avg_d_R:0.49,avg_t:4.42,avg_h:0.17,acc_A_R:35.56,acc_D_R:115.00,replay_s:-1,lr:0
# al] episode:59,avg_a_R:0.08,avg_d_R:0.50,avg_t:4.47,avg_h:0.17,acc_A_R:34.56,acc_D_R:116.00,replay_s:-1,lr:0
# al] episode:60,avg_a_R:0.07,avg_d_R:0.51,avg_t:4.44,avg_h:0.16,acc_A_R:33.56,acc_D_R:117.00,replay_s:-1,lr:0
# al] episode:60,avg_a_R:0.07,avg_d_R:0.51,avg_t:4.44,avg_h:0.16,acc_A_R:33.56,acc_D_R:117.00,replay_s:-1,lr:0
# al] episode:61,avg_a_R:0.08,avg_d_R:0.52,avg_t:4.44,avg_h:0.16,acc_A_R:34.56,acc_D_R:118.00,replay_s:-1,lr:0
# al] episode:62,avg_a_R:0.14,avg_d_R:0.48,avg_t:4.44,avg_h:0.17,acc_A_R:38.06,acc_D_R:116.00,replay_s:-1,lr:0
# al] episode:63,avg_a_R:0.12,avg_d_R:0.48,avg_t:4.44,avg_h:0.17,acc_A_R:37.06,acc_D_R:117.00,replay_s:-1,lr:0
# al] episode:64,avg_a_R:0.10,avg_d_R:0.49,avg_t:4.38,avg_h:0.17,acc_A_R:36.06,acc_D_R:118.00,replay_s:-1,lr:0
# al] episode:65,avg_a_R:0.08,avg_d_R:0.50,avg_t:4.35,avg_h:0.17,acc_A_R:35.06,acc_D_R:119.00,replay_s:-1,lr:0
# al] episode:66,avg_a_R:0.07,avg_d_R:0.51,avg_t:4.33,avg_h:0.16,acc_A_R:34.06,acc_D_R:120.00,replay_s:-1,lr:0
# al] episode:67,avg_a_R:0.05,avg_d_R:0.51,avg_t:4.31,avg_h:0.16,acc_A_R:33.06,acc_D_R:121.00,replay_s:-1,lr:0
# al] episode:68,avg_a_R:0.07,avg_d_R:0.52,avg_t:4.29,avg_h:0.16,acc_A_R:34.06,acc_D_R:122.00,replay_s:-1,lr:0
# al] episode:69,avg_a_R:0.05,avg_d_R:0.53,avg_t:4.24,avg_h:0.16,acc_A_R:33.06,acc_D_R:123.00,replay_s:-1,lr:0
# al] episode:70,avg_a_R:0.04,avg_d_R:0.54,avg_t:4.23,avg_h:0.15,acc_A_R:32.06,acc_D_R:124.00,replay_s:-1,lr:0
# al] episode:71,avg_a_R:0.05,avg_d_R:0.54,avg_t:4.21,avg_h:0.15,acc_A_R:33.06,acc_D_R:125.00,replay_s:-1,lr:0
# al] episode:72,avg_a_R:0.03,avg_d_R:0.55,avg_t:4.22,avg_h:0.15,acc_A_R:32.06,acc_D_R:126.00,replay_s:-1,lr:0
# al] episode:73,avg_a_R:0.05,avg_d_R:0.55,avg_t:4.22,avg_h:0.15,acc_A_R:33.06,acc_D_R:127.00,replay_s:-1,lr:0
# al] episode:74,avg_a_R:0.03,avg_d_R:0.56,avg_t:4.17,avg_h:0.15,acc_A_R:32.06,acc_D_R:128.00,replay_s:-1,lr:0
# al] episode:75,avg_a_R:0.02,avg_d_R:0.57,avg_t:4.16,avg_h:0.14,acc_A_R:31.06,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:76,avg_a_R:0.06,avg_d_R:0.53,avg_t:4.19,avg_h:0.16,acc_A_R:33.90,acc_D_R:127.00,replay_s:-1,lr:0
# al] episode:77,avg_a_R:0.04,avg_d_R:0.54,avg_t:4.19,avg_h:0.15,acc_A_R:32.90,acc_D_R:128.00,replay_s:-1,lr:0
# al] episode:78,avg_a_R:0.03,avg_d_R:0.54,avg_t:4.16,avg_h:0.15,acc_A_R:31.90,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:79,avg_a_R:0.03,avg_d_R:0.55,avg_t:4.30,avg_h:0.15,acc_A_R:32.02,acc_D_R:130.00,replay_s:-1,lr:0
# al] episode:80,avg_a_R:0.07,avg_d_R:0.52,avg_t:4.31,avg_h:0.16,acc_A_R:35.52,acc_D_R:128.00,replay_s:-1,lr:0
# al] episode:81,avg_a_R:0.06,avg_d_R:0.52,avg_t:4.27,avg_h:0.16,acc_A_R:34.52,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:82,avg_a_R:0.05,avg_d_R:0.53,avg_t:4.24,avg_h:0.16,acc_A_R:33.52,acc_D_R:130.00,replay_s:-1,lr:0
# al] episode:83,avg_a_R:0.09,avg_d_R:0.50,avg_t:4.24,avg_h:0.17,acc_A_R:37.02,acc_D_R:128.00,replay_s:-1,lr:0
# al] episode:84,avg_a_R:0.08,avg_d_R:0.51,avg_t:4.21,avg_h:0.16,acc_A_R:36.02,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:85,avg_a_R:0.06,avg_d_R:0.51,avg_t:4.19,avg_h:0.16,acc_A_R:35.02,acc_D_R:130.00,replay_s:-1,lr:0
# al] episode:86,avg_a_R:0.05,avg_d_R:0.52,avg_t:4.16,avg_h:0.16,acc_A_R:34.02,acc_D_R:131.00,replay_s:-1,lr:0
# al] episode:87,avg_a_R:0.08,avg_d_R:0.49,avg_t:4.27,avg_h:0.17,acc_A_R:36.46,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:88,avg_a_R:0.10,avg_d_R:0.46,avg_t:4.44,avg_h:0.18,acc_A_R:38.75,acc_D_R:127.00,replay_s:-1,lr:0
# al] episode:89,avg_a_R:0.09,avg_d_R:0.47,avg_t:4.40,avg_h:0.18,acc_A_R:37.75,acc_D_R:128.00,replay_s:-1,lr:0
# al] episode:90,avg_a_R:0.08,avg_d_R:0.47,avg_t:4.36,avg_h:0.18,acc_A_R:36.75,acc_D_R:129.00,replay_s:-1,lr:0
# al] episode:91,avg_a_R:0.09,avg_d_R:0.48,avg_t:4.38,avg_h:0.17,acc_A_R:37.75,acc_D_R:130.00,replay_s:-1,lr:0
# al] episode:92,avg_a_R:0.09,avg_d_R:0.48,avg_t:4.43,avg_h:0.17,acc_A_R:37.95,acc_D_R:131.00,replay_s:-1,lr:0
# al] episode:92,avg_a_R:0.09,avg_d_R:0.48,avg_t:4.43,avg_h:0.17,acc_A_R:37.95,acc_D_R:131.00,replay_s:-1,lr:0
# al] episode:93,avg_a_R:0.08,avg_d_R:0.49,avg_t:4.39,avg_h:0.17,acc_A_R:36.95,acc_D_R:132.00,replay_s:-1,lr:0
# al] episode:94,avg_a_R:0.10,avg_d_R:0.46,avg_t:4.46,avg_h:0.18,acc_A_R:39.45,acc_D_R:130.00,replay_s:-1,lr:0
# al] episode:95,avg_a_R:0.09,avg_d_R:0.47,avg_t:4.46,avg_h:0.18,acc_A_R:38.45,acc_D_R:131.00,replay_s:-1,lr:0
# al] episode:96,avg_a_R:0.09,avg_d_R:0.47,avg_t:4.48,avg_h:0.18,acc_A_R:38.65,acc_D_R:132.00,replay_s:-1,lr:0
# al] episode:97,avg_a_R:0.09,avg_d_R:0.48,avg_t:4.52,avg_h:0.17,acc_A_R:38.85,acc_D_R:133.00,replay_s:-1,lr:0
# al] episode:98,avg_a_R:0.08,avg_d_R:0.48,avg_t:4.48,avg_h:0.17,acc_A_R:37.85,acc_D_R:134.00,replay_s:-1,lr:0
# al] episode:99,avg_a_R:0.09,avg_d_R:0.49,avg_t:4.49,avg_h:0.17,acc_A_R:38.18,acc_D_R:135.00,replay_s:-1,lr:0
# starting eval with non-empty result objecta_R:-0.14,avg_d_R:0.67,avg_t:4.25,avg_h:0.11,acc_A_R:-260.69,acc_D_R:
#
# [Eval] episode:2000,avg_a_R:0.09,avg_d_R:0.49,avg_t:4.49,avg_h:0.17,acc_A_R:38.18,acc_D_R:135.00,replay_s:-1,lr
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:1.00,avg_d_R:1.00,avg_t:2.00,avg_h:0.00,acc_A_R:39.18,acc_D_R:136.00,replay_s:-1,lr:0.
# al] episode:1,avg_a_R:2.08,avg_d_R:-0.50,avg_t:5.00,avg_h:0.50,acc_A_R:42.35,acc_D_R:134.00,replay_s:-1,lr:0
# al] episode:2,avg_a_R:1.06,avg_d_R:0.00,avg_t:6.00,avg_h:0.33,acc_A_R:41.35,acc_D_R:135.00,replay_s:-1,lr:0.
# al] episode:3,avg_a_R:1.57,avg_d_R:-0.50,avg_t:7.00,avg_h:0.50,acc_A_R:44.47,acc_D_R:133.00,replay_s:-1,lr:0
# al] episode:4,avg_a_R:1.06,avg_d_R:-0.20,avg_t:6.40,avg_h:0.40,acc_A_R:43.47,acc_D_R:134.00,replay_s:-1,lr:0
# al] episode:5,avg_a_R:0.91,avg_d_R:0.00,avg_t:7.00,avg_h:0.33,acc_A_R:43.62,acc_D_R:135.00,replay_s:-1,lr:0.
# al] episode:6,avg_a_R:1.28,avg_d_R:-0.29,avg_t:6.57,avg_h:0.43,acc_A_R:47.12,acc_D_R:133.00,replay_s:-1,lr:0
# al] episode:7,avg_a_R:0.99,avg_d_R:-0.12,avg_t:6.25,avg_h:0.38,acc_A_R:46.12,acc_D_R:134.00,replay_s:-1,lr:0
# al] episode:8,avg_a_R:1.24,avg_d_R:-0.33,avg_t:6.22,avg_h:0.44,acc_A_R:49.37,acc_D_R:132.00,replay_s:-1,lr:0
# al] episode:9,avg_a_R:1.02,avg_d_R:-0.20,avg_t:6.30,avg_h:0.40,acc_A_R:48.37,acc_D_R:133.00,replay_s:-1,lr:0
# al] episode:10,avg_a_R:1.13,avg_d_R:-0.36,avg_t:7.36,avg_h:0.45,acc_A_R:50.63,acc_D_R:131.00,replay_s:-1,lr:
# al] episode:11,avg_a_R:0.95,avg_d_R:-0.25,avg_t:6.83,avg_h:0.42,acc_A_R:49.63,acc_D_R:132.00,replay_s:-1,lr:
# al] episode:12,avg_a_R:0.80,avg_d_R:-0.15,avg_t:6.62,avg_h:0.38,acc_A_R:48.63,acc_D_R:133.00,replay_s:-1,lr:
# al] episode:13,avg_a_R:0.68,avg_d_R:-0.07,avg_t:6.36,avg_h:0.36,acc_A_R:47.63,acc_D_R:134.00,replay_s:-1,lr:
# al] episode:14,avg_a_R:0.56,avg_d_R:0.00,avg_t:6.13,avg_h:0.33,acc_A_R:46.63,acc_D_R:135.00,replay_s:-1,lr:0
# al] episode:15,avg_a_R:0.73,avg_d_R:-0.12,avg_t:6.19,avg_h:0.38,acc_A_R:49.83,acc_D_R:133.00,replay_s:-1,lr:
# al] episode:16,avg_a_R:0.74,avg_d_R:-0.06,avg_t:6.41,avg_h:0.35,acc_A_R:50.83,acc_D_R:134.00,replay_s:-1,lr:
# al] episode:17,avg_a_R:0.72,avg_d_R:0.00,avg_t:6.33,avg_h:0.33,acc_A_R:51.17,acc_D_R:135.00,replay_s:-1,lr:0
# al] episode:18,avg_a_R:0.63,avg_d_R:0.05,avg_t:6.05,avg_h:0.32,acc_A_R:50.17,acc_D_R:136.00,replay_s:-1,lr:0
# al] episode:19,avg_a_R:0.65,avg_d_R:0.10,avg_t:5.90,avg_h:0.30,acc_A_R:51.17,acc_D_R:137.00,replay_s:-1,lr:0
# al] episode:20,avg_a_R:0.67,avg_d_R:0.14,avg_t:5.95,avg_h:0.29,acc_A_R:52.17,acc_D_R:138.00,replay_s:-1,lr:0
# al] episode:21,avg_a_R:0.59,avg_d_R:0.18,avg_t:5.73,avg_h:0.27,acc_A_R:51.17,acc_D_R:139.00,replay_s:-1,lr:0
# al] episode:22,avg_a_R:0.52,avg_d_R:0.22,avg_t:5.57,avg_h:0.26,acc_A_R:50.17,acc_D_R:140.00,replay_s:-1,lr:0
# al] episode:23,avg_a_R:0.46,avg_d_R:0.25,avg_t:5.38,avg_h:0.25,acc_A_R:49.17,acc_D_R:141.00,replay_s:-1,lr:0
# al] episode:24,avg_a_R:0.48,avg_d_R:0.28,avg_t:5.32,avg_h:0.24,acc_A_R:50.17,acc_D_R:142.00,replay_s:-1,lr:0
# al] episode:25,avg_a_R:0.42,avg_d_R:0.31,avg_t:5.15,avg_h:0.23,acc_A_R:49.17,acc_D_R:143.00,replay_s:-1,lr:0
# al] episode:26,avg_a_R:0.37,avg_d_R:0.33,avg_t:5.04,avg_h:0.22,acc_A_R:48.17,acc_D_R:144.00,replay_s:-1,lr:0
# al] episode:27,avg_a_R:0.37,avg_d_R:0.36,avg_t:5.11,avg_h:0.21,acc_A_R:48.42,acc_D_R:145.00,replay_s:-1,lr:0
# al] episode:27,avg_a_R:0.37,avg_d_R:0.36,avg_t:5.11,avg_h:0.21,acc_A_R:48.42,acc_D_R:145.00,replay_s:-1,lr:0
# al] episode:28,avg_a_R:0.32,avg_d_R:0.38,avg_t:4.97,avg_h:0.21,acc_A_R:47.42,acc_D_R:146.00,replay_s:-1,lr:0
# al] episode:29,avg_a_R:0.27,avg_d_R:0.40,avg_t:4.97,avg_h:0.20,acc_A_R:46.42,acc_D_R:147.00,replay_s:-1,lr:0
# al] episode:30,avg_a_R:0.23,avg_d_R:0.42,avg_t:4.87,avg_h:0.19,acc_A_R:45.42,acc_D_R:148.00,replay_s:-1,lr:0
# al] episode:31,avg_a_R:0.19,avg_d_R:0.44,avg_t:4.97,avg_h:0.19,acc_A_R:44.42,acc_D_R:149.00,replay_s:-1,lr:0
# al] episode:32,avg_a_R:0.16,avg_d_R:0.45,avg_t:4.94,avg_h:0.18,acc_A_R:43.42,acc_D_R:150.00,replay_s:-1,lr:0
# al] episode:33,avg_a_R:0.16,avg_d_R:0.47,avg_t:5.21,avg_h:0.18,acc_A_R:43.62,acc_D_R:151.00,replay_s:-1,lr:0
# al] episode:34,avg_a_R:0.27,avg_d_R:0.40,avg_t:5.14,avg_h:0.20,acc_A_R:47.62,acc_D_R:149.00,replay_s:-1,lr:0
# al] episode:35,avg_a_R:0.29,avg_d_R:0.42,avg_t:5.08,avg_h:0.19,acc_A_R:48.62,acc_D_R:150.00,replay_s:-1,lr:0
# al] episode:36,avg_a_R:0.39,avg_d_R:0.35,avg_t:5.03,avg_h:0.22,acc_A_R:52.62,acc_D_R:148.00,replay_s:-1,lr:0
# al] episode:37,avg_a_R:0.39,avg_d_R:0.37,avg_t:5.13,avg_h:0.21,acc_A_R:52.87,acc_D_R:149.00,replay_s:-1,lr:0
# al] episode:38,avg_a_R:0.35,avg_d_R:0.38,avg_t:5.08,avg_h:0.21,acc_A_R:51.87,acc_D_R:150.00,replay_s:-1,lr:0
# al] episode:39,avg_a_R:0.32,avg_d_R:0.40,avg_t:5.08,avg_h:0.20,acc_A_R:50.87,acc_D_R:151.00,replay_s:-1,lr:0
# al] episode:40,avg_a_R:0.33,avg_d_R:0.41,avg_t:5.15,avg_h:0.20,acc_A_R:51.87,acc_D_R:152.00,replay_s:-1,lr:0
# al] episode:41,avg_a_R:0.30,avg_d_R:0.43,avg_t:5.19,avg_h:0.19,acc_A_R:50.87,acc_D_R:153.00,replay_s:-1,lr:0
# al] episode:42,avg_a_R:0.27,avg_d_R:0.44,avg_t:5.12,avg_h:0.19,acc_A_R:49.87,acc_D_R:154.00,replay_s:-1,lr:0
# al] episode:43,avg_a_R:0.27,avg_d_R:0.45,avg_t:5.25,avg_h:0.18,acc_A_R:50.07,acc_D_R:155.00,replay_s:-1,lr:0
# al] episode:44,avg_a_R:0.24,avg_d_R:0.47,avg_t:5.16,avg_h:0.18,acc_A_R:49.07,acc_D_R:156.00,replay_s:-1,lr:0
# al] episode:45,avg_a_R:0.21,avg_d_R:0.48,avg_t:5.13,avg_h:0.17,acc_A_R:48.07,acc_D_R:157.00,replay_s:-1,lr:0
# al] episode:46,avg_a_R:0.19,avg_d_R:0.49,avg_t:5.04,avg_h:0.17,acc_A_R:47.07,acc_D_R:158.00,replay_s:-1,lr:0
# al] episode:47,avg_a_R:0.16,avg_d_R:0.50,avg_t:5.00,avg_h:0.17,acc_A_R:46.07,acc_D_R:159.00,replay_s:-1,lr:0
# al] episode:48,avg_a_R:0.22,avg_d_R:0.45,avg_t:5.06,avg_h:0.18,acc_A_R:48.82,acc_D_R:157.00,replay_s:-1,lr:0
# al] episode:49,avg_a_R:0.22,avg_d_R:0.46,avg_t:5.08,avg_h:0.18,acc_A_R:49.32,acc_D_R:158.00,replay_s:-1,lr:0
# al] episode:50,avg_a_R:0.20,avg_d_R:0.47,avg_t:5.00,avg_h:0.18,acc_A_R:48.32,acc_D_R:159.00,replay_s:-1,lr:0
# al] episode:51,avg_a_R:0.21,avg_d_R:0.48,avg_t:4.96,avg_h:0.17,acc_A_R:49.32,acc_D_R:160.00,replay_s:-1,lr:0
# al] episode:52,avg_a_R:0.19,avg_d_R:0.49,avg_t:4.96,avg_h:0.17,acc_A_R:48.32,acc_D_R:161.00,replay_s:-1,lr:0
# al] episode:53,avg_a_R:0.17,avg_d_R:0.50,avg_t:4.98,avg_h:0.17,acc_A_R:47.32,acc_D_R:162.00,replay_s:-1,lr:0
# al] episode:54,avg_a_R:0.18,avg_d_R:0.51,avg_t:4.95,avg_h:0.16,acc_A_R:48.32,acc_D_R:163.00,replay_s:-1,lr:0
# al] episode:55,avg_a_R:0.16,avg_d_R:0.52,avg_t:4.89,avg_h:0.16,acc_A_R:47.32,acc_D_R:164.00,replay_s:-1,lr:0
# al] episode:55,avg_a_R:0.16,avg_d_R:0.52,avg_t:4.89,avg_h:0.16,acc_A_R:47.32,acc_D_R:164.00,replay_s:-1,lr:0
# al] episode:56,avg_a_R:0.14,avg_d_R:0.53,avg_t:4.82,avg_h:0.16,acc_A_R:46.32,acc_D_R:165.00,replay_s:-1,lr:0
# al] episode:57,avg_a_R:0.14,avg_d_R:0.53,avg_t:4.93,avg_h:0.16,acc_A_R:46.44,acc_D_R:166.00,replay_s:-1,lr:0
# al] episode:58,avg_a_R:0.16,avg_d_R:0.54,avg_t:4.92,avg_h:0.15,acc_A_R:47.44,acc_D_R:167.00,replay_s:-1,lr:0
# al] episode:59,avg_a_R:0.22,avg_d_R:0.50,avg_t:4.87,avg_h:0.17,acc_A_R:51.44,acc_D_R:165.00,replay_s:-1,lr:0
# al] episode:60,avg_a_R:0.28,avg_d_R:0.46,avg_t:4.82,avg_h:0.18,acc_A_R:55.44,acc_D_R:163.00,replay_s:-1,lr:0
# al] episode:61,avg_a_R:0.34,avg_d_R:0.42,avg_t:4.79,avg_h:0.19,acc_A_R:59.44,acc_D_R:161.00,replay_s:-1,lr:0
# al] episode:62,avg_a_R:0.32,avg_d_R:0.43,avg_t:4.73,avg_h:0.19,acc_A_R:58.44,acc_D_R:162.00,replay_s:-1,lr:0
# al] episode:63,avg_a_R:0.30,avg_d_R:0.44,avg_t:4.70,avg_h:0.19,acc_A_R:57.44,acc_D_R:163.00,replay_s:-1,lr:0
# ...
# al] episode:68,avg_a_R:-0.38,avg_d_R:0.74,avg_t:4.29,avg_h:0.09,acc_A_R:247.68,acc_D_R:940.00,replay_s:-1,lr
# al] episode:69,avg_a_R:-0.32,avg_d_R:0.70,avg_t:4.27,avg_h:0.10,acc_A_R:251.68,acc_D_R:938.00,replay_s:-1,lr
# al] episode:70,avg_a_R:-0.33,avg_d_R:0.70,avg_t:4.25,avg_h:0.10,acc_A_R:250.68,acc_D_R:939.00,replay_s:-1,lr
# al] episode:71,avg_a_R:-0.34,avg_d_R:0.71,avg_t:4.22,avg_h:0.10,acc_A_R:249.68,acc_D_R:940.00,replay_s:-1,lr
# al] episode:72,avg_a_R:-0.29,avg_d_R:0.67,avg_t:4.25,avg_h:0.11,acc_A_R:252.93,acc_D_R:938.00,replay_s:-1,lr
# al] episode:73,avg_a_R:-0.30,avg_d_R:0.68,avg_t:4.20,avg_h:0.11,acc_A_R:251.93,acc_D_R:939.00,replay_s:-1,lr
# al] episode:74,avg_a_R:-0.31,avg_d_R:0.68,avg_t:4.20,avg_h:0.11,acc_A_R:250.93,acc_D_R:940.00,replay_s:-1,lr
# al] episode:75,avg_a_R:-0.30,avg_d_R:0.68,avg_t:4.24,avg_h:0.11,acc_A_R:251.13,acc_D_R:941.00,replay_s:-1,lr
# al] episode:76,avg_a_R:-0.31,avg_d_R:0.69,avg_t:4.22,avg_h:0.10,acc_A_R:250.13,acc_D_R:942.00,replay_s:-1,lr
# al] episode:77,avg_a_R:-0.30,avg_d_R:0.69,avg_t:4.23,avg_h:0.10,acc_A_R:251.13,acc_D_R:943.00,replay_s:-1,lr
# al] episode:78,avg_a_R:-0.31,avg_d_R:0.70,avg_t:4.22,avg_h:0.10,acc_A_R:250.13,acc_D_R:944.00,replay_s:-1,lr
# al] episode:79,avg_a_R:-0.29,avg_d_R:0.70,avg_t:4.20,avg_h:0.10,acc_A_R:251.13,acc_D_R:945.00,replay_s:-1,lr
# al] episode:80,avg_a_R:-0.30,avg_d_R:0.70,avg_t:4.17,avg_h:0.10,acc_A_R:250.13,acc_D_R:946.00,replay_s:-1,lr
# al] episode:81,avg_a_R:-0.31,avg_d_R:0.71,avg_t:4.20,avg_h:0.10,acc_A_R:249.13,acc_D_R:947.00,replay_s:-1,lr
# al] episode:82,avg_a_R:-0.29,avg_d_R:0.71,avg_t:4.17,avg_h:0.10,acc_A_R:250.13,acc_D_R:948.00,replay_s:-1,lr
# al] episode:83,avg_a_R:-0.30,avg_d_R:0.71,avg_t:4.14,avg_h:0.10,acc_A_R:249.13,acc_D_R:949.00,replay_s:-1,lr
# al] episode:84,avg_a_R:-0.31,avg_d_R:0.72,avg_t:4.14,avg_h:0.09,acc_A_R:248.13,acc_D_R:950.00,replay_s:-1,lr
# al] episode:85,avg_a_R:-0.29,avg_d_R:0.72,avg_t:4.17,avg_h:0.09,acc_A_R:249.13,acc_D_R:951.00,replay_s:-1,lr
# al] episode:85,avg_a_R:-0.29,avg_d_R:0.72,avg_t:4.17,avg_h:0.09,acc_A_R:249.13,acc_D_R:951.00,replay_s:-1,lr
# al] episode:86,avg_a_R:-0.30,avg_d_R:0.72,avg_t:4.14,avg_h:0.09,acc_A_R:248.13,acc_D_R:952.00,replay_s:-1,lr
# al] episode:87,avg_a_R:-0.31,avg_d_R:0.73,avg_t:4.11,avg_h:0.09,acc_A_R:247.13,acc_D_R:953.00,replay_s:-1,lr
# al] episode:88,avg_a_R:-0.32,avg_d_R:0.73,avg_t:4.11,avg_h:0.09,acc_A_R:246.13,acc_D_R:954.00,replay_s:-1,lr
# al] episode:89,avg_a_R:-0.31,avg_d_R:0.73,avg_t:4.16,avg_h:0.09,acc_A_R:246.63,acc_D_R:955.00,replay_s:-1,lr
# al] episode:90,avg_a_R:-0.31,avg_d_R:0.74,avg_t:4.14,avg_h:0.09,acc_A_R:245.63,acc_D_R:956.00,replay_s:-1,lr
# al] episode:91,avg_a_R:-0.32,avg_d_R:0.74,avg_t:4.15,avg_h:0.09,acc_A_R:244.63,acc_D_R:957.00,replay_s:-1,lr
# al] episode:92,avg_a_R:-0.33,avg_d_R:0.74,avg_t:4.12,avg_h:0.09,acc_A_R:243.63,acc_D_R:958.00,replay_s:-1,lr
# al] episode:93,avg_a_R:-0.30,avg_d_R:0.71,avg_t:4.17,avg_h:0.10,acc_A_R:246.21,acc_D_R:956.00,replay_s:-1,lr
# al] episode:94,avg_a_R:-0.31,avg_d_R:0.72,avg_t:4.18,avg_h:0.09,acc_A_R:245.21,acc_D_R:957.00,replay_s:-1,lr
# al] episode:95,avg_a_R:-0.29,avg_d_R:0.72,avg_t:4.24,avg_h:0.09,acc_A_R:246.21,acc_D_R:958.00,replay_s:-1,lr
# al] episode:96,avg_a_R:-0.30,avg_d_R:0.72,avg_t:4.22,avg_h:0.09,acc_A_R:245.21,acc_D_R:959.00,replay_s:-1,lr
# al] episode:97,avg_a_R:-0.31,avg_d_R:0.72,avg_t:4.21,avg_h:0.09,acc_A_R:244.21,acc_D_R:960.00,replay_s:-1,lr
# al] episode:98,avg_a_R:-0.31,avg_d_R:0.73,avg_t:4.19,avg_h:0.09,acc_A_R:243.21,acc_D_R:961.00,replay_s:-1,lr
# al] episode:99,avg_a_R:-0.32,avg_d_R:0.73,avg_t:4.21,avg_h:0.09,acc_A_R:242.21,acc_D_R:962.00,replay_s:-1,lr
# starting eval with non-empty result object_a_R:0.31,avg_d_R:0.31,avg_t:5.18,avg_h:0.23,acc_A_R:-115.22,acc_D_R:
#
# [Eval] episode:19000,avg_a_R:-0.32,avg_d_R:0.73,avg_t:4.21,avg_h:0.09,acc_A_R:242.21,acc_D_R:962.00,replay_s:-1
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] episode:0,avg_a_R:3.33,avg_d_R:-2.00,avg_t:6.00,avg_h:1.00,acc_A_R:245.54,acc_D_R:960.00,replay_s:-1,lr:
# al] episode:1,avg_a_R:3.67,avg_d_R:-2.00,avg_t:4.50,avg_h:1.00,acc_A_R:249.54,acc_D_R:958.00,replay_s:-1,lr:
# al] episode:2,avg_a_R:2.11,avg_d_R:-1.00,avg_t:3.33,avg_h:0.67,acc_A_R:248.54,acc_D_R:959.00,replay_s:-1,lr:
# al] episode:3,avg_a_R:1.33,avg_d_R:-0.50,avg_t:4.00,avg_h:0.50,acc_A_R:247.54,acc_D_R:960.00,replay_s:-1,lr:
# al] episode:4,avg_a_R:1.11,avg_d_R:-0.20,avg_t:5.20,avg_h:0.40,acc_A_R:247.74,acc_D_R:961.00,replay_s:-1,lr:
# al] episode:5,avg_a_R:0.76,avg_d_R:0.00,avg_t:4.83,avg_h:0.33,acc_A_R:246.74,acc_D_R:962.00,replay_s:-1,lr:0
# al] episode:6,avg_a_R:0.50,avg_d_R:0.14,avg_t:4.29,avg_h:0.29,acc_A_R:245.74,acc_D_R:963.00,replay_s:-1,lr:0
# al] episode:7,avg_a_R:0.46,avg_d_R:0.25,avg_t:5.00,avg_h:0.25,acc_A_R:245.87,acc_D_R:964.00,replay_s:-1,lr:0
# al] episode:8,avg_a_R:0.30,avg_d_R:0.33,avg_t:4.89,avg_h:0.22,acc_A_R:244.87,acc_D_R:965.00,replay_s:-1,lr:0
# al] episode:9,avg_a_R:0.37,avg_d_R:0.40,avg_t:4.70,avg_h:0.20,acc_A_R:245.87,acc_D_R:966.00,replay_s:-1,lr:0
# al] episode:10,avg_a_R:0.24,avg_d_R:0.45,avg_t:5.00,avg_h:0.18,acc_A_R:244.87,acc_D_R:967.00,replay_s:-1,lr:
# al] episode:11,avg_a_R:0.42,avg_d_R:0.25,avg_t:6.08,avg_h:0.25,acc_A_R:247.20,acc_D_R:965.00,replay_s:-1,lr:
# al] episode:12,avg_a_R:0.31,avg_d_R:0.31,avg_t:5.85,avg_h:0.23,acc_A_R:246.20,acc_D_R:966.00,replay_s:-1,lr:
# al] episode:13,avg_a_R:0.32,avg_d_R:0.36,avg_t:6.07,avg_h:0.21,acc_A_R:246.70,acc_D_R:967.00,replay_s:-1,lr:
# al] episode:14,avg_a_R:0.23,avg_d_R:0.40,avg_t:6.07,avg_h:0.20,acc_A_R:245.70,acc_D_R:968.00,replay_s:-1,lr:
# al] episode:15,avg_a_R:0.28,avg_d_R:0.44,avg_t:5.81,avg_h:0.19,acc_A_R:246.70,acc_D_R:969.00,replay_s:-1,lr:
# al] episode:16,avg_a_R:0.50,avg_d_R:0.29,avg_t:5.65,avg_h:0.24,acc_A_R:250.70,acc_D_R:967.00,replay_s:-1,lr:
# al] episode:17,avg_a_R:0.65,avg_d_R:0.17,avg_t:5.67,avg_h:0.28,acc_A_R:253.95,acc_D_R:965.00,replay_s:-1,lr:
# al] episode:18,avg_a_R:0.63,avg_d_R:0.21,avg_t:5.79,avg_h:0.26,acc_A_R:254.20,acc_D_R:966.00,replay_s:-1,lr:
# al] episode:19,avg_a_R:0.55,avg_d_R:0.25,avg_t:5.85,avg_h:0.25,acc_A_R:253.20,acc_D_R:967.00,replay_s:-1,lr:
# al] episode:20,avg_a_R:0.48,avg_d_R:0.29,avg_t:5.76,avg_h:0.24,acc_A_R:252.20,acc_D_R:968.00,replay_s:-1,lr:
# al] episode:21,avg_a_R:0.48,avg_d_R:0.32,avg_t:5.73,avg_h:0.23,acc_A_R:252.70,acc_D_R:969.00,replay_s:-1,lr:
# al] episode:22,avg_a_R:0.41,avg_d_R:0.35,avg_t:5.57,avg_h:0.22,acc_A_R:251.70,acc_D_R:970.00,replay_s:-1,lr:
# al] episode:22,avg_a_R:0.41,avg_d_R:0.35,avg_t:5.57,avg_h:0.22,acc_A_R:251.70,acc_D_R:970.00,replay_s:-1,lr:
# al] episode:23,avg_a_R:0.35,avg_d_R:0.38,avg_t:5.50,avg_h:0.21,acc_A_R:250.70,acc_D_R:971.00,replay_s:-1,lr:
# al] episode:24,avg_a_R:0.30,avg_d_R:0.40,avg_t:5.36,avg_h:0.20,acc_A_R:249.70,acc_D_R:972.00,replay_s:-1,lr:
# al] episode:25,avg_a_R:0.42,avg_d_R:0.31,avg_t:5.31,avg_h:0.23,acc_A_R:253.20,acc_D_R:970.00,replay_s:-1,lr:
# al] episode:26,avg_a_R:0.37,avg_d_R:0.33,avg_t:5.19,avg_h:0.22,acc_A_R:252.20,acc_D_R:971.00,replay_s:-1,lr:
# al] episode:27,avg_a_R:0.32,avg_d_R:0.36,avg_t:5.11,avg_h:0.21,acc_A_R:251.20,acc_D_R:972.00,replay_s:-1,lr:
# al] episode:28,avg_a_R:0.42,avg_d_R:0.28,avg_t:5.21,avg_h:0.24,acc_A_R:254.40,acc_D_R:970.00,replay_s:-1,lr:
# al] episode:29,avg_a_R:0.37,avg_d_R:0.30,avg_t:5.10,avg_h:0.23,acc_A_R:253.40,acc_D_R:971.00,replay_s:-1,lr:
# al] episode:30,avg_a_R:0.33,avg_d_R:0.32,avg_t:5.06,avg_h:0.23,acc_A_R:252.40,acc_D_R:972.00,replay_s:-1,lr:
# al] episode:31,avg_a_R:0.33,avg_d_R:0.34,avg_t:5.03,avg_h:0.22,acc_A_R:252.90,acc_D_R:973.00,replay_s:-1,lr:
# al] episode:32,avg_a_R:0.35,avg_d_R:0.36,avg_t:5.06,avg_h:0.21,acc_A_R:253.90,acc_D_R:974.00,replay_s:-1,lr:
# al] episode:33,avg_a_R:0.31,avg_d_R:0.38,avg_t:5.06,avg_h:0.21,acc_A_R:252.90,acc_D_R:975.00,replay_s:-1,lr:
# al] episode:34,avg_a_R:0.33,avg_d_R:0.40,avg_t:5.03,avg_h:0.20,acc_A_R:253.90,acc_D_R:976.00,replay_s:-1,lr:
# al] episode:35,avg_a_R:0.30,avg_d_R:0.42,avg_t:5.03,avg_h:0.19,acc_A_R:252.90,acc_D_R:977.00,replay_s:-1,lr:
# al] episode:36,avg_a_R:0.26,avg_d_R:0.43,avg_t:4.92,avg_h:0.19,acc_A_R:251.90,acc_D_R:978.00,replay_s:-1,lr:
# al] episode:37,avg_a_R:0.26,avg_d_R:0.45,avg_t:5.00,avg_h:0.18,acc_A_R:252.07,acc_D_R:979.00,replay_s:-1,lr:
# al] episode:38,avg_a_R:0.28,avg_d_R:0.46,avg_t:4.97,avg_h:0.18,acc_A_R:253.07,acc_D_R:980.00,replay_s:-1,lr:
# al] episode:39,avg_a_R:0.25,avg_d_R:0.47,avg_t:4.90,avg_h:0.17,acc_A_R:252.07,acc_D_R:981.00,replay_s:-1,lr:
# al] episode:40,avg_a_R:0.25,avg_d_R:0.49,avg_t:4.93,avg_h:0.17,acc_A_R:252.40,acc_D_R:982.00,replay_s:-1,lr:
# al] episode:41,avg_a_R:0.22,avg_d_R:0.50,avg_t:4.98,avg_h:0.17,acc_A_R:251.40,acc_D_R:983.00,replay_s:-1,lr:
# al] episode:42,avg_a_R:0.19,avg_d_R:0.51,avg_t:4.91,avg_h:0.16,acc_A_R:250.40,acc_D_R:984.00,replay_s:-1,lr:
# al] episode:43,avg_a_R:0.19,avg_d_R:0.52,avg_t:5.00,avg_h:0.16,acc_A_R:250.55,acc_D_R:985.00,replay_s:-1,lr:
# al] episode:44,avg_a_R:0.26,avg_d_R:0.47,avg_t:5.07,avg_h:0.18,acc_A_R:253.71,acc_D_R:983.00,replay_s:-1,lr:
# al] episode:45,avg_a_R:0.25,avg_d_R:0.48,avg_t:5.15,avg_h:0.17,acc_A_R:253.86,acc_D_R:984.00,replay_s:-1,lr:
# al] episode:45,avg_a_R:0.25,avg_d_R:0.48,avg_t:5.15,avg_h:0.17,acc_A_R:253.86,acc_D_R:984.00,replay_s:-1,lr:
# al] episode:46,avg_a_R:0.27,avg_d_R:0.49,avg_t:5.13,avg_h:0.17,acc_A_R:254.86,acc_D_R:985.00,replay_s:-1,lr:
# al] episode:47,avg_a_R:0.24,avg_d_R:0.50,avg_t:5.04,avg_h:0.17,acc_A_R:253.86,acc_D_R:986.00,replay_s:-1,lr:
# al] episode:48,avg_a_R:0.22,avg_d_R:0.51,avg_t:4.96,avg_h:0.16,acc_A_R:252.86,acc_D_R:987.00,replay_s:-1,lr:
# al] episode:49,avg_a_R:0.23,avg_d_R:0.52,avg_t:4.94,avg_h:0.16,acc_A_R:253.86,acc_D_R:988.00,replay_s:-1,lr:
# al] episode:50,avg_a_R:0.21,avg_d_R:0.53,avg_t:4.90,avg_h:0.16,acc_A_R:252.86,acc_D_R:989.00,replay_s:-1,lr:
# al] episode:51,avg_a_R:0.19,avg_d_R:0.54,avg_t:4.85,avg_h:0.15,acc_A_R:251.86,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:52,avg_a_R:0.16,avg_d_R:0.55,avg_t:4.85,avg_h:0.15,acc_A_R:250.86,acc_D_R:991.00,replay_s:-1,lr:
# al] episode:53,avg_a_R:0.16,avg_d_R:0.56,avg_t:5.02,avg_h:0.15,acc_A_R:250.94,acc_D_R:992.00,replay_s:-1,lr:
# al] episode:54,avg_a_R:0.22,avg_d_R:0.51,avg_t:5.07,avg_h:0.16,acc_A_R:254.14,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:55,avg_a_R:0.20,avg_d_R:0.52,avg_t:5.05,avg_h:0.16,acc_A_R:253.14,acc_D_R:991.00,replay_s:-1,lr:
# al] episode:56,avg_a_R:0.17,avg_d_R:0.53,avg_t:5.04,avg_h:0.16,acc_A_R:252.14,acc_D_R:992.00,replay_s:-1,lr:
# al] episode:57,avg_a_R:0.15,avg_d_R:0.53,avg_t:5.10,avg_h:0.16,acc_A_R:251.14,acc_D_R:993.00,replay_s:-1,lr:
# al] episode:58,avg_a_R:0.13,avg_d_R:0.54,avg_t:5.10,avg_h:0.15,acc_A_R:250.14,acc_D_R:994.00,replay_s:-1,lr:
# al] episode:59,avg_a_R:0.14,avg_d_R:0.55,avg_t:5.10,avg_h:0.15,acc_A_R:250.64,acc_D_R:995.00,replay_s:-1,lr:
# al] episode:60,avg_a_R:0.12,avg_d_R:0.56,avg_t:5.03,avg_h:0.15,acc_A_R:249.64,acc_D_R:996.00,replay_s:-1,lr:
# al] episode:61,avg_a_R:0.16,avg_d_R:0.52,avg_t:5.11,avg_h:0.16,acc_A_R:252.17,acc_D_R:994.00,replay_s:-1,lr:
# al] episode:62,avg_a_R:0.14,avg_d_R:0.52,avg_t:5.11,avg_h:0.16,acc_A_R:251.17,acc_D_R:995.00,replay_s:-1,lr:
# al] episode:63,avg_a_R:0.12,avg_d_R:0.53,avg_t:5.06,avg_h:0.16,acc_A_R:250.17,acc_D_R:996.00,replay_s:-1,lr:
# al] episode:64,avg_a_R:0.11,avg_d_R:0.54,avg_t:5.03,avg_h:0.15,acc_A_R:249.17,acc_D_R:997.00,replay_s:-1,lr:
# al] episode:65,avg_a_R:0.09,avg_d_R:0.55,avg_t:4.98,avg_h:0.15,acc_A_R:248.17,acc_D_R:998.00,replay_s:-1,lr:
# al] episode:66,avg_a_R:0.07,avg_d_R:0.55,avg_t:4.94,avg_h:0.15,acc_A_R:247.17,acc_D_R:999.00,replay_s:-1,lr:
# al] episode:67,avg_a_R:0.06,avg_d_R:0.56,avg_t:4.91,avg_h:0.15,acc_A_R:246.17,acc_D_R:1000.00,replay_s:-1,lr
# al] episode:67,avg_a_R:0.06,avg_d_R:0.56,avg_t:4.91,avg_h:0.15,acc_A_R:246.17,acc_D_R:1000.00,replay_s:-1,lr
# al] episode:68,avg_a_R:0.07,avg_d_R:0.57,avg_t:4.90,avg_h:0.14,acc_A_R:247.17,acc_D_R:1001.00,replay_s:-1,lr
# al] episode:69,avg_a_R:0.06,avg_d_R:0.57,avg_t:4.84,avg_h:0.14,acc_A_R:246.17,acc_D_R:1002.00,replay_s:-1,lr
# al] episode:70,avg_a_R:0.09,avg_d_R:0.54,avg_t:4.90,avg_h:0.15,acc_A_R:248.76,acc_D_R:1000.00,replay_s:-1,lr
# al] episode:71,avg_a_R:0.14,avg_d_R:0.50,avg_t:4.90,avg_h:0.17,acc_A_R:252.26,acc_D_R:998.00,replay_s:-1,lr:
# al] episode:72,avg_a_R:0.17,avg_d_R:0.47,avg_t:5.04,avg_h:0.18,acc_A_R:254.56,acc_D_R:996.00,replay_s:-1,lr:
# al] episode:73,avg_a_R:0.20,avg_d_R:0.43,avg_t:5.15,avg_h:0.19,acc_A_R:256.93,acc_D_R:994.00,replay_s:-1,lr:
# al] episode:74,avg_a_R:0.18,avg_d_R:0.44,avg_t:5.09,avg_h:0.19,acc_A_R:255.93,acc_D_R:995.00,replay_s:-1,lr:
# al] episode:75,avg_a_R:0.21,avg_d_R:0.41,avg_t:5.28,avg_h:0.20,acc_A_R:258.17,acc_D_R:993.00,replay_s:-1,lr:
# al] episode:76,avg_a_R:0.25,avg_d_R:0.38,avg_t:5.29,avg_h:0.21,acc_A_R:261.17,acc_D_R:991.00,replay_s:-1,lr:
# al] episode:77,avg_a_R:0.29,avg_d_R:0.35,avg_t:5.28,avg_h:0.22,acc_A_R:264.67,acc_D_R:989.00,replay_s:-1,lr:
# al] episode:78,avg_a_R:0.27,avg_d_R:0.35,avg_t:5.30,avg_h:0.22,acc_A_R:263.67,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:79,avg_a_R:0.26,avg_d_R:0.36,avg_t:5.28,avg_h:0.21,acc_A_R:262.67,acc_D_R:991.00,replay_s:-1,lr:
# al] episode:80,avg_a_R:0.29,avg_d_R:0.33,avg_t:5.30,avg_h:0.22,acc_A_R:265.51,acc_D_R:989.00,replay_s:-1,lr:
# al] episode:81,avg_a_R:0.32,avg_d_R:0.30,avg_t:5.32,avg_h:0.23,acc_A_R:268.71,acc_D_R:987.00,replay_s:-1,lr:
# al] episode:82,avg_a_R:0.31,avg_d_R:0.31,avg_t:5.29,avg_h:0.23,acc_A_R:267.71,acc_D_R:988.00,replay_s:-1,lr:
# al] episode:83,avg_a_R:0.32,avg_d_R:0.32,avg_t:5.25,avg_h:0.23,acc_A_R:268.71,acc_D_R:989.00,replay_s:-1,lr:
# al] episode:84,avg_a_R:0.30,avg_d_R:0.33,avg_t:5.22,avg_h:0.22,acc_A_R:267.71,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:85,avg_a_R:0.32,avg_d_R:0.30,avg_t:5.31,avg_h:0.23,acc_A_R:270.07,acc_D_R:988.00,replay_s:-1,lr:
# al] episode:86,avg_a_R:0.31,avg_d_R:0.31,avg_t:5.29,avg_h:0.23,acc_A_R:269.07,acc_D_R:989.00,replay_s:-1,lr:
# al] episode:87,avg_a_R:0.29,avg_d_R:0.32,avg_t:5.25,avg_h:0.23,acc_A_R:268.07,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:87,avg_a_R:0.29,avg_d_R:0.32,avg_t:5.25,avg_h:0.23,acc_A_R:268.07,acc_D_R:990.00,replay_s:-1,lr:
# al] episode:88,avg_a_R:0.29,avg_d_R:0.33,avg_t:5.29,avg_h:0.22,acc_A_R:268.24,acc_D_R:991.00,replay_s:-1,lr:
# al] episode:89,avg_a_R:0.28,avg_d_R:0.33,avg_t:5.26,avg_h:0.22,acc_A_R:267.24,acc_D_R:992.00,replay_s:-1,lr:
# al] episode:90,avg_a_R:0.26,avg_d_R:0.34,avg_t:5.21,avg_h:0.22,acc_A_R:266.24,acc_D_R:993.00,replay_s:-1,lr:
# al] episode:91,avg_a_R:0.25,avg_d_R:0.35,avg_t:5.17,avg_h:0.22,acc_A_R:265.24,acc_D_R:994.00,replay_s:-1,lr:
# al] episode:92,avg_a_R:0.24,avg_d_R:0.35,avg_t:5.14,avg_h:0.22,acc_A_R:264.24,acc_D_R:995.00,replay_s:-1,lr:
# al] episode:93,avg_a_R:0.22,avg_d_R:0.36,avg_t:5.13,avg_h:0.21,acc_A_R:263.24,acc_D_R:996.00,replay_s:-1,lr:
# al] episode:94,avg_a_R:0.21,avg_d_R:0.37,avg_t:5.12,avg_h:0.21,acc_A_R:262.24,acc_D_R:997.00,replay_s:-1,lr:
# al] episode:95,avg_a_R:0.20,avg_d_R:0.38,avg_t:5.07,avg_h:0.21,acc_A_R:261.24,acc_D_R:998.00,replay_s:-1,lr:
# al] episode:96,avg_a_R:0.20,avg_d_R:0.38,avg_t:5.10,avg_h:0.21,acc_A_R:261.49,acc_D_R:999.00,replay_s:-1,lr:
# al] episode:97,avg_a_R:0.19,avg_d_R:0.39,avg_t:5.08,avg_h:0.20,acc_A_R:260.49,acc_D_R:1000.00,replay_s:-1,lr
# al] episode:98,avg_a_R:0.19,avg_d_R:0.39,avg_t:5.06,avg_h:0.20,acc_A_R:261.49,acc_D_R:1001.00,replay_s:-1,lr
# al] episode:99,avg_a_R:0.18,avg_d_R:0.40,avg_t:5.05,avg_h:0.20,acc_A_R:260.49,acc_D_R:1002.00,replay_s:-1,lr
# starting eval with non-empty result object0,avg_t:5.05,avg_h:0.20,acc_A_R:260.49,acc_D_R:1002.00,replay_s:-1
#
# [Eval] episode:20000,avg_a_R:0.18,avg_d_R:0.40,avg_t:5.05,avg_h:0.20,acc_A_R:260.49,acc_D_R:1002.00,replay_s:-1
#
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:   0%| | 0/100 [00:00<?, ?it/s
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00:  34%|▎| 34/100 [00:00<00:00,
# [Train] episode: 20000.00 epsilon:0.14,avg_a_R:0.31,avg_d_R:0.31,avg_t:5.18,avg_h:0.23,acc_A_R:-115.22,acc_D_R:
# al] avg_a_R:0.00,avg_d_R:0.00,avg_t:0.00,avg_h:0.00,acc_A_R:0.00,acc_D_R:0.00: 100%|█| 100/100 [00:18<00:00,

# %%
from src.utils.utils import get_output_dir, print_summary
from src.utils.plotting import plot_results

# %%
print_summary(train_result, title = "Training")
print("\n")
print_summary(eval_result, title = "Evaluation")
# Out:
# Training Summary:
# --------------------------------------------------
# Final Defense Performance:
# - Average Reward: 0.69 ± 0.09
# - Max-Min Reward: 1.0 - 0.4
# - Average Episode Length: 3.49 ± 0.48
# - Max-Min Episode Length: 5.0 - 2.5
# - Average Hack Probability: 10.24% ± 3.06%
# - Max-Min Hack Probability: 0.2 - 0.0
# - Final Cumulative Reward: 13812
#
#
#
# Evaluation Summary:
# --------------------------------------------------
# Final Defense Performance:
# - Average Reward: 0.69 ± 0.13
# - Max-Min Reward: 0.88 - 0.34
# - Average Episode Length: 3.10 ± 0.40
# - Max-Min Episode Length: 4.56 - 2.52
# - Average Hack Probability: 10.24% ± 4.21%
# - Max-Min Hack Probability: 0.22 - 0.04
# - Final Cumulative Reward: 1455

# %%
# !pip install latex
import latex
# Out:
# Requirement already satisfied: latex in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: tempdir in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from latex) (0.7.1)
# Requirement already satisfied: data in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from latex) (0.4)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from latex) (1.0.0)
# Requirement already satisfied: shutilwhich in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from latex) (1.1.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from data->latex) (1.16.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from data->latex) (5.1.1)
# Requirement already satisfied: funcsigs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from data->latex) (1.0.2)

# %%
os.makedirs("final_results", exist_ok=True)

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
results_path = os.path.join("final_results/", f"final_results_{timestamp}")

train_result.to_csv(results_path + "_train.csv")
eval_result.to_csv(results_path + "_eval.csv")

print(f"\nResults saved to: {results_path}")
# Out:
# Results saved to: final_results/final_results_2025-04-11_08-48-14

# %%
output_dir = ""
random_seed = 33
plot_results(output_dir, random_seed, algorithm = "Q Learning")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 output_dir = ""
#       2 random_seed = 33
# ----> 3 plot_results(output_dir, random_seed, algorithm = "Q Learning")
#
# NameError: name 'plot_results' is not defined

# %%
train_path = "results/data/33/1743696969.26054_train_results_checkpoint.csv"
eval_path = "results/data/33/1743696969.26054_eval_results_checkpoint.csv"

read_and_plot_results(
    train_path, eval_path,
    q_agent_config.train_log_frequency,
    q_agent_config.eval_frequency, q_agent_config.eval_log_frequency,
    q_agent_config.eval_episodes, default_output_dir , sim = False,
    random_seed = random_seed)
# Out:
# Failed to process string with tex because latex could not be found
# Error in callback <function _draw_all_if_interactive at 0x1770437f0> (for post_execute), with arguments args (),kwargs {}:
# /Users/shirley/AI-Agent-for-Cyber-Security/experiments/util/plotting_util.py:449: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(xlims)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %%
from src.utils.plotting import plot_results
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
output_dir = ""
random_seed = 33
plot_results(output_dir, random_seed, algorithm = "Q Learning", mode="random")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[32], line 3
#       1 output_dir = ""
#       2 random_seed = 33
# ----> 3 plot_results(output_dir, random_seed, algorithm = "Q Learning", mode="random")
#
# File ~/AI-Agent-for-Cyber-Security/src/utils/plotting.py:74, in plot_results(output_dir, random_seed, algorithm, mode)
#      71 fig.text(0.25, 0.90, left_column_title, ha='center', fontsize=20)
#      72 fig.text(0.75, 0.90, right_column_title, ha='center', fontsize=20)
# ---> 74 plt.tight_layout()
#      75 plt.subplots_adjust(top=0.9, wspace=0.4)
#      76 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2801, in tight_layout(pad, h_pad, w_pad, rect)
#    2793 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2794 def tight_layout(
#    2795     *,
#    (...)
#    2799     rect: tuple[float, float, float, float] | None = None,
#    2800 ) -> None:
# -> 2801     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3545, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3543 previous_engine = self.get_layout_engine()
#    3544 self.set_layout_engine(engine)
# -> 3545 engine.execute(self)
#    3546 if previous_engine is not None and not isinstance(
#    3547     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3548 ):
#    3549     _api.warn_external('The figure layout has changed to tight')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/layout_engine.py:183, in TightLayoutEngine.execute(self, fig)
#     181 renderer = fig._get_renderer()
#     182 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183     kwargs = get_tight_layout_figure(
#     184         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     186         rect=info['rect'])
#     187 if kwargs:
#     188     fig.subplots_adjust(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:1410, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1404 """
#    1405 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1406 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1407 when encountering third-party subclasses that do not support it.
#    1408 """
#    1409 try:
# -> 1410     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1411 except TypeError:
#    1412     return obj.get_tightbbox(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:457, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     451 if len(args) > name_idx:
#     452     warn_deprecated(
#     453         since, message="Passing the %(name)s %(obj_type)s "
#     454         "positionally is deprecated since Matplotlib %(since)s; the "
#     455         "parameter will become keyword-only %(removal)s.",
#     456         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 457 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:4476, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4474 for axis in self._axis_map.values():
#    4475     if self.axison and axis.get_visible():
# -> 4476         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4477         if ba:
#    4478             bb.append(ba)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:1410, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1404 """
#    1405 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1406 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1407 when encountering third-party subclasses that do not support it.
#    1408 """
#    1409 try:
# -> 1410     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1411 except TypeError:
#    1412     return obj.get_tightbbox(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2413, in XAxis._update_label_position(self, renderer)
#    2409     return
#    2411 # get bounding boxes for this axis and any siblings
#    2412 # that have been set by `fig.align_xlabels()`
# -> 2413 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2415 x, y = self.label.get_position()
#    2416 if self.label_position == 'bottom':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
# Error in callback <function _draw_all_if_interactive at 0x1770437f0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1842, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1841         err_msg = os.strerror(errno_num)
# -> 1842     raise child_exception_type(errno_num, err_msg, err_filename)
#    1843 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1372, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1369     renderer = self.figure._get_renderer()
#    1370 ticks_to_draw = self._update_ticks()
# -> 1372 self._update_label_position(renderer)
#    1374 # go back to just this axis's tick labels
#    1375 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2654, in YAxis._update_label_position(self, renderer)
#    2650     return
#    2652 # get bounding boxes for this axis and any siblings
#    2653 # that have been set by `fig.align_ylabels()`
# -> 2654 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2655 x, y = self.label.get_position()
#    2656 if self.label_position == 'left':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:2206, in Axis._get_tick_boxes_siblings(self, renderer)
#    2204 axis = ax._axis_map[name]
#    2205 ticks_to_draw = axis._update_ticks()
# -> 2206 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2207 bboxes.extend(tlb)
#    2208 bboxes2.extend(tlb2)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:212, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     210 _api.check_in_list(["TeX", True, False], ismath=ismath)
#     211 if ismath == "TeX":
# --> 212     return super().get_text_width_height_descent(s, prop, ismath)
#     214 if ismath:
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/backend_bases.py:597, in RendererBase.get_text_width_height_descent(self, s, prop, ismath)
#     593 fontsize = prop.get_size_in_points()
#     595 if ismath == 'TeX':
#     596     # todo: handle properties
# --> 597     return self.get_texmanager().get_text_width_height_descent(
#     598         s, fontsize, renderer=self)
#     600 dpi = self.points_to_pixels(72)
#     601 if ismath:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:363, in TexManager.get_text_width_height_descent(cls, tex, fontsize, renderer)
#     361 if tex.strip() == '':
#     362     return 0, 0, 0
# --> 363 dvifile = cls.make_dvi(tex, fontsize)
#     364 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     365 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:295, in TexManager.make_dvi(cls, tex, fontsize)
#     293     with TemporaryDirectory(dir=cwd) as tmpdir:
#     294         tmppath = Path(tmpdir)
# --> 295         cls._run_checked_subprocess(
#     296             ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     297              f"--output-directory={tmppath.name}",
#     298              f"{texfile.name}"], tex, cwd=cwd)
#     299         (tmppath / Path(dvifile).name).replace(dvifile)
#     300 return dvifile
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/texmanager.py:254, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
# --> 254     raise RuntimeError(
#     255         f'Failed to process string with tex because {command[0]} '
#     256         'could not be found') from exc
#     257 except subprocess.CalledProcessError as exc:
#     258     raise RuntimeError(
#     259         '{prog} was not able to process the following string:\n'
#     260         '{tex!r}\n\n'
#    (...)
#     267             exc=exc.output.decode('utf-8', 'backslashreplace'))
#     268         ) from None
#
# RuntimeError: Failed to process string with tex because latex could not be found
